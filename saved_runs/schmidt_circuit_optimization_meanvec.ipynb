# %%
import pennylane as qml
import numpy as np
from math import ceil, log2
import torch
import torch.nn as nn
from schmidt_decomposition import SchmidtDecomposition, number_of_terms_above_threshold


# -----------------------------------------------------------------------------
# 2) Quantum circuit module with probs optimization
# -----------------------------------------------------------------------------
class SchmidtQuantumCircuit(nn.Module):
    def __init__(
        self,
        n_qubits: int,
        n_terms: int,
        init_terms: list = None,
        n_ancilla_layers: int = 2,
    ):
        super().__init__()
        self.n_qubits = n_qubits
        self.n_terms = n_terms
        self.n_ancilla = ceil(log2(n_terms)) if n_terms > 1 else 0
        self.n_ancilla_layers = n_ancilla_layers

        # Ancilla rotation parameters
        if self.n_ancilla > 0:
            num_ancilla_params = self.n_ancilla + max(0, self.n_ancilla - 1)
            self.ancilla_params = nn.Parameter(
                torch.randn(self.n_ancilla_layers * num_ancilla_params)
            )
        else:
            self.ancilla_params = None

        # Data-qubit parameters - now with optional Schmidt initialization
        self.unitary_params = nn.ParameterList()

        # # Initialize from Schmidt decomposition if provided
        # # We did not observe any performance improvement from this!
        # # maybe the angle computations for also coefficients would make better!
        # if init_terms:

        #     for k in range(min(n_terms, len(init_terms))):
        #         term_angles = []
        #         for vector in init_terms[k]:
        #             angle = SchmidtDecomposition.vector_to_angle(vector)
        #             term_angles.append(angle)
        #         # Initialize parameter with Schmidt-derived angles
        #         self.unitary_params.append(
        #             nn.Parameter(torch.tensor(term_angles, dtype=torch.float32)))

        #     # Initialize remaining terms randomly
        #     for _ in range(n_terms - len(init_terms)):
        #         print("herrrrr")
        #         self.unitary_params.append(
        #             nn.Parameter(torch.randn(self.n_qubits)))
        # else:
        # All random initialization
        for _ in range(n_terms):
            self.unitary_params.append(nn.Parameter(torch.randn(self.n_qubits)))

        self.dev = qml.device("lightning.qubit", wires=self.n_ancilla + self.n_qubits)
        self.qnode = self.create_qnode()

    def create_qnode(self):
        @qml.qnode(self.dev, interface="torch")
        def circuit(features):
            # Ancilla preparation
            if self.n_ancilla > 0:
                p = 0
                for l in range(self.n_ancilla_layers):
                    for i in range(self.n_ancilla):
                        qml.RY(self.ancilla_params[p], wires=i)
                        p += 1
                    for i in range(self.n_ancilla - 1):
                        qml.CRY(self.ancilla_params[p], wires=[i, i + 1])
                        p += 1

            # Embed input data
            data_wires = list(range(self.n_ancilla, self.n_ancilla + self.n_qubits))
            qml.AmplitudeEmbedding(features=features, wires=data_wires, normalize=True)

            # Apply parameterized unitaries
            ctrl_qubits = list(range(self.n_ancilla))
            if self.n_ancilla == 0:
                for q in range(self.n_qubits):
                    qml.RY(self.unitary_params[0][q], wires=q + self.n_ancilla)
            else:
                for k in range(self.n_terms):
                    ctrl_bin_values = bin(k)[2:].zfill(self.n_ancilla)
                    ctrl_int_values = [int(a) for a in list(ctrl_bin_values)]
                    for q in range(self.n_qubits):
                        qml.ctrl(qml.RY, ctrl_qubits, control_values=ctrl_int_values)(
                            self.unitary_params[k][q], wires=q + self.n_ancilla
                        )

            return qml.probs(data_wires)

        return circuit

    def forward(self, x: torch.Tensor):
        return self.qnode(x)


# -----------------------------------------------------------------------------
def visualize_circuit(model, avector):
    """Visualize the quantum circuit"""
    fig, ax = qml.draw_mpl(model.qnode, show_all_wires=True)(avector)
    # plt.title("")
    plt.tight_layout()
    plt.show()


# -----------------------------------------------------------------------------
# -----------------------------------------------------------------------------
# 3) Optimization Framework
# -----------------------------------------------------------------------------
def optimize_schmidt_circuit(
    data: np.ndarray,
    schmidt_threshold=0.1,
    epochs=100,
    lr=0.01,
    single_vector=False,  # run for single or multiple vectors
    min_terms=1 #number of minimum terms
):
    """Optimizes quantum circuit to match Schmidt decomposition targets"""

    sd = SchmidtDecomposition(threshold=schmidt_threshold)

    if data.ndim == 1 or single_vector == True:
        single_vector = True
        n_qubits = int(log2(data.size))
        # Precompute target Schmidt states
        data = data / np.linalg.norm(data)  # normalize data
        mean_vec = data
        target_probs = np.abs(sd.compute_decomposition(mean_vec)) ** 2
        target_probs = torch.Tensor(target_probs).float()
        # Get initial circuit parameters from data vector
        terms, _ = sd.flatten_decomposition(mean_vec)
    else:
        single_vector = False
        n_qubits = int(log2(len(data[0])))
        # Precompute target Schmidt states
        target_probs = []
        for vec in data:
            vec_norm = np.linalg.norm(vec)
            if vec_norm == 0:
                print("⚠️Warning: Data vector has zero norm! it is converted to 1..00")
                vec[0] = 1
            else:
                vec = vec / vec_norm  # normalize vector

          
            target = np.abs(sd.compute_decomposition(vec)) ** 2
            target_probs.append(torch.tensor(target))

        target_probs = torch.stack(target_probs)
        # Get initial circuit parameters from mean vector
        mean_vec = data.mean(axis=0)
        mean_vec = mean_vec / np.linalg.norm(mean_vec)
        terms, _ = sd.flatten_decomposition(mean_vec)

    n_terms = len(terms)
    if n_terms == 1:
        n_terms = min_terms
    model = SchmidtQuantumCircuit(
        n_qubits, n_terms, init_terms=None, n_ancilla_layers=(n_terms + 1) // 2
    )

    print(
        f"Schmidt threshold:{sd.threshold}\n"
        f"Schmidt terms: {n_terms}\n"
        f"ancilla qubits: {model.n_ancilla}\n"
        f"ancilla layers: {model.n_ancilla_layers}\n"
        f"data qubits: {n_qubits}"
    )
    # visualize_circuit(model, mean_vec)
    print(qml.draw(model.qnode, decimals=None)(mean_vec))

    # Optimization setup
    optimizer = torch.optim.Adam(model.parameters(), lr=lr)
    scheduler = torch.optim.lr_scheduler.CosineAnnealingLR(optimizer, T_max=epochs)

    best_loss = 2**n_qubits
    best_output_probs = []
    losses = []
    for epoch in range(epochs):
        optimizer.zero_grad()
        if single_vector:
            # Compute circuit output
            output_probs = model(torch.tensor(data)).float()
            loss = norm_of_prob_diffs(output_probs, target_probs)
        else:
            # Compute circuit outputs
            output_probs = []
            for sample in data:
                output = model(torch.tensor(sample, dtype=torch.float32))
                output_probs.append(output)

            output_probs = torch.stack(output_probs)


            loss = average_norm_of_prob_diffs(output_probs, target_probs)

        # Backpropagation
        loss.backward()
        optimizer.step()
        scheduler.step()

        # Track best fidelity
        if loss.item() < best_loss:
            best_loss = loss.item()
            best_output_probs = output_probs

        if epoch % 5 == 0:
            print(f"Epoch {epoch:3d} | Loss: {loss.item():.4f} | Best {best_loss:.4f}")

        losses.append(loss.item())

    print(f"\nOptimization Complete | Best Loss: {best_loss:.4f}")
    print("found", torch.round(best_output_probs, decimals=2))
    print("target", torch.round(target_probs, decimals=2))
    return (
        model,
        best_loss,
        losses,
    )

def mse_loss(probs1: torch.Tensor, probs2: torch.Tensor):
    """Compute MSE between two probability tensors"""
    return torch.mean((probs1 - probs2)**2)
    
def norm_of_prob_diffs(probs1: torch.Tensor, probs2: torch.Tensor):
    """Compute average state fidelity between two states"""
    return torch.norm((probs1 - probs2),'fro')


def average_norm_of_prob_diffs(probs1: torch.Tensor, probs2: torch.Tensor):
    """Compute average state fidelity between two sets of state vectors"""
    return torch.norm((probs1 - probs2),'fro') / len(probs1)


#####################################################3
######################### the below is for running###
def random_data(n_qubits, dist="normal"):
    import numpy as np

    n = n_qubits
    N = 2**n
    dist = "normal"
    rng = np.random.default_rng()
    if dist == "normal":
        x = rng.normal(size=N)
    elif dist == "uniform":
        x = rng.uniform(size=N)
    elif dist == "exponential":
        x = rng.exponential(size=N)
    elif dist == "poisson":
        x = rng.poisson(size=N)
    return x


def run_for_single_vector(n_qubits=3, n_runs=100):
    all_results = {}
    for i in range(n_runs):
        avec = random_data(n_qubits)
        avec = avec / np.linalg.norm(avec)
        qc, best_loss, _ = optimize_schmidt_circuit(
            avec, schmidt_threshold=0.05, epochs=100, lr=0.01
        )
        all_results[i] = best_loss

    return all_results


def run_for_mean_vector(number_of_runs=1, sample_size=20,datasets=None):
    from data_loaders import load_dataset
    if datasets is None:
        datasets = ["iris",]
    all_results = {}
    sample_size = sample_size
    for ds in datasets:
        print("=" * 40)
        print(
            f"running for the data set {ds}\n"
            f"for random {sample_size} sample data vectors"
        )
        X, y, n_qubits, n_classes = load_dataset(ds)

        average_loss = 0
        for i in range(number_of_runs):

            sample_indices = np.random.choice(
                X.shape[0], 
                size=min(sample_size, 
                         X.shape[0]), 
                replace=False
            )
            mean_vec = X[sample_indices].mean(axis=0)
            mean_vec = mean_vec / np.linalg.norm(mean_vec)
            qc, best_loss, losses = optimize_schmidt_circuit(
                mean_vec, schmidt_threshold=0.3, epochs=200, lr=0.01
            )
            all_results[ds + f"-{i}"] = (best_loss, losses)
            average_loss += best_loss
        print(f"the final average loss for {ds} is { average_loss/number_of_runs}\n")
        print("=" * 40)

    print(all_results)
    return all_results


def run_for_data_samples(number_of_runs=1, sample_size=20,datasets=None):
    from data_loaders import load_dataset
    if datasets is None:
        datasets = ["iris",]
    all_results = {}
    sample_size = sample_size
    for ds in datasets:
        print("=" * 40)
        print(
            f"running for the data set {ds}\n"
            f"for random {sample_size} sample data vectors"
        )
        X, y, n_qubits, n_classes = load_dataset(ds)

        average_loss = 0
        for i in range(number_of_runs):
            sample_indices = np.random.choice(
                len(X), size=min(sample_size, len(X)), replace=False
            )

            qc, best_loss, losses = optimize_schmidt_circuit(
                X[sample_indices], schmidt_threshold=0.3, epochs=200, lr=0.01
            )
            all_results[ds + f"-{i}"] = (best_loss, losses)
            average_loss += best_loss
        print(f"the final average loss for {ds} is { average_loss/number_of_runs}\n")
        print("=" * 40)

    print(all_results)
    return all_results


# %%


def plot_results(all_results, number_of_runs=5, fig_name="loss_curves"):
    from matplotlib import pyplot as plt
    import numpy as np
    import matplotlib as mpl

    # Configure global font settings
    mpl.rcParams.update(
        {
            "font.size": 24,
            "axes.titlesize": 24,
            "axes.labelsize": 24,
            "xtick.labelsize": 24,
            "ytick.labelsize": 24,
            "legend.fontsize": 24,
        }
    )

    # Extract dataset names (unique base names without run index)
    base_datasets = sorted({k.split("-")[0] for k in all_results.keys()})

    # Create 2x3 subplot grid
    fig, axs = plt.subplots(2, 3, figsize=(24, 14))
    axs = axs.flatten()

    for i, dataset in enumerate(base_datasets):
        if i >= 6:  # Only plot first 6 datasets
            break

        ax = axs[i]
        dataset_losses = []
        best_losses = []

        # Collect all runs for this dataset
        for run_idx in range(number_of_runs):
            key = f"{dataset}-{run_idx}"
            if key in all_results:
                best_loss, losses = all_results[key]
                dataset_losses.append(losses)
                best_losses.append(best_loss)

        if not dataset_losses:
            continue

        # Calculate mean values
        mean_best = np.mean(best_losses)
        mean_loss = np.mean(dataset_losses, axis=0)
        epochs = len(mean_loss)

        # Plot individual runs
        for j, loss_curve in enumerate(dataset_losses):
            ax.plot(
                loss_curve,
                # color='gray',
                alpha=0.8,
                linewidth=2,
                label=f"Run {j+1}" if i == 0 else None,
            )

        # Plot mean curve
        ax.plot(
            mean_loss,
            "--",
            color="black",
            linewidth=4,
            label="Mean" if i == 0 else None,
        )

        # Add annotations
        ax.text(
            0.25,
            0.90,
            f"Mean Best: {mean_best:.3f}",
            transform=ax.transAxes,
            fontsize=24,
            bbox=dict(facecolor="white", alpha=0.8, edgecolor="gray"),
        )

        ax.text(
            0.65,
            0.75,
            f"Runs: {len(dataset_losses)}",
            transform=ax.transAxes,
            fontsize=24,
            bbox=dict(facecolor="white", alpha=0.8, edgecolor="gray"),
        )

        # Configure plot appearance
        ax.set_title(f"{dataset.replace('_', ' ').title()}", fontsize=24, pad=15)
        ax.set_xlabel("Epochs", fontsize=24)
        ax.set_ylabel("Loss", fontsize=24)
        ax.grid(True, linestyle="--", alpha=0.6)
        ax.set_yscale("log")  # Logarithmic scale often helps visualize loss

        # Only add legend to first plot
        if i == 0:
            ax.legend(loc="lower left", framealpha=0.8)

    # Handle any empty subplots
    for j in range(i + 1, 6):
        axs[j].axis("off")

    # Adjust layout
    plt.tight_layout(pad=4.0, w_pad=3.0, h_pad=4.0)

    # Save high-resolution figures
    plt.savefig(f"{fig_name}.pdf", dpi=300, bbox_inches="tight")
    plt.savefig(f"{fig_name}.png", dpi=300, bbox_inches="tight")
    plt.show()
    plt.close()


# if __name__ == "__main__":
    # qc, best_loss, losses = optimize_schmidt_circuit(
    #     X[sample_indices], schmidt_threshold=0.3, epochs=200, lr=0.01
    # )
from matplotlib import pyplot as plt
datasets = [
    "iris",
    "california_housing",
    "diabetes",
    "wine",
    "breast_cancer",
    "ionosphere",
    "covtype",
    "digits",
]
# r = run_for_single_vector()
# plt.plot(r.keys, r.values)

# data qubits: 2
# 0: ─╭|Ψ⟩──RY─┤ ╭Probs
# 1: ─╰|Ψ⟩──RY─┤ ╰Probs
# Epoch   0 | Loss: 0.2555 | Best 0.2555
# Epoch   5 | Loss: 0.2259 | Best 0.2259
# Epoch  10 | Loss: 0.1968 | Best 0.1968
# Epoch  15 | Loss: 0.1683 | Best 0.1683
# Epoch  20 | Loss: 0.1408 | Best 0.1408
# Epoch  25 | Loss: 0.1145 | Best 0.1145
# Epoch  30 | Loss: 0.0901 | Best 0.0901
# Epoch  35 | Loss: 0.0687 | Best 0.0687
# Epoch  40 | Loss: 0.0518 | Best 0.0518
# Epoch  45 | Loss: 0.0399 | Best 0.0399
# Epoch  50 | Loss: 0.0349 | Best 0.0349
# Epoch  55 | Loss: 0.0350 | Best 0.0347
# Epoch  60 | Loss: 0.0358 | Best 0.0347
# Epoch  65 | Loss: 0.0360 | Best 0.0347
# Epoch  70 | Loss: 0.0355 | Best 0.0347
# Epoch  75 | Loss: 0.0350 | Best 0.0347
# Epoch  80 | Loss: 0.0346 | Best 0.0346
# Epoch  85 | Loss: 0.0345 | Best 0.0345
# Epoch  90 | Loss: 0.0345 | Best 0.0345
# Epoch  95 | Loss: 0.0346 | Best 0.0345
# Epoch 100 | Loss: 0.0346 | Best 0.0345
# Epoch 105 | Loss: 0.0346 | Best 0.0345
# Epoch 110 | Loss: 0.0345 | Best 0.0345
# Epoch 115 | Loss: 0.0345 | Best 0.0345
# Epoch 120 | Loss: 0.0345 | Best 0.0345
# Epoch 125 | Loss: 0.0345 | Best 0.0345
# Epoch 130 | Loss: 0.0345 | Best 0.0345
# Epoch 135 | Loss: 0.0345 | Best 0.0345
# Epoch 140 | Loss: 0.0345 | Best 0.0345
# Epoch 145 | Loss: 0.0345 | Best 0.0345
# Epoch 150 | Loss: 0.0345 | Best 0.0345
# Epoch 155 | Loss: 0.0345 | Best 0.0345
# Epoch 160 | Loss: 0.0345 | Best 0.0345
# Epoch 165 | Loss: 0.0345 | Best 0.0345
# Epoch 170 | Loss: 0.0345 | Best 0.0345
# Epoch 175 | Loss: 0.0345 | Best 0.0345
# Epoch 180 | Loss: 0.0345 | Best 0.0345
# Epoch 185 | Loss: 0.0345 | Best 0.0345
# Epoch 190 | Loss: 0.0345 | Best 0.0345
# Epoch 195 | Loss: 0.0345 | Best 0.0345
#
# Optimization Complete | Best Loss: 0.0345
# found tensor([0.6500, 0.1800, 0.1600, 0.0100], grad_fn=<RoundBackward1>)
# target tensor([0.6400, 0.1700, 0.1500, 0.0400])
# Schmidt threshold:0.3
# Schmidt terms: 1
# ancilla qubits: 0
# ancilla layers: 1
# data qubits: 2
# 0: ─╭|Ψ⟩──RY─┤ ╭Probs
# 1: ─╰|Ψ⟩──RY─┤ ╰Probs
# Epoch   0 | Loss: 0.7186 | Best 0.7186
# Epoch   5 | Loss: 0.7014 | Best 0.7014
# Epoch  10 | Loss: 0.6845 | Best 0.6845
# Epoch  15 | Loss: 0.6664 | Best 0.6664
# Epoch  90 | Loss: 0.5866 | Best 0.5866
# Epoch  95 | Loss: 0.5678 | Best 0.5678
# Epoch 100 | Loss: 0.5500 | Best 0.5500
# Epoch 105 | Loss: 0.5334 | Best 0.5334
# Epoch 110 | Loss: 0.5181 | Best 0.5181
# Epoch 115 | Loss: 0.5040 | Best 0.5040
# Epoch 120 | Loss: 0.4912 | Best 0.4912
# Epoch 125 | Loss: 0.4797 | Best 0.4797
# Epoch 130 | Loss: 0.4694 | Best 0.4694
# Epoch 135 | Loss: 0.4604 | Best 0.4604
# Epoch 140 | Loss: 0.4526 | Best 0.4526
# Epoch 145 | Loss: 0.4459 | Best 0.4459
# Epoch 150 | Loss: 0.4402 | Best 0.4402
# Epoch 155 | Loss: 0.4355 | Best 0.4355
# Epoch 160 | Loss: 0.4318 | Best 0.4318
# Epoch 165 | Loss: 0.4288 | Best 0.4288
# Epoch 170 | Loss: 0.4266 | Best 0.4266
# Epoch 175 | Loss: 0.4250 | Best 0.4250
# Epoch 180 | Loss: 0.4239 | Best 0.4239
# Epoch 185 | Loss: 0.4232 | Best 0.4232
# Epoch 190 | Loss: 0.4229 | Best 0.4229
# Epoch 195 | Loss: 0.4227 | Best 0.4227
#
# Optimization Complete | Best Loss: 0.4227
# found tensor([0.2900, 0.3100, 0.1400, 0.2600], grad_fn=<RoundBackward1>)
# target tensor([0.5900, 0.1200, 0.2400, 0.0500])
# the final average loss for iris is 0.13778214156627655
#
# ========================================
# ========================================
# running for the data set california_housing
# for random 20 sample data vectors
# [[   8.3252       41.            6.98412698 ...    2.55555556
#     37.88       -122.23      ]
#  [   8.3014       21.            6.23813708 ...    2.10984183
#     37.86       -122.22      ]
#  [   7.2574       52.            8.28813559 ...    2.80225989
#     37.85       -122.24      ]
#  ...
#  [   1.7          17.            5.20554273 ...    2.3256351
#     39.43       -121.22      ]
#  [   1.8672       18.            5.32951289 ...    2.12320917
#     39.43       -121.32      ]
#  [   2.3886       16.            5.25471698 ...    2.61698113
#     39.37       -121.24      ]]
# Schmidt threshold:0.3
# Schmidt terms: 1
# ancilla qubits: 0
# ancilla layers: 1
# data qubits: 3
# 0: ─╭|Ψ⟩──RY─┤ ╭Probs
# 1: ─├|Ψ⟩──RY─┤ ├Probs
# 2: ─╰|Ψ⟩──RY─┤ ╰Probs
# Epoch   0 | Loss: 0.4020 | Best 0.4020
# Epoch   5 | Loss: 0.3688 | Best 0.3688
# Epoch  10 | Loss: 0.3370 | Best 0.3370
# Epoch  15 | Loss: 0.3067 | Best 0.3067
# Epoch  20 | Loss: 0.2781 | Best 0.2781
# Epoch  25 | Loss: 0.2513 | Best 0.2513
# Epoch  30 | Loss: 0.2266 | Best 0.2266
# Epoch  35 | Loss: 0.2040 | Best 0.2040
# Epoch  40 | Loss: 0.1836 | Best 0.1836
# Epoch  45 | Loss: 0.1652 | Best 0.1652
# Epoch  50 | Loss: 0.1488 | Best 0.1488
# Epoch  55 | Loss: 0.1342 | Best 0.1342
# Epoch  60 | Loss: 0.1214 | Best 0.1214
# Epoch 165 | Loss: 0.0165 | Best 0.0165
# Epoch 170 | Loss: 0.0165 | Best 0.0165
# Epoch 175 | Loss: 0.0164 | Best 0.0164
# Epoch 180 | Loss: 0.0164 | Best 0.0164
# Epoch 185 | Loss: 0.0164 | Best 0.0164
# Epoch 190 | Loss: 0.0164 | Best 0.0164
# Epoch 195 | Loss: 0.0164 | Best 0.0164
#
# Optimization Complete | Best Loss: 0.0164
# found tensor([0.0000, 0.0000, 0.0000, 0.0000, 0.9900, 0.0000, 0.0000, 0.0100],
#        grad_fn=<RoundBackward1>)
# target tensor([0., 0., 0., 0., 1., 0., 0., 0.])
# the final average loss for california_housing is 0.10156846456229687
#
# ========================================
# ========================================
# running for the data set diabetes
# for random 20 sample data vectors
# Schmidt threshold:0.3
# Schmidt terms: 3
# ancilla qubits: 2
# ancilla layers: 2
# data qubits: 3
# 0: ──RY──╭●───RY─╭●──╭○──╭○──╭○──╭○──╭○──╭○──╭●──╭●──╭●──┤
# 1: ──RY──╰RY──RY─╰RY─├○──├○──├○──├●──├●──├●──├○──├○──├○──┤
# 2: ─╭|Ψ⟩─────────────╰RY─│───│───╰RY─│───│───╰RY─│───│───┤ ╭Probs
# 3: ─├|Ψ⟩─────────────────╰RY─│───────╰RY─│───────╰RY─│───┤ ├Probs
# 4: ─╰|Ψ⟩─────────────────────╰RY─────────╰RY─────────╰RY─┤ ╰Probs
# Epoch   0 | Loss: 0.2028 | Best 0.2028
# Epoch   5 | Loss: 0.1727 | Best 0.1727
# Epoch  10 | Loss: 0.1466 | Best 0.1466
# Epoch  15 | Loss: 0.1239 | Best 0.1239
# Epoch  20 | Loss: 0.1053 | Best 0.1053
# Epoch  25 | Loss: 0.0910 | Best 0.0910
# Epoch  30 | Loss: 0.0805 | Best 0.0805
# Epoch  35 | Loss: 0.0733 | Best 0.0733
# Epoch  40 | Loss: 0.0682 | Best 0.0682
# Epoch  45 | Loss: 0.0643 | Best 0.0643
# Epoch  50 | Loss: 0.0611 | Best 0.0611
# Epoch  55 | Loss: 0.0582 | Best 0.0582
# Epoch  60 | Loss: 0.0555 | Best 0.0555
# Epoch  65 | Loss: 0.0529 | Best 0.0529
# Epoch  70 | Loss: 0.0505 | Best 0.0505
# Epoch  75 | Loss: 0.0485 | Best 0.0485
# Epoch  80 | Loss: 0.0467 | Best 0.0467
# Epoch  85 | Loss: 0.0453 | Best 0.0453
# Epoch  90 | Loss: 0.0441 | Best 0.0441
# Epoch  95 | Loss: 0.0431 | Best 0.0431
# Epoch 100 | Loss: 0.0422 | Best 0.0422
# Epoch 105 | Loss: 0.0415 | Best 0.0415
# Epoch 110 | Loss: 0.0408 | Best 0.0408
# Epoch 115 | Loss: 0.0403 | Best 0.0403
# Epoch 120 | Loss: 0.0398 | Best 0.0398
# Epoch 125 | Loss: 0.0394 | Best 0.0394
# Epoch 130 | Loss: 0.0391 | Best 0.0391
# Epoch 135 | Loss: 0.0388 | Best 0.0388
# Epoch 140 | Loss: 0.0385 | Best 0.0385
# Epoch 145 | Loss: 0.0383 | Best 0.0383
# Epoch 150 | Loss: 0.0382 | Best 0.0382
# Epoch 155 | Loss: 0.0380 | Best 0.0380
# Epoch 160 | Loss: 0.0379 | Best 0.0379
# Epoch 165 | Loss: 0.0378 | Best 0.0378
# Epoch 170 | Loss: 0.0378 | Best 0.0378
# Epoch 175 | Loss: 0.0377 | Best 0.0377
# Epoch 180 | Loss: 0.0377 | Best 0.0377
# Epoch 185 | Loss: 0.0377 | Best 0.0377
# Epoch 190 | Loss: 0.0377 | Best 0.0377
# Epoch 195 | Loss: 0.0377 | Best 0.0377
#
# Optimization Complete | Best Loss: 0.0377
# found tensor([0.0100, 0.5900, 0.1900, 0.0200, 0.1200, 0.0300, 0.0100, 0.0300],
#        grad_fn=<RoundBackward1>)
# target tensor([0.0000, 0.6000, 0.2100, 0.0200, 0.1400, 0.0200, 0.0000, 0.0100])
# Schmidt threshold:0.3
# Schmidt terms: 3
# ancilla qubits: 2
# ancilla layers: 2
# data qubits: 3
# 0: ──RY──╭●───RY─╭●──╭○──╭○──╭○──╭○──╭○──╭○──╭●──╭●──╭●──┤
# 1: ──RY──╰RY──RY─╰RY─├○──├○──├○──├●──├●──├●──├○──├○──├○──┤
# 2: ─╭|Ψ⟩─────────────╰RY─│───│───╰RY─│───│───╰RY─│───│───┤ ╭Probs
# 3: ─├|Ψ⟩─────────────────╰RY─│───────╰RY─│───────╰RY─│───┤ ├Probs
# 4: ─╰|Ψ⟩─────────────────────╰RY─────────╰RY─────────╰RY─┤ ╰Probs
# Epoch   0 | Loss: 0.2477 | Best 0.2477
# Epoch   5 | Loss: 0.2067 | Best 0.2067
# Epoch  10 | Loss: 0.1688 | Best 0.1688
# Epoch  15 | Loss: 0.1348 | Best 0.1348
# Epoch  20 | Loss: 0.1054 | Best 0.1054
# Epoch  25 | Loss: 0.0810 | Best 0.0810
# Epoch  30 | Loss: 0.0617 | Best 0.0617
# Epoch  35 | Loss: 0.0476 | Best 0.0476
# Epoch  40 | Loss: 0.0380 | Best 0.0380
# Epoch  45 | Loss: 0.0319 | Best 0.0319
# Epoch  50 | Loss: 0.0284 | Best 0.0284
# Epoch  55 | Loss: 0.0261 | Best 0.0261
# Epoch  60 | Loss: 0.0248 | Best 0.0248
# Epoch  65 | Loss: 0.0239 | Best 0.0239
# Epoch  70 | Loss: 0.0233 | Best 0.0233
# Epoch  75 | Loss: 0.0229 | Best 0.0229
# Epoch  80 | Loss: 0.0226 | Best 0.0226
# Epoch  85 | Loss: 0.0223 | Best 0.0223
# Epoch  90 | Loss: 0.0221 | Best 0.0221
# Epoch  95 | Loss: 0.0220 | Best 0.0220
# Epoch 100 | Loss: 0.0219 | Best 0.0219
# Epoch 105 | Loss: 0.0218 | Best 0.0218
# Epoch 110 | Loss: 0.0217 | Best 0.0217
# Epoch 115 | Loss: 0.0216 | Best 0.0216
# Epoch 120 | Loss: 0.0215 | Best 0.0215
# Epoch 125 | Loss: 0.0215 | Best 0.0215
# Epoch 130 | Loss: 0.0214 | Best 0.0214
# Epoch 135 | Loss: 0.0214 | Best 0.0214
# Epoch 140 | Loss: 0.0214 | Best 0.0214
# Epoch 145 | Loss: 0.0213 | Best 0.0213
# Epoch 150 | Loss: 0.0213 | Best 0.0213
# Epoch 155 | Loss: 0.0213 | Best 0.0213
# Epoch 160 | Loss: 0.0213 | Best 0.0213
# Epoch 165 | Loss: 0.0213 | Best 0.0213
# Epoch 170 | Loss: 0.0213 | Best 0.0213
# Epoch 175 | Loss: 0.0212 | Best 0.0212
# Epoch 180 | Loss: 0.0212 | Best 0.0212
# Epoch 185 | Loss: 0.0212 | Best 0.0212
# Epoch 190 | Loss: 0.0212 | Best 0.0212
# Epoch 195 | Loss: 0.0212 | Best 0.0212
#
# Optimization Complete | Best Loss: 0.0212
# found tensor([0.0100, 0.5100, 0.1700, 0.0300, 0.2300, 0.0200, 0.0100, 0.0200],
#        grad_fn=<RoundBackward1>)
# target tensor([0.0000, 0.5200, 0.1800, 0.0300, 0.2300, 0.0300, 0.0000, 0.0100])
# Schmidt threshold:0.3
# Schmidt terms: 3
# ancilla qubits: 2
# ancilla layers: 2
# data qubits: 3
# 0: ──RY──╭●───RY─╭●──╭○──╭○──╭○──╭○──╭○──╭○──╭●──╭●──╭●──┤
# 1: ──RY──╰RY──RY─╰RY─├○──├○──├○──├●──├●──├●──├○──├○──├○──┤
# 2: ─╭|Ψ⟩─────────────╰RY─│───│───╰RY─│───│───╰RY─│───│───┤ ╭Probs
# 3: ─├|Ψ⟩─────────────────╰RY─│───────╰RY─│───────╰RY─│───┤ ├Probs
# 4: ─╰|Ψ⟩─────────────────────╰RY─────────╰RY─────────╰RY─┤ ╰Probs
# Epoch   0 | Loss: 0.1615 | Best 0.1615
# Epoch   5 | Loss: 0.1305 | Best 0.1305
# Epoch  10 | Loss: 0.1045 | Best 0.1045
# Epoch  15 | Loss: 0.0834 | Best 0.0834
# Epoch  20 | Loss: 0.0665 | Best 0.0665
# Epoch  25 | Loss: 0.0534 | Best 0.0534
# Epoch  30 | Loss: 0.0445 | Best 0.0445
# Epoch  35 | Loss: 0.0393 | Best 0.0393
# Epoch  40 | Loss: 0.0357 | Best 0.0357
# Epoch  45 | Loss: 0.0330 | Best 0.0330
# Epoch  50 | Loss: 0.0310 | Best 0.0310
# Epoch  55 | Loss: 0.0295 | Best 0.0295
# Epoch  60 | Loss: 0.0284 | Best 0.0284
# Epoch  65 | Loss: 0.0277 | Best 0.0277
# Epoch  70 | Loss: 0.0270 | Best 0.0270
# Epoch  75 | Loss: 0.0266 | Best 0.0266
# Epoch  80 | Loss: 0.0262 | Best 0.0262
# Epoch  85 | Loss: 0.0259 | Best 0.0259
# Epoch  90 | Loss: 0.0257 | Best 0.0257
# Epoch  95 | Loss: 0.0255 | Best 0.0255
# Epoch 100 | Loss: 0.0254 | Best 0.0254
# Epoch 105 | Loss: 0.0253 | Best 0.0253
# Epoch 110 | Loss: 0.0252 | Best 0.0252
# Epoch 115 | Loss: 0.0251 | Best 0.0251
# Epoch 120 | Loss: 0.0251 | Best 0.0251
# Epoch 115 | Loss: 0.0357 | Best 0.0357
# Epoch 120 | Loss: 0.0355 | Best 0.0355
# Epoch 125 | Loss: 0.0354 | Best 0.0354
# Epoch 130 | Loss: 0.0353 | Best 0.0353
# Epoch 135 | Loss: 0.0352 | Best 0.0352
# Epoch 140 | Loss: 0.0351 | Best 0.0351
# Epoch 145 | Loss: 0.0350 | Best 0.0350
# Epoch 150 | Loss: 0.0350 | Best 0.0350
# Epoch 155 | Loss: 0.0349 | Best 0.0349
# Epoch 160 | Loss: 0.0349 | Best 0.0349
# Epoch 165 | Loss: 0.0348 | Best 0.0348
# Epoch 170 | Loss: 0.0348 | Best 0.0348
# Epoch 175 | Loss: 0.0348 | Best 0.0348
# Epoch 180 | Loss: 0.0348 | Best 0.0348
# Epoch 185 | Loss: 0.0347 | Best 0.0347
# Epoch 190 | Loss: 0.0347 | Best 0.0347
# Epoch 195 | Loss: 0.0347 | Best 0.0347
#
# Optimization Complete | Best Loss: 0.0347
# found tensor([0.0000, 0.6600, 0.1400, 0.0300, 0.0900, 0.0300, 0.0100, 0.0300],
#        grad_fn=<RoundBackward1>)
# target tensor([0.0000, 0.6700, 0.1600, 0.0300, 0.1000, 0.0200, 0.0000, 0.0100])
# Schmidt threshold:0.3
# Schmidt terms: 2
# ancilla qubits: 1
# ancilla layers: 1
# data qubits: 3
# 0: ──RY──╭○──╭○──╭○──╭●──╭●──╭●──┤
# 1: ─╭|Ψ⟩─╰RY─│───│───╰RY─│───│───┤ ╭Probs
# 2: ─├|Ψ⟩─────╰RY─│───────╰RY─│───┤ ├Probs
# 3: ─╰|Ψ⟩─────────╰RY─────────╰RY─┤ ╰Probs
# Epoch   0 | Loss: 0.3302 | Best 0.3302
# Epoch   5 | Loss: 0.2947 | Best 0.2947
# Epoch  10 | Loss: 0.2622 | Best 0.2622
# Epoch  15 | Loss: 0.2333 | Best 0.2333
# Epoch  20 | Loss: 0.2086 | Best 0.2086
# Epoch  25 | Loss: 0.1878 | Best 0.1878
# Epoch  30 | Loss: 0.1703 | Best 0.1703
# Epoch  35 | Loss: 0.1555 | Best 0.1555
# Epoch  40 | Loss: 0.1429 | Best 0.1429
# Epoch  45 | Loss: 0.1321 | Best 0.1321
# Epoch  50 | Loss: 0.1231 | Best 0.1231
# Epoch  55 | Loss: 0.1156 | Best 0.1156
# Epoch  60 | Loss: 0.1094 | Best 0.1094
# Epoch  65 | Loss: 0.1045 | Best 0.1045
# Epoch  70 | Loss: 0.1005 | Best 0.1005
# Epoch  75 | Loss: 0.0973 | Best 0.0973
# Epoch  80 | Loss: 0.0946 | Best 0.0946
# Epoch  85 | Loss: 0.0924 | Best 0.0924
# Epoch  90 | Loss: 0.0906 | Best 0.0906
# Epoch  95 | Loss: 0.0889 | Best 0.0889
# Epoch 100 | Loss: 0.0873 | Best 0.0873
# Epoch 105 | Loss: 0.0859 | Best 0.0859
# Epoch 110 | Loss: 0.0846 | Best 0.0846
# Epoch 115 | Loss: 0.0834 | Best 0.0834
# Epoch 120 | Loss: 0.0823 | Best 0.0823
# Epoch 125 | Loss: 0.0812 | Best 0.0812
# Epoch 130 | Loss: 0.0803 | Best 0.0803
# Epoch 135 | Loss: 0.0794 | Best 0.0794
# Epoch 140 | Loss: 0.0787 | Best 0.0787
# Epoch 145 | Loss: 0.0781 | Best 0.0781
# Epoch 150 | Loss: 0.0776 | Best 0.0776
# Epoch 155 | Loss: 0.0772 | Best 0.0772
# Epoch 160 | Loss: 0.0768 | Best 0.0768
# Epoch 165 | Loss: 0.0765 | Best 0.0765
# Epoch 170 | Loss: 0.0763 | Best 0.0763
# Epoch 175 | Loss: 0.0762 | Best 0.0762
# Epoch 180 | Loss: 0.0761 | Best 0.0761
# Epoch 185 | Loss: 0.0760 | Best 0.0760
# Epoch 190 | Loss: 0.0760 | Best 0.0760
# Epoch 195 | Loss: 0.0760 | Best 0.0760
#
# Optimization Complete | Best Loss: 0.0760
# found tensor([0.0100, 0.7200, 0.1400, 0.0100, 0.0500, 0.0200, 0.0200, 0.0300],
#        grad_fn=<RoundBackward1>)
# target tensor([0.0100, 0.7600, 0.1600, 0.0100, 0.0000, 0.0500, 0.0100, 0.0000])
# the final average loss for diabetes is 0.03888569734990597
#
# ========================================
# ========================================
# running for the data set wine
# for random 20 sample data vectors
# dimension 13, padding with zeros for 16
# Schmidt threshold:0.3
# Schmidt terms: 1
# ancilla qubits: 0
# ancilla layers: 1
# data qubits: 4
# 0: ─╭|Ψ⟩──RY─┤ ╭Probs
# 1: ─├|Ψ⟩──RY─┤ ├Probs
# 2: ─├|Ψ⟩──RY─┤ ├Probs
# 3: ─╰|Ψ⟩──RY─┤ ╰Probs
# Epoch   0 | Loss: 1.0001 | Best 1.0001
# Epoch   5 | Loss: 0.9756 | Best 0.9756
# Epoch  10 | Loss: 0.9504 | Best 0.9504
# Epoch  15 | Loss: 0.9250 | Best 0.9250
# Epoch  20 | Loss: 0.8995 | Best 0.8995
# Epoch  25 | Loss: 0.8741 | Best 0.8741
# Epoch  30 | Loss: 0.8485 | Best 0.8485
# Epoch  35 | Loss: 0.8220 | Best 0.8220
# Epoch  40 | Loss: 0.7941 | Best 0.7941
# Epoch  45 | Loss: 0.7647 | Best 0.7647
# Epoch  50 | Loss: 0.7339 | Best 0.7339
# Epoch  55 | Loss: 0.7023 | Best 0.7023
# Epoch  60 | Loss: 0.6705 | Best 0.6705
# Epoch  65 | Loss: 0.6390 | Best 0.6390
# Epoch  70 | Loss: 0.6082 | Best 0.6082
# Epoch  75 | Loss: 0.5784 | Best 0.5784
# Epoch  80 | Loss: 0.5499 | Best 0.5499
# Epoch  85 | Loss: 0.5229 | Best 0.5229
# Epoch  90 | Loss: 0.4973 | Best 0.4973
# Epoch  95 | Loss: 0.4734 | Best 0.4734
# Epoch 100 | Loss: 0.4512 | Best 0.4512
# Epoch 105 | Loss: 0.4308 | Best 0.4308
# Epoch 110 | Loss: 0.4123 | Best 0.4123
# Epoch 115 | Loss: 0.3955 | Best 0.3955
# Epoch 120 | Loss: 0.3805 | Best 0.3805
# Epoch 125 | Loss: 0.3672 | Best 0.3672
# Epoch 130 | Loss: 0.3556 | Best 0.3556
# Epoch 135 | Loss: 0.3454 | Best 0.3454
# Epoch 140 | Loss: 0.3367 | Best 0.3367
# Epoch 145 | Loss: 0.3294 | Best 0.3294
# Epoch 150 | Loss: 0.3232 | Best 0.3232
# Epoch 155 | Loss: 0.3181 | Best 0.3181
# Epoch 160 | Loss: 0.3141 | Best 0.3141
# Epoch 165 | Loss: 0.3109 | Best 0.3109
# Epoch 170 | Loss: 0.3085 | Best 0.3085
# Epoch 175 | Loss: 0.3068 | Best 0.3068
# Epoch 180 | Loss: 0.3056 | Best 0.3056
# Epoch 185 | Loss: 0.3049 | Best 0.3049
# Epoch 190 | Loss: 0.3045 | Best 0.3045
# Epoch 195 | Loss: 0.3044 | Best 0.3044
#
# Optimization Complete | Best Loss: 0.3043
# found tensor([0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0900,
#         0.0000, 0.0200, 0.0000, 0.7300, 0.0000, 0.1600, 0.0000],
#        grad_fn=<RoundBackward1>)
# target tensor([0.0000, 0.0000, 0.0000, 0.0000, 0.0200, 0.0000, 0.0000, 0.0000, 0.0000,
#         0.0000, 0.0000, 0.0000, 0.9800, 0.0000, 0.0000, 0.0000])
# Schmidt threshold:0.3
# Schmidt terms: 1
# ancilla qubits: 0
# ancilla layers: 1
# data qubits: 4
# 0: ─╭|Ψ⟩──RY─┤ ╭Probs
# 1: ─├|Ψ⟩──RY─┤ ├Probs
# 2: ─├|Ψ⟩──RY─┤ ├Probs
# 3: ─╰|Ψ⟩──RY─┤ ╰Probs
# Epoch   0 | Loss: 0.7348 | Best 0.7348
# Epoch   5 | Loss: 0.7010 | Best 0.7010
# Epoch  10 | Loss: 0.6660 | Best 0.6660
# Epoch  15 | Loss: 0.6302 | Best 0.6302
# Epoch  20 | Loss: 0.5938 | Best 0.5938
# Epoch  25 | Loss: 0.5572 | Best 0.5572
# Epoch  30 | Loss: 0.5207 | Best 0.5207
# Epoch  35 | Loss: 0.4846 | Best 0.4846
# Epoch  40 | Loss: 0.4492 | Best 0.4492
# Epoch  45 | Loss: 0.4151 | Best 0.4151
# Epoch  50 | Loss: 0.3824 | Best 0.3824
# Epoch  55 | Loss: 0.3514 | Best 0.3514
# Epoch  60 | Loss: 0.3223 | Best 0.3223
# Epoch  65 | Loss: 0.2952 | Best 0.2952
# Epoch  70 | Loss: 0.2702 | Best 0.2702
# Epoch  75 | Loss: 0.2473 | Best 0.2473
# Epoch  80 | Loss: 0.2265 | Best 0.2265
# Epoch  85 | Loss: 0.2078 | Best 0.2078
# Epoch  90 | Loss: 0.1911 | Best 0.1911
# Epoch  95 | Loss: 0.1763 | Best 0.1763
# Epoch 100 | Loss: 0.1632 | Best 0.1632
# Epoch 105 | Loss: 0.1517 | Best 0.1517
# Epoch 110 | Loss: 0.1416 | Best 0.1416
# Epoch 115 | Loss: 0.1329 | Best 0.1329
# Epoch 120 | Loss: 0.1253 | Best 0.1253
# Epoch 125 | Loss: 0.1188 | Best 0.1188
# Epoch 130 | Loss: 0.1133 | Best 0.1133
# Epoch 135 | Loss: 0.1086 | Best 0.1086
# Epoch 140 | Loss: 0.1046 | Best 0.1046
# Epoch 145 | Loss: 0.1013 | Best 0.1013
# Epoch 150 | Loss: 0.0986 | Best 0.0986
# Epoch 155 | Loss: 0.0964 | Best 0.0964
# Epoch 160 | Loss: 0.0947 | Best 0.0947
# Epoch 165 | Loss: 0.0933 | Best 0.0933
# Epoch 170 | Loss: 0.0923 | Best 0.0923
# Epoch 175 | Loss: 0.0915 | Best 0.0915
# Epoch 180 | Loss: 0.0910 | Best 0.0910
# Epoch 185 | Loss: 0.0907 | Best 0.0907
# Epoch 190 | Loss: 0.0905 | Best 0.0905
# Epoch 195 | Loss: 0.0905 | Best 0.0905
#
# Optimization Complete | Best Loss: 0.0905
# found tensor([0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0200,
#         0.0000, 0.0000, 0.0000, 0.9200, 0.0600, 0.0000, 0.0000],
#        grad_fn=<RoundBackward1>)
# target tensor([0.0000, 0.0000, 0.0000, 0.0000, 0.0200, 0.0000, 0.0000, 0.0000, 0.0000,
#         0.0000, 0.0000, 0.0000, 0.9800, 0.0000, 0.0000, 0.0000])
# Schmidt threshold:0.3
# Schmidt terms: 1
# ancilla qubits: 0
# ancilla layers: 1
# data qubits: 4
# 0: ─╭|Ψ⟩──RY─┤ ╭Probs
# 1: ─├|Ψ⟩──RY─┤ ├Probs
# 2: ─├|Ψ⟩──RY─┤ ├Probs
# 3: ─╰|Ψ⟩──RY─┤ ╰Probs
# Epoch   0 | Loss: 0.0836 | Best 0.0836
# Epoch   5 | Loss: 0.0615 | Best 0.0615
# Epoch  10 | Loss: 0.0447 | Best 0.0447
# Epoch  15 | Loss: 0.0335 | Best 0.0335
# Epoch  20 | Loss: 0.0273 | Best 0.0273
# Epoch  25 | Loss: 0.0237 | Best 0.0237
# Epoch  30 | Loss: 0.0197 | Best 0.0197
# Epoch  35 | Loss: 0.0147 | Best 0.0147
# Epoch  40 | Loss: 0.0097 | Best 0.0097
# Epoch  45 | Loss: 0.0077 | Best 0.0077
# Epoch  50 | Loss: 0.0052 | Best 0.0052
# Epoch  55 | Loss: 0.0043 | Best 0.0043
# Epoch  60 | Loss: 0.0030 | Best 0.0030
# Epoch  65 | Loss: 0.0023 | Best 0.0023
# Epoch  70 | Loss: 0.0021 | Best 0.0021
# Epoch  75 | Loss: 0.0019 | Best 0.0019
# Epoch  80 | Loss: 0.0018 | Best 0.0018
# Epoch  85 | Loss: 0.0017 | Best 0.0017
# Epoch  90 | Loss: 0.0017 | Best 0.0017
# Epoch  95 | Loss: 0.0017 | Best 0.0017
# Epoch 100 | Loss: 0.0016 | Best 0.0016
# Epoch 105 | Loss: 0.0016 | Best 0.0016
# Epoch 110 | Loss: 0.0016 | Best 0.0016
# Epoch 115 | Loss: 0.0016 | Best 0.0016
# Epoch 120 | Loss: 0.0016 | Best 0.0016
# Epoch 125 | Loss: 0.0016 | Best 0.0016
# Epoch 130 | Loss: 0.0016 | Best 0.0016
# Epoch 135 | Loss: 0.0016 | Best 0.0016
# Epoch 140 | Loss: 0.0016 | Best 0.0016
# Epoch 145 | Loss: 0.0016 | Best 0.0016
# Epoch 150 | Loss: 0.0016 | Best 0.0016
# Epoch 155 | Loss: 0.0016 | Best 0.0016
# Epoch 160 | Loss: 0.0016 | Best 0.0016
# Epoch 165 | Loss: 0.0016 | Best 0.0016
# Epoch 170 | Loss: 0.0016 | Best 0.0016
# Epoch 175 | Loss: 0.0016 | Best 0.0016
# Epoch 180 | Loss: 0.0016 | Best 0.0016
# Epoch 185 | Loss: 0.0016 | Best 0.0016
# Epoch 190 | Loss: 0.0016 | Best 0.0016
# Epoch 195 | Loss: 0.0016 | Best 0.0016
#
# Optimization Complete | Best Loss: 0.0016
# found tensor([0.0000, 0.0000, 0.0000, 0.0000, 0.0200, 0.0000, 0.0000, 0.0000, 0.0000,
#         0.0000, 0.0000, 0.0000, 0.9800, 0.0000, 0.0000, 0.0000],
#        grad_fn=<RoundBackward1>)
# target tensor([0.0000, 0.0000, 0.0000, 0.0000, 0.0200, 0.0000, 0.0000, 0.0000, 0.0000,
#         0.0000, 0.0000, 0.0000, 0.9800, 0.0000, 0.0000, 0.0000])
# Schmidt threshold:0.3
# Schmidt terms: 1
# ancilla qubits: 0
# ancilla layers: 1
# data qubits: 4
# 0: ─╭|Ψ⟩──RY─┤ ╭Probs
# 1: ─├|Ψ⟩──RY─┤ ├Probs
# 2: ─├|Ψ⟩──RY─┤ ├Probs
# 3: ─╰|Ψ⟩──RY─┤ ╰Probs
# Epoch   0 | Loss: 0.2564 | Best 0.2564
# Epoch   5 | Loss: 0.2225 | Best 0.2225
# Epoch  10 | Loss: 0.1914 | Best 0.1914
# Epoch  15 | Loss: 0.1634 | Best 0.1634
# Epoch  20 | Loss: 0.1380 | Best 0.1380
# Epoch  25 | Loss: 0.1154 | Best 0.1154
# Epoch  30 | Loss: 0.0954 | Best 0.0954
# Epoch  35 | Loss: 0.0778 | Best 0.0778
# Epoch  40 | Loss: 0.0624 | Best 0.0624
# Epoch  45 | Loss: 0.0491 | Best 0.0491
# Epoch  50 | Loss: 0.0377 | Best 0.0377
# Epoch  55 | Loss: 0.0279 | Best 0.0279
# Epoch  60 | Loss: 0.0196 | Best 0.0196
# Epoch  65 | Loss: 0.0125 | Best 0.0125
# Epoch  70 | Loss: 0.0066 | Best 0.0066
# Epoch  75 | Loss: 0.0021 | Best 0.0021
# Epoch  80 | Loss: 0.0025 | Best 0.0015
# Epoch  85 | Loss: 0.0032 | Best 0.0015
# Epoch  90 | Loss: 0.0027 | Best 0.0015
# Epoch  95 | Loss: 0.0017 | Best 0.0015
# Epoch 100 | Loss: 0.0016 | Best 0.0015
# Epoch 105 | Loss: 0.0017 | Best 0.0015
# Epoch 110 | Loss: 0.0016 | Best 0.0015
# Epoch 115 | Loss: 0.0015 | Best 0.0015
# Epoch 120 | Loss: 0.0015 | Best 0.0015
# Epoch 125 | Loss: 0.0015 | Best 0.0015
# Epoch 130 | Loss: 0.0015 | Best 0.0015
# Epoch 135 | Loss: 0.0015 | Best 0.0015
# Epoch 140 | Loss: 0.0015 | Best 0.0015
# Epoch 145 | Loss: 0.0015 | Best 0.0015
# Epoch 150 | Loss: 0.0015 | Best 0.0015
# Epoch 155 | Loss: 0.0015 | Best 0.0015
# Epoch 160 | Loss: 0.0015 | Best 0.0015
# Epoch 165 | Loss: 0.0015 | Best 0.0015
# Epoch 170 | Loss: 0.0015 | Best 0.0015
# Epoch 175 | Loss: 0.0015 | Best 0.0015
# Epoch 180 | Loss: 0.0015 | Best 0.0015
# Epoch 185 | Loss: 0.0015 | Best 0.0015
# Epoch 190 | Loss: 0.0015 | Best 0.0015
# Epoch 195 | Loss: 0.0015 | Best 0.0015
#
# Optimization Complete | Best Loss: 0.0015
# found tensor([0.0000, 0.0000, 0.0000, 0.0000, 0.0200, 0.0000, 0.0000, 0.0000, 0.0000,
#         0.0000, 0.0000, 0.0000, 0.9800, 0.0000, 0.0000, 0.0000],
#        grad_fn=<RoundBackward1>)
# target tensor([0.0000, 0.0000, 0.0000, 0.0000, 0.0200, 0.0000, 0.0000, 0.0000, 0.0000,
#         0.0000, 0.0000, 0.0000, 0.9800, 0.0000, 0.0000, 0.0000])
# Schmidt threshold:0.3
# Schmidt terms: 1
# ancilla qubits: 0
# ancilla layers: 1
# data qubits: 4
# 0: ─╭|Ψ⟩──RY─┤ ╭Probs
# 1: ─├|Ψ⟩──RY─┤ ├Probs
# 2: ─├|Ψ⟩──RY─┤ ├Probs
# 3: ─╰|Ψ⟩──RY─┤ ╰Probs
# Epoch   0 | Loss: 1.1840 | Best 1.1840
# Epoch   5 | Loss: 1.1524 | Best 1.1524
# Epoch  10 | Loss: 1.1197 | Best 1.1197
# Epoch  15 | Loss: 1.0866 | Best 1.0866
# Epoch  20 | Loss: 1.0538 | Best 1.0538
# Epoch  25 | Loss: 1.0222 | Best 1.0222
# Epoch  30 | Loss: 0.9924 | Best 0.9924
# Epoch  35 | Loss: 0.9651 | Best 0.9651
# Epoch  40 | Loss: 0.9404 | Best 0.9404
# Epoch  45 | Loss: 0.9183 | Best 0.9183
# Epoch  50 | Loss: 0.8985 | Best 0.8985
# Epoch  55 | Loss: 0.8805 | Best 0.8805
# Epoch  60 | Loss: 0.8635 | Best 0.8635
# Epoch  65 | Loss: 0.8471 | Best 0.8471
# Epoch  70 | Loss: 0.8308 | Best 0.8308
# Epoch  75 | Loss: 0.8143 | Best 0.8143
# Epoch  80 | Loss: 0.7974 | Best 0.7974
# Epoch  85 | Loss: 0.7802 | Best 0.7802
# Epoch  90 | Loss: 0.7628 | Best 0.7628
# Epoch  95 | Loss: 0.7454 | Best 0.7454
# Epoch 100 | Loss: 0.7281 | Best 0.7281
# Epoch 105 | Loss: 0.7113 | Best 0.7113
# Epoch 110 | Loss: 0.6951 | Best 0.6951
# Epoch 115 | Loss: 0.6798 | Best 0.6798
# Epoch 120 | Loss: 0.6655 | Best 0.6655
# Epoch 125 | Loss: 0.6523 | Best 0.6523
# Epoch 130 | Loss: 0.6403 | Best 0.6403
# Epoch 135 | Loss: 0.6296 | Best 0.6296
# Epoch 140 | Loss: 0.6202 | Best 0.6202
# Epoch 145 | Loss: 0.6120 | Best 0.6120
# Epoch 150 | Loss: 0.6051 | Best 0.6051
# Epoch 155 | Loss: 0.5994 | Best 0.5994
# Epoch 160 | Loss: 0.5947 | Best 0.5947
# Epoch 165 | Loss: 0.5910 | Best 0.5910
# Epoch 170 | Loss: 0.5882 | Best 0.5882
# Epoch 175 | Loss: 0.5862 | Best 0.5862
# Epoch 180 | Loss: 0.5848 | Best 0.5848
# Epoch 185 | Loss: 0.5840 | Best 0.5840
# Epoch 190 | Loss: 0.5836 | Best 0.5836
# Epoch 195 | Loss: 0.5834 | Best 0.5834
#
# Optimization Complete | Best Loss: 0.5834
# found tensor([0.0000, 0.0000, 0.0000, 0.0000, 0.0100, 0.0100, 0.0000, 0.0000, 0.0300,
#         0.0200, 0.0000, 0.0000, 0.5200, 0.3600, 0.0300, 0.0200],
#        grad_fn=<RoundBackward1>)
# target tensor([0.0000, 0.0000, 0.0000, 0.0000, 0.0200, 0.0000, 0.0000, 0.0000, 0.0000,
#         0.0000, 0.0000, 0.0000, 0.9800, 0.0000, 0.0000, 0.0000])
# the final average loss for wine is 0.19624811713583767
#
# ========================================
# ========================================
# running for the data set breast_cancer
# for random 20 sample data vectors
# dimension 30, padding with zeros for 32
# Schmidt threshold:0.3
# Schmidt terms: 2
# ancilla qubits: 1
# ancilla layers: 1
# data qubits: 5
# 0: ──RY──╭○──╭○──╭○──╭○──╭○──╭●──╭●──╭●──╭●──╭●──┤
# 1: ─╭|Ψ⟩─╰RY─│───│───│───│───╰RY─│───│───│───│───┤ ╭Probs
# 2: ─├|Ψ⟩─────╰RY─│───│───│───────╰RY─│───│───│───┤ ├Probs
# 3: ─├|Ψ⟩─────────╰RY─│───│───────────╰RY─│───│───┤ ├Probs
# 4: ─├|Ψ⟩─────────────╰RY─│───────────────╰RY─│───┤ ├Probs
# 5: ─╰|Ψ⟩─────────────────╰RY─────────────────╰RY─┤ ╰Probs
# Epoch   0 | Loss: 0.3117 | Best 0.3117
# Epoch   5 | Loss: 0.2695 | Best 0.2695
# Epoch  10 | Loss: 0.2293 | Best 0.2293
# Epoch  15 | Loss: 0.1921 | Best 0.1921
# Epoch  20 | Loss: 0.1587 | Best 0.1587
# Epoch  25 | Loss: 0.1298 | Best 0.1298
# Epoch  30 | Loss: 0.1058 | Best 0.1058
# Epoch  35 | Loss: 0.0865 | Best 0.0865
# Epoch  40 | Loss: 0.0714 | Best 0.0714
# Epoch  45 | Loss: 0.0598 | Best 0.0598
# Epoch  50 | Loss: 0.0510 | Best 0.0510
# Epoch  55 | Loss: 0.0445 | Best 0.0445
# Epoch  60 | Loss: 0.0397 | Best 0.0397
# Epoch  65 | Loss: 0.0361 | Best 0.0361
# Epoch  70 | Loss: 0.0335 | Best 0.0335
# Epoch  75 | Loss: 0.0315 | Best 0.0315
# Epoch  80 | Loss: 0.0300 | Best 0.0300
# Epoch  85 | Loss: 0.0288 | Best 0.0288
# Epoch  90 | Loss: 0.0278 | Best 0.0278
# Epoch  95 | Loss: 0.0270 | Best 0.0270
# Epoch 100 | Loss: 0.0264 | Best 0.0264
# Epoch 105 | Loss: 0.0258 | Best 0.0258
# Epoch 110 | Loss: 0.0253 | Best 0.0253
# Epoch 115 | Loss: 0.0248 | Best 0.0248
# Epoch 120 | Loss: 0.0244 | Best 0.0244
# Epoch 125 | Loss: 0.0240 | Best 0.0240
# Epoch 130 | Loss: 0.0237 | Best 0.0237
# Epoch 135 | Loss: 0.0233 | Best 0.0233
# Epoch 140 | Loss: 0.0231 | Best 0.0231
# Epoch 145 | Loss: 0.0228 | Best 0.0228
# Epoch 150 | Loss: 0.0226 | Best 0.0226
# Epoch 155 | Loss: 0.0224 | Best 0.0224
# Epoch 160 | Loss: 0.0223 | Best 0.0223
# Epoch 165 | Loss: 0.0221 | Best 0.0221
# Epoch 170 | Loss: 0.0220 | Best 0.0220
# Epoch 175 | Loss: 0.0219 | Best 0.0219
# Epoch 180 | Loss: 0.0219 | Best 0.0219
# Epoch 185 | Loss: 0.0219 | Best 0.0219
# Epoch 190 | Loss: 0.0218 | Best 0.0218
# Epoch 195 | Loss: 0.0218 | Best 0.0218
#
# Optimization Complete | Best Loss: 0.0218
# found tensor([0.0000, 0.0000, 0.0000, 0.4000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#         0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#         0.0000, 0.0000, 0.0000, 0.0100, 0.0000, 0.5800, 0.0000, 0.0000, 0.0000,
#         0.0000, 0.0000, 0.0000, 0.0000, 0.0000], grad_fn=<RoundBackward1>)
# target tensor([0.0000, 0.0000, 0.0100, 0.3800, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#         0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#         0.0000, 0.0000, 0.0000, 0.0000, 0.0100, 0.5900, 0.0000, 0.0000, 0.0000,
#         0.0000, 0.0000, 0.0000, 0.0000, 0.0000])
# Schmidt threshold:0.3
# Schmidt terms: 2
# ancilla qubits: 1
# ancilla layers: 1
# data qubits: 5
# 0: ──RY──╭○──╭○──╭○──╭○──╭○──╭●──╭●──╭●──╭●──╭●──┤
# 1: ─╭|Ψ⟩─╰RY─│───│───│───│───╰RY─│───│───│───│───┤ ╭Probs
# 2: ─├|Ψ⟩─────╰RY─│───│───│───────╰RY─│───│───│───┤ ├Probs
# 3: ─├|Ψ⟩─────────╰RY─│───│───────────╰RY─│───│───┤ ├Probs
# 4: ─├|Ψ⟩─────────────╰RY─│───────────────╰RY─│───┤ ├Probs
# 5: ─╰|Ψ⟩─────────────────╰RY─────────────────╰RY─┤ ╰Probs
# Epoch   0 | Loss: 0.4453 | Best 0.4453
# Epoch   5 | Loss: 0.4190 | Best 0.4190
# Epoch  10 | Loss: 0.3934 | Best 0.3934
# Epoch  15 | Loss: 0.3686 | Best 0.3686
# Epoch  20 | Loss: 0.3446 | Best 0.3446
# Epoch  25 | Loss: 0.3215 | Best 0.3215
# Epoch  30 | Loss: 0.2993 | Best 0.2993
# Epoch  35 | Loss: 0.2782 | Best 0.2782
# Epoch  40 | Loss: 0.2583 | Best 0.2583
# Epoch  45 | Loss: 0.2396 | Best 0.2396
# Epoch  50 | Loss: 0.2221 | Best 0.2221
# Epoch  55 | Loss: 0.2058 | Best 0.2058
# Epoch  60 | Loss: 0.1907 | Best 0.1907
# Epoch  65 | Loss: 0.1766 | Best 0.1766
# Epoch  70 | Loss: 0.1637 | Best 0.1637
# Epoch  75 | Loss: 0.1518 | Best 0.1518
# Epoch  80 | Loss: 0.1410 | Best 0.1410
# Epoch  85 | Loss: 0.1311 | Best 0.1311
# Epoch  90 | Loss: 0.1222 | Best 0.1222
# Epoch  95 | Loss: 0.1141 | Best 0.1141
# Epoch 100 | Loss: 0.1069 | Best 0.1069
# Epoch 105 | Loss: 0.1004 | Best 0.1004
# Epoch 110 | Loss: 0.0947 | Best 0.0947
# Epoch 115 | Loss: 0.0896 | Best 0.0896
# Epoch 120 | Loss: 0.0852 | Best 0.0852
# Epoch 125 | Loss: 0.0813 | Best 0.0813
# Epoch 130 | Loss: 0.0779 | Best 0.0779
# Epoch 135 | Loss: 0.0750 | Best 0.0750
# Epoch 140 | Loss: 0.0725 | Best 0.0725
# Epoch 145 | Loss: 0.0704 | Best 0.0704
# Epoch 150 | Loss: 0.0687 | Best 0.0687
# Epoch 155 | Loss: 0.0673 | Best 0.0673
# Epoch 160 | Loss: 0.0661 | Best 0.0661
# Epoch 165 | Loss: 0.0652 | Best 0.0652
# Epoch 170 | Loss: 0.0646 | Best 0.0646
# Epoch 175 | Loss: 0.0641 | Best 0.0641
# Epoch 180 | Loss: 0.0637 | Best 0.0637
# Epoch 185 | Loss: 0.0635 | Best 0.0635
# Epoch 190 | Loss: 0.0634 | Best 0.0634
# Epoch 195 | Loss: 0.0634 | Best 0.0634
#
# Optimization Complete | Best Loss: 0.0634
# found tensor([0.0000, 0.0100, 0.0000, 0.3600, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#         0.0000, 0.0000, 0.0200, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#         0.0000, 0.0000, 0.0000, 0.0100, 0.0000, 0.5600, 0.0000, 0.0000, 0.0000,
#         0.0000, 0.0000, 0.0000, 0.0000, 0.0300], grad_fn=<RoundBackward1>)
# target tensor([0.0000, 0.0000, 0.0100, 0.3700, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#         0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#         0.0000, 0.0000, 0.0000, 0.0000, 0.0100, 0.6000, 0.0000, 0.0000, 0.0000,
#         0.0000, 0.0000, 0.0000, 0.0000, 0.0000])
# Schmidt threshold:0.3
# Schmidt terms: 2
# ancilla qubits: 1
# ancilla layers: 1
# data qubits: 5
# 0: ──RY──╭○──╭○──╭○──╭○──╭○──╭●──╭●──╭●──╭●──╭●──┤
# 1: ─╭|Ψ⟩─╰RY─│───│───│───│───╰RY─│───│───│───│───┤ ╭Probs
# 2: ─├|Ψ⟩─────╰RY─│───│───│───────╰RY─│───│───│───┤ ├Probs
# 3: ─├|Ψ⟩─────────╰RY─│───│───────────╰RY─│───│───┤ ├Probs
# 4: ─├|Ψ⟩─────────────╰RY─│───────────────╰RY─│───┤ ├Probs
# 5: ─╰|Ψ⟩─────────────────╰RY─────────────────╰RY─┤ ╰Probs
# Epoch   0 | Loss: 0.6719 | Best 0.6719
# Epoch   5 | Loss: 0.6541 | Best 0.6541
# Epoch  10 | Loss: 0.6350 | Best 0.6350
# Epoch  15 | Loss: 0.6148 | Best 0.6148
# Epoch  20 | Loss: 0.5935 | Best 0.5935
# Epoch  25 | Loss: 0.5713 | Best 0.5713
# ...
# Epoch 125 | Loss: 0.0408 | Best 0.0408
# Epoch 130 | Loss: 0.0403 | Best 0.0403
# Epoch 135 | Loss: 0.0400 | Best 0.0400
# Epoch 140 | Loss: 0.0398 | Best 0.0398
# Epoch 145 | Loss: 0.0396 | Best 0.0396
# Epoch 150 | Loss: 0.0394 | Best 0.0394
# Epoch 155 | Loss: 0.0393 | Best 0.0393
# Epoch 160 | Loss: 0.0392 | Best 0.0392
# Epoch 165 | Loss: 0.0391 | Best 0.0391
# Epoch 170 | Loss: 0.0391 | Best 0.0391
# Epoch 175 | Loss: 0.0390 | Best 0.0390
# Epoch 180 | Loss: 0.0390 | Best 0.0390
# Epoch 185 | Loss: 0.0390 | Best 0.0390
# Epoch 190 | Loss: 0.0390 | Best 0.0390
# Epoch 195 | Loss: 0.0390 | Best 0.0390
#
# Optimization Complete | Best Loss: 0.0390
# found tensor([0.0000, 0.0000, 0.0300, 0.0400, 0.0200, 0.0200, 0.0000, 0.0000, 0.0000,
#         0.0000, 0.0500, 0.0500, 0.0200, 0.0200, 0.0000, 0.0000, 0.0000, 0.0000,
#         0.0300, 0.0300, 0.0100, 0.0100, 0.0000, 0.0000, 0.0000, 0.0000, 0.0300,
#         0.0300, 0.0200, 0.0300, 0.0000, 0.0000, 0.0000, 0.0000, 0.0400, 0.0400,
#         0.0300, 0.0300, 0.0000, 0.0000, 0.0000, 0.0000, 0.0300, 0.0300, 0.0200,
#         0.0200, 0.0000, 0.0000, 0.0000, 0.0000, 0.0400, 0.0300, 0.0300, 0.0200,
#         0.0000, 0.0100, 0.0000, 0.0000, 0.0400, 0.0400, 0.0300, 0.0300, 0.0000,
#         0.0000], grad_fn=<RoundBackward1>)
# target tensor([0.0000, 0.0000, 0.0300, 0.0400, 0.0300, 0.0200, 0.0000, 0.0000, 0.0000,
#         0.0000, 0.0400, 0.0400, 0.0300, 0.0200, 0.0000, 0.0000, 0.0000, 0.0000,
#         0.0300, 0.0300, 0.0300, 0.0200, 0.0000, 0.0000, 0.0000, 0.0000, 0.0300,
#         0.0300, 0.0300, 0.0200, 0.0000, 0.0000, 0.0000, 0.0000, 0.0400, 0.0400,
#         0.0300, 0.0300, 0.0000, 0.0000, 0.0000, 0.0000, 0.0400, 0.0400, 0.0300,
#         0.0300, 0.0000, 0.0000, 0.0000, 0.0000, 0.0300, 0.0300, 0.0300, 0.0200,
#         0.0000, 0.0000, 0.0000, 0.0000, 0.0300, 0.0400, 0.0300, 0.0200, 0.0000,
#         0.0000])
# Schmidt threshold:0.3
# Schmidt terms: 2
# ancilla qubits: 1
# ancilla layers: 1
# data qubits: 6
# 0: ──RY──╭○──╭○──╭○──╭○──╭○──╭○──╭●──╭●──╭●──╭●──╭●──╭●──┤
# 1: ─╭|Ψ⟩─╰RY─│───│───│───│───│───╰RY─│───│───│───│───│───┤ ╭Probs
# 2: ─├|Ψ⟩─────╰RY─│───│───│───│───────╰RY─│───│───│───│───┤ ├Probs
# 3: ─├|Ψ⟩─────────╰RY─│───│───│───────────╰RY─│───│───│───┤ ├Probs
# 4: ─├|Ψ⟩─────────────╰RY─│───│───────────────╰RY─│───│───┤ ├Probs
# 5: ─├|Ψ⟩─────────────────╰RY─│───────────────────╰RY─│───┤ ├Probs
# 6: ─╰|Ψ⟩─────────────────────╰RY─────────────────────╰RY─┤ ╰Probs
# Epoch   0 | Loss: 0.3410 | Best 0.3410
# Epoch   5 | Loss: 0.3266 | Best 0.3266
# Epoch  10 | Loss: 0.3111 | Best 0.3111
# Epoch  15 | Loss: 0.2947 | Best 0.2947
# Epoch  20 | Loss: 0.2776 | Best 0.2776
# Epoch  25 | Loss: 0.2601 | Best 0.2601
# Epoch  30 | Loss: 0.2424 | Best 0.2424
# Epoch  35 | Loss: 0.2247 | Best 0.2247
# Epoch  40 | Loss: 0.2075 | Best 0.2075
# Epoch  45 | Loss: 0.1909 | Best 0.1909
# Epoch  50 | Loss: 0.1751 | Best 0.1751
# Epoch  55 | Loss: 0.1603 | Best 0.1603
# Epoch  60 | Loss: 0.1466 | Best 0.1466
# Epoch  65 | Loss: 0.1340 | Best 0.1340
# Epoch  70 | Loss: 0.1227 | Best 0.1227
# Epoch  75 | Loss: 0.1125 | Best 0.1125
# Epoch  80 | Loss: 0.1037 | Best 0.1037
# Epoch  85 | Loss: 0.0960 | Best 0.0960
# Epoch  90 | Loss: 0.0895 | Best 0.0895
# Epoch  95 | Loss: 0.0840 | Best 0.0840
# Epoch 100 | Loss: 0.0794 | Best 0.0794
# Epoch 105 | Loss: 0.0756 | Best 0.0756
# Epoch 110 | Loss: 0.0723 | Best 0.0723
# Epoch 115 | Loss: 0.0696 | Best 0.0696
# Epoch 120 | Loss: 0.0674 | Best 0.0674
# Epoch 125 | Loss: 0.0655 | Best 0.0655
# Epoch 130 | Loss: 0.0640 | Best 0.0640
# Epoch 135 | Loss: 0.0627 | Best 0.0627
# Epoch 140 | Loss: 0.0616 | Best 0.0616
# Epoch 145 | Loss: 0.0608 | Best 0.0608
# Epoch 150 | Loss: 0.0601 | Best 0.0601
# Epoch 155 | Loss: 0.0595 | Best 0.0595
# Epoch 160 | Loss: 0.0591 | Best 0.0591
# Epoch 165 | Loss: 0.0587 | Best 0.0587
# Epoch 170 | Loss: 0.0585 | Best 0.0585
# Epoch 175 | Loss: 0.0583 | Best 0.0583
# Epoch 180 | Loss: 0.0582 | Best 0.0582
# Epoch 185 | Loss: 0.0581 | Best 0.0581
# Epoch 190 | Loss: 0.0581 | Best 0.0581
# Epoch 195 | Loss: 0.0580 | Best 0.0580
#
# Optimization Complete | Best Loss: 0.0580
# found tensor([0.0100, 0.0000, 0.0200, 0.0300, 0.0400, 0.0400, 0.0100, 0.0100, 0.0100,
#         0.0000, 0.0200, 0.0400, 0.0500, 0.0300, 0.0000, 0.0100, 0.0000, 0.0000,
#         0.0100, 0.0200, 0.0300, 0.0300, 0.0100, 0.0000, 0.0000, 0.0000, 0.0300,
#         0.0300, 0.0300, 0.0400, 0.0100, 0.0000, 0.0100, 0.0000, 0.0100, 0.0200,
#         0.0300, 0.0300, 0.0100, 0.0000, 0.0000, 0.0000, 0.0200, 0.0200, 0.0200,
#         0.0200, 0.0100, 0.0000, 0.0200, 0.0000, 0.0100, 0.0300, 0.0400, 0.0200,
#         0.0000, 0.0100, 0.0100, 0.0000, 0.0100, 0.0300, 0.0300, 0.0200, 0.0000,
#         0.0000], grad_fn=<RoundBackward1>)
# target tensor([0.0000, 0.0000, 0.0300, 0.0400, 0.0300, 0.0400, 0.0000, 0.0000, 0.0000,
#         0.0000, 0.0300, 0.0400, 0.0400, 0.0400, 0.0000, 0.0000, 0.0000, 0.0000,
#         0.0300, 0.0300, 0.0300, 0.0300, 0.0000, 0.0000, 0.0000, 0.0000, 0.0300,
#         0.0400, 0.0400, 0.0400, 0.0000, 0.0000, 0.0000, 0.0000, 0.0200, 0.0300,
#         0.0300, 0.0300, 0.0000, 0.0000, 0.0000, 0.0000, 0.0300, 0.0300, 0.0300,
#         0.0300, 0.0000, 0.0000, 0.0000, 0.0000, 0.0200, 0.0300, 0.0200, 0.0300,
#         0.0000, 0.0000, 0.0000, 0.0000, 0.0200, 0.0300, 0.0300, 0.0300, 0.0000,
#         0.0000])
# Schmidt threshold:0.3
# Schmidt terms: 2
# ancilla qubits: 1
# ancilla layers: 1
# data qubits: 6
# 0: ──RY──╭○──╭○──╭○──╭○──╭○──╭○──╭●──╭●──╭●──╭●──╭●──╭●──┤
# 1: ─╭|Ψ⟩─╰RY─│───│───│───│───│───╰RY─│───│───│───│───│───┤ ╭Probs
# 2: ─├|Ψ⟩─────╰RY─│───│───│───│───────╰RY─│───│───│───│───┤ ├Probs
# 3: ─├|Ψ⟩─────────╰RY─│───│───│───────────╰RY─│───│───│───┤ ├Probs
# 4: ─├|Ψ⟩─────────────╰RY─│───│───────────────╰RY─│───│───┤ ├Probs
# 5: ─├|Ψ⟩─────────────────╰RY─│───────────────────╰RY─│───┤ ├Probs
# 6: ─╰|Ψ⟩─────────────────────╰RY─────────────────────╰RY─┤ ╰Probs
# Epoch   0 | Loss: 0.1817 | Best 0.1817
# Epoch   5 | Loss: 0.1686 | Best 0.1686
# Epoch  10 | Loss: 0.1583 | Best 0.1583
# Epoch  15 | Loss: 0.1498 | Best 0.1498
# Epoch  20 | Loss: 0.1414 | Best 0.1414
# Epoch  25 | Loss: 0.1327 | Best 0.1327
# Epoch  30 | Loss: 0.1239 | Best 0.1239
# Epoch  35 | Loss: 0.1152 | Best 0.1152
# Epoch  40 | Loss: 0.1068 | Best 0.1068
# Epoch  45 | Loss: 0.0987 | Best 0.0987
# Epoch  50 | Loss: 0.0911 | Best 0.0911
# Epoch  55 | Loss: 0.0839 | Best 0.0839
# Epoch  60 | Loss: 0.0772 | Best 0.0772
# Epoch  65 | Loss: 0.0710 | Best 0.0710
# Epoch  70 | Loss: 0.0654 | Best 0.0654
# Epoch  75 | Loss: 0.0604 | Best 0.0604
# Epoch  80 | Loss: 0.0562 | Best 0.0562
# Epoch  85 | Loss: 0.0528 | Best 0.0528
# Epoch  90 | Loss: 0.0501 | Best 0.0501
# Epoch  95 | Loss: 0.0481 | Best 0.0481
# Epoch 100 | Loss: 0.0466 | Best 0.0466
# Epoch 105 | Loss: 0.0456 | Best 0.0456
# Epoch 110 | Loss: 0.0448 | Best 0.0448
# Epoch 115 | Loss: 0.0443 | Best 0.0443
# Epoch 120 | Loss: 0.0439 | Best 0.0439
# Epoch 125 | Loss: 0.0436 | Best 0.0436
# Epoch 130 | Loss: 0.0434 | Best 0.0434
# Epoch 135 | Loss: 0.0433 | Best 0.0433
# Epoch 140 | Loss: 0.0431 | Best 0.0431
# Epoch 145 | Loss: 0.0431 | Best 0.0431
# Epoch 150 | Loss: 0.0430 | Best 0.0430
# Epoch 155 | Loss: 0.0430 | Best 0.0430
# Epoch 160 | Loss: 0.0429 | Best 0.0429
# Epoch 165 | Loss: 0.0429 | Best 0.0429
# Epoch 170 | Loss: 0.0429 | Best 0.0429
# Epoch 175 | Loss: 0.0429 | Best 0.0429
# Epoch 180 | Loss: 0.0429 | Best 0.0429
# Epoch 185 | Loss: 0.0428 | Best 0.0428
# Epoch 190 | Loss: 0.0428 | Best 0.0428
# Epoch 195 | Loss: 0.0428 | Best 0.0428
#
# Optimization Complete | Best Loss: 0.0428
# found tensor([0.0000, 0.0000, 0.0200, 0.0300, 0.0400, 0.0300, 0.0000, 0.0000, 0.0000,
#         0.0000, 0.0300, 0.0200, 0.0400, 0.0300, 0.0000, 0.0000, 0.0000, 0.0000,
#         0.0300, 0.0200, 0.0400, 0.0300, 0.0000, 0.0000, 0.0000, 0.0000, 0.0200,
#         0.0400, 0.0600, 0.0400, 0.0000, 0.0000, 0.0000, 0.0000, 0.0200, 0.0200,
#         0.0300, 0.0300, 0.0000, 0.0000, 0.0000, 0.0000, 0.0200, 0.0200, 0.0400,
#         0.0300, 0.0000, 0.0000, 0.0000, 0.0000, 0.0200, 0.0100, 0.0300, 0.0200,
#         0.0000, 0.0000, 0.0000, 0.0000, 0.0300, 0.0300, 0.0500, 0.0400, 0.0000,
#         0.0000], grad_fn=<RoundBackward1>)
# target tensor([0.0000, 0.0000, 0.0300, 0.0200, 0.0300, 0.0200, 0.0000, 0.0000, 0.0000,
#         0.0000, 0.0400, 0.0300, 0.0400, 0.0300, 0.0000, 0.0000, 0.0000, 0.0000,
#         0.0300, 0.0300, 0.0400, 0.0300, 0.0000, 0.0000, 0.0000, 0.0000, 0.0400,
#         0.0400, 0.0500, 0.0400, 0.0000, 0.0000, 0.0000, 0.0000, 0.0200, 0.0200,
#         0.0300, 0.0200, 0.0000, 0.0000, 0.0000, 0.0000, 0.0300, 0.0300, 0.0300,
#         0.0300, 0.0000, 0.0000, 0.0000, 0.0000, 0.0300, 0.0200, 0.0300, 0.0200,
#         0.0000, 0.0000, 0.0000, 0.0000, 0.0400, 0.0300, 0.0400, 0.0300, 0.0000,
#         0.0000])
# Schmidt threshold:0.3
# Schmidt terms: 2
# ancilla qubits: 1
# ancilla layers: 1
# data qubits: 6
# 0: ──RY──╭○──╭○──╭○──╭○──╭○──╭○──╭●──╭●──╭●──╭●──╭●──╭●──┤
# 1: ─╭|Ψ⟩─╰RY─│───│───│───│───│───╰RY─│───│───│───│───│───┤ ╭Probs
# 2: ─├|Ψ⟩─────╰RY─│───│───│───│───────╰RY─│───│───│───│───┤ ├Probs
# 3: ─├|Ψ⟩─────────╰RY─│───│───│───────────╰RY─│───│───│───┤ ├Probs
# 4: ─├|Ψ⟩─────────────╰RY─│───│───────────────╰RY─│───│───┤ ├Probs
# 5: ─├|Ψ⟩─────────────────╰RY─│───────────────────╰RY─│───┤ ├Probs
# 6: ─╰|Ψ⟩─────────────────────╰RY─────────────────────╰RY─┤ ╰Probs
# Epoch   0 | Loss: 0.1793 | Best 0.1793
# Epoch   5 | Loss: 0.1658 | Best 0.1658
# Epoch  10 | Loss: 0.1533 | Best 0.1533
# Epoch  15 | Loss: 0.1418 | Best 0.1418
# Epoch  20 | Loss: 0.1315 | Best 0.1315
# Epoch  25 | Loss: 0.1220 | Best 0.1220
# Epoch  30 | Loss: 0.1135 | Best 0.1135
# Epoch  35 | Loss: 0.1059 | Best 0.1059
# Epoch  40 | Loss: 0.0992 | Best 0.0992
# Epoch  45 | Loss: 0.0933 | Best 0.0933
# Epoch  50 | Loss: 0.0881 | Best 0.0881
# Epoch  55 | Loss: 0.0835 | Best 0.0835
# Epoch  60 | Loss: 0.0794 | Best 0.0794
# Epoch  65 | Loss: 0.0757 | Best 0.0757
# Epoch  70 | Loss: 0.0724 | Best 0.0724
# Epoch  75 | Loss: 0.0694 | Best 0.0694
# Epoch  80 | Loss: 0.0667 | Best 0.0667
# Epoch  85 | Loss: 0.0643 | Best 0.0643
# Epoch  90 | Loss: 0.0622 | Best 0.0622
# Epoch  95 | Loss: 0.0604 | Best 0.0604
# Epoch 100 | Loss: 0.0590 | Best 0.0590
# Epoch 105 | Loss: 0.0578 | Best 0.0578
# Epoch 110 | Loss: 0.0569 | Best 0.0569
# Epoch 115 | Loss: 0.0562 | Best 0.0562
# Epoch 120 | Loss: 0.0556 | Best 0.0556
