# %%
import pennylane as qml
import numpy as np
from math import ceil, log2

import torch
import torch.nn as nn
from torch.utils.data import DataLoader, TensorDataset
from schmidt_decomposition import SchmidtDecomposition


# -----------------------------------------------------------------------------
# 2) Quantum circuit module - FIXED TENSOR HANDLING
# -----------------------------------------------------------------------------
class SchmidtQuantumCircuit(nn.Module):
    def __init__(
        self,
        n_qubits: int,
        n_terms: int,
        init_terms: list = None,
        n_ancilla_layers: int = 2,
    ):
        super().__init__()
        self.n_qubits = n_qubits
        self.n_terms = n_terms
        self.n_ancilla = ceil(log2(n_terms)) if n_terms > 1 else 0
        self.n_ancilla_layers = n_ancilla_layers

        # Ancilla rotation parameters
        if self.n_ancilla > 0:
            num_ancilla_params = self.n_ancilla + max(0, self.n_ancilla - 1)
            self.ancilla_params = nn.Parameter(
                torch.randn(self.n_ancilla_layers * num_ancilla_params)
            )
        else:
            self.ancilla_params = None

        # Data-qubit parameters - now with optional Schmidt initialization
        self.unitary_params = nn.ParameterList()

        # # Initialize from Schmidt decomposition if provided
        # # We did not observe any performance improvement from this!
        # # maybe the angle computations for also coefficients would make better!
        # if init_terms:

        #     for k in range(min(n_terms, len(init_terms))):
        #         term_angles = []
        #         for vector in init_terms[k]:
        #             angle = SchmidtDecomposition.vector_to_angle(vector)
        #             term_angles.append(angle)
        #         # Initialize parameter with Schmidt-derived angles
        #         self.unitary_params.append(
        #             nn.Parameter(torch.tensor(term_angles, dtype=torch.float32)))

        #     # Initialize remaining terms randomly
        #     for _ in range(n_terms - len(init_terms)):
        #         print("herrrrr")
        #         self.unitary_params.append(
        #             nn.Parameter(torch.randn(self.n_qubits)))
        # else:
        # All random initialization
        for _ in range(n_terms):
            self.unitary_params.append(nn.Parameter(torch.randn(self.n_qubits)))

        self.dev = qml.device("lightning.qubit", wires=self.n_ancilla + self.n_qubits)
        self.qnode = self.create_qnode()

    def create_qnode(self):
        @qml.qnode(self.dev, interface="torch")
        def circuit(features):
            # Ancilla preparation
            if self.n_ancilla > 0:
                p = 0
                for l in range(self.n_ancilla_layers):
                    for i in range(self.n_ancilla):
                        qml.RY(self.ancilla_params[p], wires=i)
                        p += 1
                    for i in range(self.n_ancilla - 1):
                        qml.CRY(self.ancilla_params[p], wires=[i, i + 1])
                        p += 1

            # Embed input data
            data_wires = list(range(self.n_ancilla, self.n_ancilla + self.n_qubits))
            qml.AmplitudeEmbedding(features=features, wires=data_wires, normalize=True)

            # Apply parameterized unitaries
            ctrl_qubits = list(range(self.n_ancilla))
            if self.n_ancilla == 0:
                for q in range(self.n_qubits):
                    qml.RY(self.unitary_params[0][q], wires=q + self.n_ancilla)
            else:
                for k in range(self.n_terms):
                    ctrl_bin_values = bin(k)[2:].zfill(self.n_ancilla)
                    ctrl_int_values = [int(a) for a in list(ctrl_bin_values)]
                    for q in range(self.n_qubits):
                        qml.ctrl(qml.RY, ctrl_qubits, control_values=ctrl_int_values)(
                            self.unitary_params[k][q], wires=q + self.n_ancilla
                        )

            return [qml.expval(qml.PauliZ(w)) for w in data_wires]

        return circuit

    def forward(self, x: torch.Tensor):
        # x: [batch, features]
        # Process each sample individually
        results = []
        for sample in x:
            results.append(torch.Tensor(self.qnode(sample)).float())
        return torch.stack(results)


# -----------------------------------------------------------------------------
# 3) Hybrid classifier
# -----------------------------------------------------------------------------
class HybridModel(nn.Module):
    def __init__(
        self,
        n_qubits: int,
        data_mean: np.ndarray,
        output_dim: int = 1,
        schmidt_threshold: float = 0.1,
        hidden_dims=[64, 32],
        dropout_prob=0.25,
        min_terms=1 #min schmidt terms, min ancilla
    ):
        super().__init__()
        # Schmidt decomposition on the mean
        sd = SchmidtDecomposition(threshold=schmidt_threshold)
        terms, _ = sd.flatten_decomposition(data_mean)
        n_terms = len(terms)
        if n_terms == 1:
            n_terms = min_terms
        self.qc = SchmidtQuantumCircuit(n_qubits, n_terms, terms)
        total_wires = n_qubits + self.qc.n_ancilla
        print(
            f"number of schmidt terms: {n_terms},"
            f"number of ancilla qubits:{self.qc.n_ancilla}"
        )

        # classical head takes exactly n_qubits inputs
        layers = []
        input_dim = n_qubits
        for h in hidden_dims:
            layers += [
                nn.Linear(input_dim, h),
                nn.BatchNorm1d(h),
                nn.ReLU(),
                nn.Dropout(dropout_prob),
            ]
            input_dim = h

        # final classifier
        layers.append(nn.Linear(input_dim, output_dim))
        self.classical_net = nn.Sequential(*layers)

    def forward(self, x: torch.Tensor):
        # x: [batch, features]
        q_out = self.qc(x)
        return self.classical_net(q_out)


# -----------------------------------------------------------------------------
# K-Fold cross-validation driver
# -----------------------------------------------------------------------------
from sklearn.model_selection import train_test_split
from sklearn.model_selection import StratifiedKFold, train_test_split


def cross_validate(
    X,
    y,
    n_qubits,
    n_classes,
    schmidt_threshold=0.1,
    hidden_dims=[64,32],
    max_terms=4, #not used
    min_terms=1,
    epochs=50,
    lr=0.05,
    batch_size=32,
    k_folds=5,
    val_frac=0.2,
    dataset_name="",
    seed=42,
):
    # reproducibility & device
    torch.manual_seed(seed)
    np.random.seed(seed)
    device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

    skf = StratifiedKFold(n_splits=k_folds, shuffle=True, random_state=seed)
    fold_accuracies = []
    losses = {}
    for fold, (train_idx, test_idx) in enumerate(skf.split(X, y), 1):
        print(f"\n=== Dataset={dataset_name} | Fold {fold}/{k_folds} ===")

        # Split out test fold
        X_train_full, y_train_full = X[train_idx], y[train_idx]
        X_test, y_test = X[test_idx], y[test_idx]

        # Further carve out a validation set from the training folds
        X_train, X_val, y_train, y_val = train_test_split(
            X_train_full,
            y_train_full,
            test_size=val_frac,
            random_state=seed+fold,
            stratify=y_train_full,
        )

        # DataLoaders
        train_loader = DataLoader(
            TensorDataset(
                torch.tensor(X_train, dtype=torch.float64),
                torch.tensor(y_train, dtype=torch.long),
            ),
            batch_size=batch_size,
            shuffle=True,
        )
        val_loader = DataLoader(
            TensorDataset(
                torch.tensor(X_val, dtype=torch.float64),
                torch.tensor(y_val, dtype=torch.long),
            ),
            batch_size=batch_size,
        )
        test_loader = DataLoader(
            TensorDataset(
                torch.tensor(X_test, dtype=torch.float64),
                torch.tensor(y_test, dtype=torch.long),
            ),
            batch_size=batch_size,
        )

        # Precompute mean vector for Schmidt decomposition
        mean_vec = X_train.mean(axis=0)
        mean_vec /= np.linalg.norm(mean_vec)
        
        # Initialize model, optimizer, scheduler, loss
        model = HybridModel(
            n_qubits,
            mean_vec,
            output_dim=n_classes,
            schmidt_threshold=schmidt_threshold,
            hidden_dims=hidden_dims,
            min_terms=min_terms,
        )
        opt = torch.optim.AdamW(model.parameters(), lr=lr, weight_decay=1e-4)
        sched = torch.optim.lr_scheduler.CosineAnnealingLR(opt, T_max=epochs)
        loss_fn = nn.CrossEntropyLoss()
        print(f"Using {device} for training")
        print(f"Model: {model}")
        print(
            f"Number of parameters: {sum(p.numel() for p in model.parameters() if p.requires_grad)}"
        )
        print(f"Optimizer: {opt}")
        print(f"Loss Function: {loss_fn}")
        best_val_acc = 0.0
        best_state = None
        losses[fold] = []
        # ----- Training Loop -----
        for ep in range(1, epochs + 1):
            model.train()
            running_loss = 0.0
            correct, total = 0, 0

            for xb, yb in train_loader:
                opt.zero_grad()
                preds = model(xb)
 
                loss = loss_fn(preds, yb)
                loss.backward()
                opt.step()

                running_loss += loss.item() * xb.size(0)
                correct += (preds.argmax(1) == yb).sum().item()
                total += xb.size(0)

            sched.step()
            train_acc = correct / total

            # ----- Validation -----
            model.eval()
            v_corr, v_tot = 0, 0
            with torch.no_grad():
                for xb, yb in val_loader:
                    preds = model(xb)
                    v_corr += (preds.argmax(1) == yb).sum().item()
                    v_tot += xb.size(0)
            val_acc = v_corr / v_tot

            if val_acc > best_val_acc:
                best_val_acc = val_acc
                best_state = model.state_dict()

            if ep % 10 == 0 or ep == 1:
                lr_val = sched.get_last_lr()[0]
                print(
                    f" Ep{ep:2d}  loss={(running_loss/total):.4f}  "
                    f"train_acc={train_acc:.3f}  val_acc={val_acc:.3f}  lr={lr_val:.6f}"
                )
            losses[fold].append([(running_loss / total), train_acc, val_acc])
        # ----- Test Evaluation -----
        model.load_state_dict(best_state)
        model.eval()
        t_corr, t_tot = 0, 0
        with torch.no_grad():
            for xb, yb in test_loader:
                preds = model(xb)
                t_corr += (preds.argmax(1) == yb).sum().item()
                t_tot += xb.size(0)
        test_acc = t_corr / t_tot

        print(f" >>> Fold {fold} Test Accuracy: {test_acc:.3f}")
        fold_accuracies.append(test_acc)

    mean_acc = np.mean(fold_accuracies)
    std_acc = np.std(fold_accuracies)
    print(f"\n>>> {dataset_name} CV Results: mean={mean_acc:.3f}, std={std_acc:.3f}\n")
    return fold_accuracies, losses


# if __name__ == "__main__":
from data_loaders import load_dataset

datasets = [
    "iris",
    "wine",
    "breast_cancer",
    "ionosphere",
    "covtype",
    "digits",
]
all_results = {}
all_losses = {}
for ds in datasets:
    X, y, n_qubits, n_classes = load_dataset(ds)

    print(f"\n=== Dataset={ds}")
    accs, losses = cross_validate(
        X,
        y,
        n_qubits,
        n_classes,
        hidden_dims=[64,32],
        schmidt_threshold=0.3,
        min_terms=1,
        epochs=200,
        lr=0.05,
        batch_size=32,
        k_folds=5,
        val_frac=0.2,
        seed=42,
        dataset_name=ds,
    )
    all_results[ds] = accs
    all_losses[ds] = losses
    print("=" * 40)
    print("=" * 40)
# Summary
print("=== Final Summary ===")
for ds, accs in all_results.items():
    print(
        f"{ds:15} folds={len(accs)}  mean_acc={np.mean(accs):.3f}  std={np.std(accs):.3f}"
    )
# Out:
# === Dataset=iris
#
# === Dataset=iris | Fold 1/5 ===
# number of schmidt terms: 1,number of ancilla qubits:0
# Using cpu for training
# Model: HybridModel(
#   (qc): SchmidtQuantumCircuit(
#     (unitary_params): ParameterList(  (0): Parameter containing: [torch.float32 of size 2])
#   )
#   (classical_net): Sequential(
#     (0): Linear(in_features=2, out_features=64, bias=True)
#     (1): BatchNorm1d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): ReLU()
#     (3): Dropout(p=0.25, inplace=False)
#     (4): Linear(in_features=64, out_features=32, bias=True)
#     (5): BatchNorm1d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (6): ReLU()
#     (7): Dropout(p=0.25, inplace=False)
#     (8): Linear(in_features=32, out_features=3, bias=True)
#   )
# )
# Number of parameters: 2565
# Optimizer: AdamW (
# Parameter Group 0
#     amsgrad: False
#     betas: (0.9, 0.999)
#     capturable: False
#     decoupled_weight_decay: True
#     differentiable: False
#     eps: 1e-08
#     foreach: None
#     fused: None
#     initial_lr: 0.05
#     lr: 0.05
#     maximize: False
#     weight_decay: 0.0001
# )
# Loss Function: CrossEntropyLoss()
#  Ep 1  loss=0.8550  train_acc=0.583  val_acc=0.792  lr=0.049997
#  Ep10  loss=0.2889  train_acc=0.875  val_acc=0.875  lr=0.049692
#  Ep20  loss=0.1839  train_acc=0.948  val_acc=0.917  lr=0.048776
#  Ep30  loss=0.1403  train_acc=0.948  val_acc=0.917  lr=0.047275
#  Ep40  loss=0.1398  train_acc=0.938  val_acc=0.875  lr=0.045225
#  Ep50  loss=0.1591  train_acc=0.927  val_acc=0.917  lr=0.042678
#  Ep60  loss=0.1935  train_acc=0.927  val_acc=0.917  lr=0.039695
#  Ep70  loss=0.1390  train_acc=0.917  val_acc=0.917  lr=0.036350
#  Ep80  loss=0.1207  train_acc=0.948  val_acc=0.917  lr=0.032725
#  Ep90  loss=0.1215  train_acc=0.948  val_acc=0.917  lr=0.028911
#  Ep100  loss=0.1314  train_acc=0.969  val_acc=0.917  lr=0.025000
#  Ep110  loss=0.1390  train_acc=0.938  val_acc=0.917  lr=0.021089
#  Ep120  loss=0.1617  train_acc=0.938  val_acc=0.875  lr=0.017275
#  Ep130  loss=0.2015  train_acc=0.917  val_acc=0.917  lr=0.013650
#  Ep140  loss=0.1108  train_acc=0.948  val_acc=0.875  lr=0.010305
#  Ep150  loss=0.0934  train_acc=0.969  val_acc=0.875  lr=0.007322
#  Ep160  loss=0.0937  train_acc=0.990  val_acc=0.917  lr=0.004775
#  Ep170  loss=0.1174  train_acc=0.938  val_acc=0.875  lr=0.002725
#  Ep180  loss=0.1525  train_acc=0.917  val_acc=0.875  lr=0.001224
#  Ep190  loss=0.0933  train_acc=0.958  val_acc=0.875  lr=0.000308
#  Ep200  loss=0.2155  train_acc=0.906  val_acc=0.875  lr=0.000000
#  >>> Fold 1 Test Accuracy: 1.000
#
# === Dataset=iris | Fold 2/5 ===
# number of schmidt terms: 1,number of ancilla qubits:0
# Using cpu for training
# Model: HybridModel(
#   (qc): SchmidtQuantumCircuit(
#     (unitary_params): ParameterList(  (0): Parameter containing: [torch.float32 of size 2])
#   )
#   (classical_net): Sequential(
#     (0): Linear(in_features=2, out_features=64, bias=True)
#     (1): BatchNorm1d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): ReLU()
#     (3): Dropout(p=0.25, inplace=False)
#     (4): Linear(in_features=64, out_features=32, bias=True)
#     (5): BatchNorm1d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (6): ReLU()
#     (7): Dropout(p=0.25, inplace=False)
#     (8): Linear(in_features=32, out_features=3, bias=True)
#   )
# )
# Number of parameters: 2565
# Optimizer: AdamW (
# Parameter Group 0
#     amsgrad: False
#     betas: (0.9, 0.999)
#     capturable: False
#     decoupled_weight_decay: True
#     differentiable: False
#     eps: 1e-08
#     foreach: None
#     fused: None
#     initial_lr: 0.05
#     lr: 0.05
#     maximize: False
#     weight_decay: 0.0001
# )
# Loss Function: CrossEntropyLoss()
#  Ep 1  loss=0.8388  train_acc=0.594  val_acc=0.333  lr=0.049997
#  Ep10  loss=0.2170  train_acc=0.917  val_acc=0.875  lr=0.049692
#  Ep20  loss=0.2218  train_acc=0.896  val_acc=0.667  lr=0.048776
#  Ep30  loss=0.2914  train_acc=0.865  val_acc=0.708  lr=0.047275
#  Ep40  loss=0.2469  train_acc=0.906  val_acc=0.667  lr=0.045225
#  Ep50  loss=0.3153  train_acc=0.844  val_acc=1.000  lr=0.042678
#  Ep60  loss=0.1889  train_acc=0.917  val_acc=0.667  lr=0.039695
#  Ep70  loss=0.1869  train_acc=0.938  val_acc=1.000  lr=0.036350
#  Ep80  loss=0.1104  train_acc=0.958  val_acc=0.708  lr=0.032725
#  Ep90  loss=0.1624  train_acc=0.938  val_acc=0.708  lr=0.028911
#  Ep100  loss=0.1810  train_acc=0.906  val_acc=0.917  lr=0.025000
#  Ep110  loss=0.1815  train_acc=0.948  val_acc=0.917  lr=0.021089
#  Ep120  loss=0.2154  train_acc=0.917  val_acc=0.958  lr=0.017275
#  Ep130  loss=0.1268  train_acc=0.938  val_acc=1.000  lr=0.013650
#  Ep140  loss=0.1892  train_acc=0.885  val_acc=1.000  lr=0.010305
#  Ep150  loss=0.1629  train_acc=0.927  val_acc=1.000  lr=0.007322
#  Ep160  loss=0.1819  train_acc=0.917  val_acc=1.000  lr=0.004775
#  Ep170  loss=0.1621  train_acc=0.958  val_acc=1.000  lr=0.002725
#  Ep180  loss=0.1452  train_acc=0.958  val_acc=1.000  lr=0.001224
#  Ep190  loss=0.1254  train_acc=0.948  val_acc=1.000  lr=0.000308
#  Ep200  loss=0.1347  train_acc=0.969  val_acc=1.000  lr=0.000000
#  >>> Fold 2 Test Accuracy: 1.000
#
# === Dataset=iris | Fold 3/5 ===
# number of schmidt terms: 1,number of ancilla qubits:0
# Using cpu for training
# Model: HybridModel(
#   (qc): SchmidtQuantumCircuit(
#     (unitary_params): ParameterList(  (0): Parameter containing: [torch.float32 of size 2])
#   )
#   (classical_net): Sequential(
#     (0): Linear(in_features=2, out_features=64, bias=True)
#     (1): BatchNorm1d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): ReLU()
#     (3): Dropout(p=0.25, inplace=False)
#     (4): Linear(in_features=64, out_features=32, bias=True)
#     (5): BatchNorm1d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (6): ReLU()
#     (7): Dropout(p=0.25, inplace=False)
#     (8): Linear(in_features=32, out_features=3, bias=True)
#   )
# )
# Number of parameters: 2565
# Optimizer: AdamW (
# Parameter Group 0
#     amsgrad: False
#     betas: (0.9, 0.999)
#     capturable: False
#     decoupled_weight_decay: True
#     differentiable: False
#     eps: 1e-08
#     foreach: None
#     fused: None
#     initial_lr: 0.05
#     lr: 0.05
#     maximize: False
#     weight_decay: 0.0001
# )
# Loss Function: CrossEntropyLoss()
#  Ep 1  loss=0.9723  train_acc=0.521  val_acc=0.333  lr=0.049997
#  Ep10  loss=0.3309  train_acc=0.865  val_acc=0.875  lr=0.049692
#  Ep20  loss=0.2376  train_acc=0.875  val_acc=0.667  lr=0.048776
#  Ep30  loss=0.2819  train_acc=0.896  val_acc=0.667  lr=0.047275
#  Ep40  loss=0.1452  train_acc=0.969  val_acc=0.708  lr=0.045225
#  Ep50  loss=0.1818  train_acc=0.938  val_acc=0.833  lr=0.042678
#  Ep60  loss=0.1165  train_acc=0.969  val_acc=0.708  lr=0.039695
#  Ep70  loss=0.1569  train_acc=0.938  val_acc=0.792  lr=0.036350
#  Ep80  loss=0.1012  train_acc=0.969  val_acc=1.000  lr=0.032725
#  Ep90  loss=0.0874  train_acc=0.969  val_acc=0.792  lr=0.028911
#  Ep100  loss=0.2044  train_acc=0.927  val_acc=0.792  lr=0.025000
#  Ep110  loss=0.1714  train_acc=0.948  val_acc=1.000  lr=0.021089
#  Ep120  loss=0.0627  train_acc=0.979  val_acc=0.958  lr=0.017275
#  Ep130  loss=0.0997  train_acc=0.969  val_acc=1.000  lr=0.013650
#  Ep140  loss=0.0777  train_acc=0.990  val_acc=0.792  lr=0.010305
#  Ep150  loss=0.1024  train_acc=0.938  val_acc=1.000  lr=0.007322
#  Ep160  loss=0.0957  train_acc=0.958  val_acc=0.958  lr=0.004775
#  Ep170  loss=0.0857  train_acc=0.969  val_acc=1.000  lr=0.002725
#  Ep180  loss=0.2051  train_acc=0.938  val_acc=0.958  lr=0.001224
#  Ep190  loss=0.0848  train_acc=0.948  val_acc=1.000  lr=0.000308
#  Ep200  loss=0.0835  train_acc=0.958  val_acc=0.958  lr=0.000000
#  >>> Fold 3 Test Accuracy: 0.867
#
# === Dataset=iris | Fold 4/5 ===
# number of schmidt terms: 1,number of ancilla qubits:0
# Using cpu for training
# Model: HybridModel(
#   (qc): SchmidtQuantumCircuit(
#     (unitary_params): ParameterList(  (0): Parameter containing: [torch.float32 of size 2])
#   )
#   (classical_net): Sequential(
#     (0): Linear(in_features=2, out_features=64, bias=True)
#     (1): BatchNorm1d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): ReLU()
#     (3): Dropout(p=0.25, inplace=False)
#     (4): Linear(in_features=64, out_features=32, bias=True)
#     (5): BatchNorm1d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (6): ReLU()
#     (7): Dropout(p=0.25, inplace=False)
#     (8): Linear(in_features=32, out_features=3, bias=True)
#   )
# )
# Number of parameters: 2565
# Optimizer: AdamW (
# Parameter Group 0
#     amsgrad: False
#     betas: (0.9, 0.999)
#     capturable: False
#     decoupled_weight_decay: True
#     differentiable: False
#     eps: 1e-08
#     foreach: None
#     fused: None
#     initial_lr: 0.05
#     lr: 0.05
#     maximize: False
#     weight_decay: 0.0001
# )
# Loss Function: CrossEntropyLoss()
#  Ep 1  loss=0.6989  train_acc=0.698  val_acc=0.333  lr=0.049997
#  Ep10  loss=0.1146  train_acc=0.958  val_acc=0.875  lr=0.049692
#  Ep20  loss=0.0932  train_acc=0.969  val_acc=0.917  lr=0.048776
#  Ep30  loss=0.1144  train_acc=0.958  val_acc=0.833  lr=0.047275
#  Ep40  loss=0.1221  train_acc=0.948  val_acc=0.833  lr=0.045225
#  Ep50  loss=0.1114  train_acc=0.958  val_acc=0.750  lr=0.042678
#  Ep60  loss=0.1489  train_acc=0.927  val_acc=0.833  lr=0.039695
#  Ep70  loss=0.1811  train_acc=0.938  val_acc=1.000  lr=0.036350
#  Ep80  loss=0.1241  train_acc=0.938  val_acc=0.833  lr=0.032725
#  Ep90  loss=0.0943  train_acc=0.979  val_acc=0.958  lr=0.028911
#  Ep100  loss=0.1238  train_acc=0.958  val_acc=0.917  lr=0.025000
#  Ep110  loss=0.1134  train_acc=0.969  val_acc=0.917  lr=0.021089
#  Ep120  loss=0.1207  train_acc=0.958  val_acc=0.958  lr=0.017275
#  Ep130  loss=0.1262  train_acc=0.958  val_acc=1.000  lr=0.013650
#  Ep140  loss=0.1044  train_acc=0.958  val_acc=0.958  lr=0.010305
#  Ep150  loss=0.1319  train_acc=0.948  val_acc=0.958  lr=0.007322
#  Ep160  loss=0.1120  train_acc=0.958  val_acc=0.958  lr=0.004775
#  Ep170  loss=0.1009  train_acc=0.979  val_acc=0.958  lr=0.002725
#  Ep180  loss=0.0922  train_acc=0.969  val_acc=0.958  lr=0.001224
#  Ep190  loss=0.1148  train_acc=0.979  val_acc=0.958  lr=0.000308
#  Ep200  loss=0.1048  train_acc=0.979  val_acc=0.958  lr=0.000000
#  >>> Fold 4 Test Accuracy: 0.967
#
# === Dataset=iris | Fold 5/5 ===
# number of schmidt terms: 1,number of ancilla qubits:0
# Using cpu for training
# Model: HybridModel(
#   (qc): SchmidtQuantumCircuit(
#     (unitary_params): ParameterList(  (0): Parameter containing: [torch.float32 of size 2])
#   )
#   (classical_net): Sequential(
#     (0): Linear(in_features=2, out_features=64, bias=True)
#     (1): BatchNorm1d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): ReLU()
#     (3): Dropout(p=0.25, inplace=False)
#     (4): Linear(in_features=64, out_features=32, bias=True)
#     (5): BatchNorm1d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (6): ReLU()
#     (7): Dropout(p=0.25, inplace=False)
#     (8): Linear(in_features=32, out_features=3, bias=True)
#   )
# )
# Number of parameters: 2565
# Optimizer: AdamW (
# Parameter Group 0
#     amsgrad: False
#     betas: (0.9, 0.999)
#     capturable: False
#     decoupled_weight_decay: True
#     differentiable: False
#     eps: 1e-08
#     foreach: None
#     fused: None
#     initial_lr: 0.05
#     lr: 0.05
#     maximize: False
#     weight_decay: 0.0001
# )
# Loss Function: CrossEntropyLoss()
#  Ep 1  loss=0.8134  train_acc=0.677  val_acc=0.417  lr=0.049997
#  Ep10  loss=0.1791  train_acc=0.917  val_acc=0.708  lr=0.049692
#  Ep20  loss=0.2575  train_acc=0.917  val_acc=0.667  lr=0.048776
#  Ep30  loss=0.2406  train_acc=0.906  val_acc=0.708  lr=0.047275
#  Ep40  loss=0.1361  train_acc=0.938  val_acc=0.417  lr=0.045225
#  Ep50  loss=0.2147  train_acc=0.917  val_acc=0.667  lr=0.042678
#  Ep60  loss=0.1571  train_acc=0.917  val_acc=0.917  lr=0.039695
#  Ep70  loss=0.1628  train_acc=0.958  val_acc=0.958  lr=0.036350
#  Ep80  loss=0.1194  train_acc=0.958  val_acc=1.000  lr=0.032725
#  Ep90  loss=0.1634  train_acc=0.938  val_acc=0.875  lr=0.028911
#  Ep100  loss=0.1728  train_acc=0.938  val_acc=0.917  lr=0.025000
#  Ep110  loss=0.1446  train_acc=0.927  val_acc=0.958  lr=0.021089
#  Ep120  loss=0.1601  train_acc=0.938  val_acc=0.917  lr=0.017275
#  Ep130  loss=0.1073  train_acc=0.938  val_acc=0.917  lr=0.013650
#  Ep140  loss=0.1217  train_acc=0.927  val_acc=0.958  lr=0.010305
#  Ep150  loss=0.2226  train_acc=0.917  val_acc=0.958  lr=0.007322
#  Ep160  loss=0.2177  train_acc=0.927  val_acc=0.958  lr=0.004775
#  Ep170  loss=0.1212  train_acc=0.958  val_acc=0.958  lr=0.002725
#  Ep180  loss=0.1314  train_acc=0.927  val_acc=0.958  lr=0.001224
#  Ep190  loss=0.1604  train_acc=0.917  val_acc=0.958  lr=0.000308
#  Ep200  loss=0.1251  train_acc=0.958  val_acc=0.958  lr=0.000000
#  >>> Fold 5 Test Accuracy: 0.967
#
# >>> iris CV Results: mean=0.960, std=0.049
#
# ========================================
# ========================================
# dimension 13, padding with zeros for 16
#
# === Dataset=wine
#
# === Dataset=wine | Fold 1/5 ===
# number of schmidt terms: 1,number of ancilla qubits:0
# Using cpu for training
# Model: HybridModel(
#   (qc): SchmidtQuantumCircuit(
#     (unitary_params): ParameterList(  (0): Parameter containing: [torch.float32 of size 4])
#   )
#   (classical_net): Sequential(
#     (0): Linear(in_features=4, out_features=64, bias=True)
#     (1): BatchNorm1d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): ReLU()
#     (3): Dropout(p=0.25, inplace=False)
#     (4): Linear(in_features=64, out_features=32, bias=True)
#     (5): BatchNorm1d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (6): ReLU()
#     (7): Dropout(p=0.25, inplace=False)
#     (8): Linear(in_features=32, out_features=3, bias=True)
#   )
# )
# Number of parameters: 2695
# Optimizer: AdamW (
# Parameter Group 0
#     amsgrad: False
#     betas: (0.9, 0.999)
#     capturable: False
#     decoupled_weight_decay: True
#     differentiable: False
#     eps: 1e-08
#     foreach: None
#     fused: None
#     initial_lr: 0.05
#     lr: 0.05
#     maximize: False
#     weight_decay: 0.0001
# )
# Loss Function: CrossEntropyLoss()
#  Ep 1  loss=1.0009  train_acc=0.478  val_acc=0.310  lr=0.049997
#  Ep10  loss=0.5295  train_acc=0.743  val_acc=0.310  lr=0.049692
#  Ep20  loss=0.4406  train_acc=0.841  val_acc=0.414  lr=0.048776
#  Ep30  loss=0.4552  train_acc=0.805  val_acc=0.414  lr=0.047275
#  Ep40  loss=0.4300  train_acc=0.788  val_acc=0.414  lr=0.045225
#  Ep50  loss=0.2957  train_acc=0.858  val_acc=0.414  lr=0.042678
#  Ep60  loss=0.2954  train_acc=0.885  val_acc=0.414  lr=0.039695
#  Ep70  loss=0.3393  train_acc=0.814  val_acc=0.414  lr=0.036350
#  Ep80  loss=0.3752  train_acc=0.814  val_acc=0.414  lr=0.032725
#  Ep90  loss=0.4018  train_acc=0.823  val_acc=0.414  lr=0.028911
#  Ep100  loss=0.2377  train_acc=0.885  val_acc=0.414  lr=0.025000
#  Ep110  loss=0.2536  train_acc=0.894  val_acc=0.414  lr=0.021089
#  Ep120  loss=0.3077  train_acc=0.876  val_acc=0.414  lr=0.017275
#  Ep130  loss=0.2613  train_acc=0.876  val_acc=0.414  lr=0.013650
#  Ep140  loss=0.2362  train_acc=0.920  val_acc=0.414  lr=0.010305
#  Ep150  loss=0.1689  train_acc=0.938  val_acc=0.414  lr=0.007322
#  Ep160  loss=0.2759  train_acc=0.903  val_acc=0.414  lr=0.004775
#  Ep170  loss=0.2784  train_acc=0.894  val_acc=0.414  lr=0.002725
#  Ep180  loss=0.3844  train_acc=0.832  val_acc=0.483  lr=0.001224
#  Ep190  loss=0.2439  train_acc=0.885  val_acc=0.793  lr=0.000308
#  Ep200  loss=0.2306  train_acc=0.938  val_acc=0.862  lr=0.000000
#  >>> Fold 1 Test Accuracy: 0.917
#
# === Dataset=wine | Fold 2/5 ===
# number of schmidt terms: 1,number of ancilla qubits:0
# Using cpu for training
# Model: HybridModel(
#   (qc): SchmidtQuantumCircuit(
#     (unitary_params): ParameterList(  (0): Parameter containing: [torch.float32 of size 4])
#   )
#   (classical_net): Sequential(
#     (0): Linear(in_features=4, out_features=64, bias=True)
#     (1): BatchNorm1d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): ReLU()
#     (3): Dropout(p=0.25, inplace=False)
#     (4): Linear(in_features=64, out_features=32, bias=True)
#     (5): BatchNorm1d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (6): ReLU()
#     (7): Dropout(p=0.25, inplace=False)
#     (8): Linear(in_features=32, out_features=3, bias=True)
#   )
# )
# Number of parameters: 2695
# Optimizer: AdamW (
# Parameter Group 0
#     amsgrad: False
#     betas: (0.9, 0.999)
#     capturable: False
#     decoupled_weight_decay: True
#     differentiable: False
#     eps: 1e-08
#     foreach: None
#     fused: None
#     initial_lr: 0.05
#     lr: 0.05
#     maximize: False
#     weight_decay: 0.0001
# )
# Loss Function: CrossEntropyLoss()
#  Ep 1  loss=0.9253  train_acc=0.522  val_acc=0.310  lr=0.049997
#  Ep10  loss=0.6642  train_acc=0.681  val_acc=0.310  lr=0.049692
#  Ep20  loss=0.7028  train_acc=0.646  val_acc=0.310  lr=0.048776
#  Ep30  loss=0.6835  train_acc=0.708  val_acc=0.724  lr=0.047275
#  Ep40  loss=0.6029  train_acc=0.664  val_acc=0.379  lr=0.045225
#  Ep50  loss=0.6576  train_acc=0.690  val_acc=0.310  lr=0.042678
#  Ep60  loss=0.5913  train_acc=0.690  val_acc=0.586  lr=0.039695
#  Ep70  loss=0.5998  train_acc=0.726  val_acc=0.310  lr=0.036350
#  Ep80  loss=0.5553  train_acc=0.681  val_acc=0.517  lr=0.032725
#  Ep90  loss=0.5422  train_acc=0.735  val_acc=0.414  lr=0.028911
#  Ep100  loss=0.5612  train_acc=0.752  val_acc=0.655  lr=0.025000
#  Ep110  loss=0.5137  train_acc=0.770  val_acc=0.414  lr=0.021089
#  Ep120  loss=0.5141  train_acc=0.752  val_acc=0.483  lr=0.017275
#  Ep130  loss=0.4146  train_acc=0.788  val_acc=0.655  lr=0.013650
#  Ep140  loss=0.4884  train_acc=0.805  val_acc=0.517  lr=0.010305
#  Ep150  loss=0.4370  train_acc=0.823  val_acc=0.655  lr=0.007322
#  Ep160  loss=0.3656  train_acc=0.823  val_acc=0.655  lr=0.004775
#  Ep170  loss=0.3663  train_acc=0.858  val_acc=0.690  lr=0.002725
#  Ep180  loss=0.3151  train_acc=0.858  val_acc=0.655  lr=0.001224
#  Ep190  loss=0.2899  train_acc=0.867  val_acc=0.828  lr=0.000308
#  Ep200  loss=0.3034  train_acc=0.841  val_acc=0.931  lr=0.000000
#  >>> Fold 2 Test Accuracy: 0.917
#
# === Dataset=wine | Fold 3/5 ===
# number of schmidt terms: 1,number of ancilla qubits:0
# Using cpu for training
# Model: HybridModel(
#   (qc): SchmidtQuantumCircuit(
#     (unitary_params): ParameterList(  (0): Parameter containing: [torch.float32 of size 4])
#   )
#   (classical_net): Sequential(
#     (0): Linear(in_features=4, out_features=64, bias=True)
#     (1): BatchNorm1d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): ReLU()
#     (3): Dropout(p=0.25, inplace=False)
#     (4): Linear(in_features=64, out_features=32, bias=True)
#     (5): BatchNorm1d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (6): ReLU()
#     (7): Dropout(p=0.25, inplace=False)
#     (8): Linear(in_features=32, out_features=3, bias=True)
#   )
# )
# Number of parameters: 2695
# Optimizer: AdamW (
# Parameter Group 0
#     amsgrad: False
#     betas: (0.9, 0.999)
#     capturable: False
#     decoupled_weight_decay: True
#     differentiable: False
#     eps: 1e-08
#     foreach: None
#     fused: None
#     initial_lr: 0.05
#     lr: 0.05
#     maximize: False
#     weight_decay: 0.0001
# )
# Loss Function: CrossEntropyLoss()
#  Ep 1  loss=0.8329  train_acc=0.575  val_acc=0.310  lr=0.049997
#  Ep10  loss=0.4470  train_acc=0.752  val_acc=0.310  lr=0.049692
#  Ep20  loss=0.4209  train_acc=0.814  val_acc=0.310  lr=0.048776
#  Ep30  loss=0.6587  train_acc=0.770  val_acc=0.310  lr=0.047275
#  Ep40  loss=0.4109  train_acc=0.850  val_acc=0.517  lr=0.045225
#  Ep50  loss=0.3902  train_acc=0.841  val_acc=0.310  lr=0.042678
#  Ep60  loss=0.3474  train_acc=0.858  val_acc=0.414  lr=0.039695
#  Ep70  loss=0.3702  train_acc=0.850  val_acc=0.448  lr=0.036350
#  Ep80  loss=0.3177  train_acc=0.867  val_acc=0.483  lr=0.032725
#  Ep90  loss=0.3309  train_acc=0.867  val_acc=0.414  lr=0.028911
#  Ep100  loss=0.2994  train_acc=0.858  val_acc=0.448  lr=0.025000
#  Ep110  loss=0.3602  train_acc=0.850  val_acc=0.552  lr=0.021089
#  Ep120  loss=0.3148  train_acc=0.876  val_acc=0.414  lr=0.017275
#  Ep130  loss=0.3499  train_acc=0.832  val_acc=0.621  lr=0.013650
#  Ep140  loss=0.2958  train_acc=0.876  val_acc=0.414  lr=0.010305
#  Ep150  loss=0.2659  train_acc=0.894  val_acc=0.414  lr=0.007322
#  Ep160  loss=0.3036  train_acc=0.894  val_acc=0.621  lr=0.004775
#  Ep170  loss=0.2591  train_acc=0.903  val_acc=0.414  lr=0.002725
#  Ep180  loss=0.3418  train_acc=0.850  val_acc=0.655  lr=0.001224
#  Ep190  loss=0.3266  train_acc=0.894  val_acc=0.759  lr=0.000308
#  Ep200  loss=0.2474  train_acc=0.867  val_acc=0.828  lr=0.000000
#  >>> Fold 3 Test Accuracy: 0.806
#
# === Dataset=wine | Fold 4/5 ===
# number of schmidt terms: 1,number of ancilla qubits:0
# Using cpu for training
# Model: HybridModel(
#   (qc): SchmidtQuantumCircuit(
#     (unitary_params): ParameterList(  (0): Parameter containing: [torch.float32 of size 4])
#   )
#   (classical_net): Sequential(
#     (0): Linear(in_features=4, out_features=64, bias=True)
#     (1): BatchNorm1d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): ReLU()
#     (3): Dropout(p=0.25, inplace=False)
#     (4): Linear(in_features=64, out_features=32, bias=True)
#     (5): BatchNorm1d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (6): ReLU()
#     (7): Dropout(p=0.25, inplace=False)
#     (8): Linear(in_features=32, out_features=3, bias=True)
#   )
# )
# Number of parameters: 2695
# Optimizer: AdamW (
# Parameter Group 0
#     amsgrad: False
#     betas: (0.9, 0.999)
#     capturable: False
#     decoupled_weight_decay: True
#     differentiable: False
#     eps: 1e-08
#     foreach: None
#     fused: None
#     initial_lr: 0.05
#     lr: 0.05
#     maximize: False
#     weight_decay: 0.0001
# )
# Loss Function: CrossEntropyLoss()
#  Ep 1  loss=0.8637  train_acc=0.553  val_acc=0.310  lr=0.049997
#  Ep10  loss=0.6393  train_acc=0.711  val_acc=0.310  lr=0.049692
#  Ep20  loss=0.5755  train_acc=0.711  val_acc=0.310  lr=0.048776
#  Ep30  loss=0.5875  train_acc=0.728  val_acc=0.414  lr=0.047275
#  Ep40  loss=0.5886  train_acc=0.719  val_acc=0.310  lr=0.045225
#  Ep50  loss=0.4256  train_acc=0.789  val_acc=0.552  lr=0.042678
#  Ep60  loss=0.5459  train_acc=0.728  val_acc=0.379  lr=0.039695
#  Ep70  loss=0.4491  train_acc=0.842  val_acc=0.345  lr=0.036350
#  Ep80  loss=0.5011  train_acc=0.781  val_acc=0.310  lr=0.032725
#  Ep90  loss=0.4310  train_acc=0.807  val_acc=0.483  lr=0.028911
#  Ep100  loss=0.4204  train_acc=0.746  val_acc=0.345  lr=0.025000
#  Ep110  loss=0.3941  train_acc=0.825  val_acc=0.345  lr=0.021089
#  Ep120  loss=0.3578  train_acc=0.868  val_acc=0.483  lr=0.017275
#  Ep130  loss=0.3857  train_acc=0.807  val_acc=0.414  lr=0.013650
#  Ep140  loss=0.3590  train_acc=0.860  val_acc=0.517  lr=0.010305
#  Ep150  loss=0.3454  train_acc=0.816  val_acc=0.414  lr=0.007322
#  Ep160  loss=0.3224  train_acc=0.877  val_acc=0.552  lr=0.004775
#  Ep170  loss=0.2913  train_acc=0.877  val_acc=0.621  lr=0.002725
#  Ep180  loss=0.3421  train_acc=0.851  val_acc=0.759  lr=0.001224
#  Ep190  loss=0.3595  train_acc=0.851  val_acc=0.793  lr=0.000308
#  Ep200  loss=0.3111  train_acc=0.868  val_acc=0.759  lr=0.000000
#  >>> Fold 4 Test Accuracy: 0.829
#
# === Dataset=wine | Fold 5/5 ===
# number of schmidt terms: 1,number of ancilla qubits:0
# Using cpu for training
# Model: HybridModel(
#   (qc): SchmidtQuantumCircuit(
#     (unitary_params): ParameterList(  (0): Parameter containing: [torch.float32 of size 4])
#   )
#   (classical_net): Sequential(
#     (0): Linear(in_features=4, out_features=64, bias=True)
#     (1): BatchNorm1d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): ReLU()
#     (3): Dropout(p=0.25, inplace=False)
#     (4): Linear(in_features=64, out_features=32, bias=True)
#     (5): BatchNorm1d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (6): ReLU()
#     (7): Dropout(p=0.25, inplace=False)
#     (8): Linear(in_features=32, out_features=3, bias=True)
#   )
# )
# Number of parameters: 2695
# Optimizer: AdamW (
# Parameter Group 0
#     amsgrad: False
#     betas: (0.9, 0.999)
#     capturable: False
#     decoupled_weight_decay: True
#     differentiable: False
#     eps: 1e-08
#     foreach: None
#     fused: None
#     initial_lr: 0.05
#     lr: 0.05
#     maximize: False
#     weight_decay: 0.0001
# )
# Loss Function: CrossEntropyLoss()
#  Ep 1  loss=0.9329  train_acc=0.491  val_acc=0.345  lr=0.049997
#  Ep10  loss=0.6222  train_acc=0.649  val_acc=0.345  lr=0.049692
#  Ep20  loss=0.6219  train_acc=0.675  val_acc=0.345  lr=0.048776
#  Ep30  loss=0.6238  train_acc=0.728  val_acc=0.345  lr=0.047275
#  Ep40  loss=0.5214  train_acc=0.684  val_acc=0.345  lr=0.045225
#  Ep50  loss=0.5794  train_acc=0.789  val_acc=0.345  lr=0.042678
#  Ep60  loss=0.5015  train_acc=0.789  val_acc=0.345  lr=0.039695
#  Ep70  loss=0.5300  train_acc=0.789  val_acc=0.345  lr=0.036350
#  Ep80  loss=0.4854  train_acc=0.789  val_acc=0.345  lr=0.032725
#  Ep90  loss=0.4141  train_acc=0.807  val_acc=0.345  lr=0.028911
#  Ep100  loss=0.4414  train_acc=0.763  val_acc=0.379  lr=0.025000
#  Ep110  loss=0.4076  train_acc=0.781  val_acc=0.379  lr=0.021089
#  Ep120  loss=0.4735  train_acc=0.746  val_acc=0.345  lr=0.017275
#  Ep130  loss=0.4025  train_acc=0.825  val_acc=0.448  lr=0.013650
#  Ep140  loss=0.3874  train_acc=0.851  val_acc=0.345  lr=0.010305
#  Ep150  loss=0.3911  train_acc=0.798  val_acc=0.690  lr=0.007322
#  Ep160  loss=0.3607  train_acc=0.842  val_acc=0.621  lr=0.004775
#  Ep170  loss=0.3934  train_acc=0.781  val_acc=0.690  lr=0.002725
#  Ep180  loss=0.3910  train_acc=0.833  val_acc=0.862  lr=0.001224
#  Ep190  loss=0.3539  train_acc=0.833  val_acc=0.862  lr=0.000308
#  Ep200  loss=0.4405  train_acc=0.807  val_acc=0.862  lr=0.000000
#  >>> Fold 5 Test Accuracy: 0.800
#
# >>> wine CV Results: mean=0.853, std=0.052
#
# ========================================
# ========================================
# dimension 30, padding with zeros for 32
#
# === Dataset=breast_cancer
#
# === Dataset=breast_cancer | Fold 1/5 ===
# number of schmidt terms: 2,number of ancilla qubits:1
# Using cpu for training
# Model: HybridModel(
#   (qc): SchmidtQuantumCircuit(
#     (unitary_params): ParameterList(
#         (0): Parameter containing: [torch.float32 of size 5]
#         (1): Parameter containing: [torch.float32 of size 5]
#     )
#   )
#   (classical_net): Sequential(
#     (0): Linear(in_features=5, out_features=64, bias=True)
#     (1): BatchNorm1d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): ReLU()
#     (3): Dropout(p=0.25, inplace=False)
#     (4): Linear(in_features=64, out_features=32, bias=True)
#     (5): BatchNorm1d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (6): ReLU()
#     (7): Dropout(p=0.25, inplace=False)
#     (8): Linear(in_features=32, out_features=2, bias=True)
#   )
# )
# Number of parameters: 2734
# Optimizer: AdamW (
# Parameter Group 0
#     amsgrad: False
#     betas: (0.9, 0.999)
#     capturable: False
#     decoupled_weight_decay: True
#     differentiable: False
#     eps: 1e-08
#     foreach: None
#     fused: None
#     initial_lr: 0.05
#     lr: 0.05
#     maximize: False
#     weight_decay: 0.0001
# )
# Loss Function: CrossEntropyLoss()
#  Ep 1  loss=0.3247  train_acc=0.879  val_acc=0.505  lr=0.049997
#  Ep10  loss=0.1828  train_acc=0.915  val_acc=0.934  lr=0.049692
#  Ep20  loss=0.2046  train_acc=0.926  val_acc=0.802  lr=0.048776
#  Ep30  loss=0.2547  train_acc=0.915  val_acc=0.923  lr=0.047275
#  Ep40  loss=0.2048  train_acc=0.909  val_acc=0.857  lr=0.045225
#  Ep50  loss=0.1878  train_acc=0.926  val_acc=0.802  lr=0.042678
#  Ep60  loss=0.2153  train_acc=0.926  val_acc=0.956  lr=0.039695
#  Ep70  loss=0.1865  train_acc=0.929  val_acc=0.846  lr=0.036350
#  Ep80  loss=0.2688  train_acc=0.882  val_acc=0.802  lr=0.032725
#  Ep90  loss=0.1972  train_acc=0.904  val_acc=0.890  lr=0.028911
#  Ep100  loss=0.1950  train_acc=0.937  val_acc=0.429  lr=0.025000
#  Ep110  loss=0.2014  train_acc=0.912  val_acc=0.879  lr=0.021089
#  Ep120  loss=0.1791  train_acc=0.912  val_acc=0.758  lr=0.017275
#  Ep130  loss=0.2089  train_acc=0.912  val_acc=0.956  lr=0.013650
#  Ep140  loss=0.1609  train_acc=0.929  val_acc=0.945  lr=0.010305
#  Ep150  loss=0.1684  train_acc=0.929  val_acc=0.956  lr=0.007322
#  Ep160  loss=0.1865  train_acc=0.926  val_acc=0.934  lr=0.004775
#  Ep170  loss=0.2116  train_acc=0.923  val_acc=0.934  lr=0.002725
#  Ep180  loss=0.1719  train_acc=0.929  val_acc=0.945  lr=0.001224
#  Ep190  loss=0.1732  train_acc=0.926  val_acc=0.945  lr=0.000308
#  Ep200  loss=0.1617  train_acc=0.934  val_acc=0.945  lr=0.000000
#  >>> Fold 1 Test Accuracy: 0.930
#
# === Dataset=breast_cancer | Fold 2/5 ===
# number of schmidt terms: 2,number of ancilla qubits:1
# Using cpu for training
# Model: HybridModel(
#   (qc): SchmidtQuantumCircuit(
#     (unitary_params): ParameterList(
#         (0): Parameter containing: [torch.float32 of size 5]
#         (1): Parameter containing: [torch.float32 of size 5]
#     )
#   )
#   (classical_net): Sequential(
#     (0): Linear(in_features=5, out_features=64, bias=True)
#     (1): BatchNorm1d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): ReLU()
#     (3): Dropout(p=0.25, inplace=False)
#     (4): Linear(in_features=64, out_features=32, bias=True)
#     (5): BatchNorm1d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (6): ReLU()
#     (7): Dropout(p=0.25, inplace=False)
#     (8): Linear(in_features=32, out_features=2, bias=True)
#   )
# )
# Number of parameters: 2734
# Optimizer: AdamW (
# Parameter Group 0
#     amsgrad: False
#     betas: (0.9, 0.999)
#     capturable: False
#     decoupled_weight_decay: True
#     differentiable: False
#     eps: 1e-08
#     foreach: None
#     fused: None
#     initial_lr: 0.05
#     lr: 0.05
#     maximize: False
#     weight_decay: 0.0001
# )
# Loss Function: CrossEntropyLoss()
#  Ep 1  loss=0.2792  train_acc=0.879  val_acc=0.637  lr=0.049997
#  Ep10  loss=0.1857  train_acc=0.915  val_acc=0.802  lr=0.049692
#  Ep20  loss=0.2440  train_acc=0.887  val_acc=0.703  lr=0.048776
#  Ep30  loss=0.2192  train_acc=0.926  val_acc=0.813  lr=0.047275
#  Ep40  loss=0.2062  train_acc=0.918  val_acc=0.769  lr=0.045225
#  Ep50  loss=0.2088  train_acc=0.920  val_acc=0.835  lr=0.042678
#  Ep60  loss=0.2044  train_acc=0.920  val_acc=0.868  lr=0.039695
#  Ep70  loss=0.2302  train_acc=0.912  val_acc=0.934  lr=0.036350
#  Ep80  loss=0.1955  train_acc=0.926  val_acc=0.945  lr=0.032725
#  Ep90  loss=0.1734  train_acc=0.940  val_acc=0.945  lr=0.028911
#  Ep100  loss=0.1614  train_acc=0.934  val_acc=0.934  lr=0.025000
#  Ep110  loss=0.1979  train_acc=0.923  val_acc=0.879  lr=0.021089
#  Ep120  loss=0.1929  train_acc=0.923  val_acc=0.868  lr=0.017275
#  Ep130  loss=0.2249  train_acc=0.920  val_acc=0.868  lr=0.013650
#  Ep140  loss=0.1794  train_acc=0.918  val_acc=0.923  lr=0.010305
#  Ep150  loss=0.1951  train_acc=0.937  val_acc=0.923  lr=0.007322
#  Ep160  loss=0.2005  train_acc=0.918  val_acc=0.923  lr=0.004775
#  Ep170  loss=0.1517  train_acc=0.937  val_acc=0.890  lr=0.002725
#  Ep180  loss=0.1946  train_acc=0.923  val_acc=0.912  lr=0.001224
#  Ep190  loss=0.1821  train_acc=0.929  val_acc=0.912  lr=0.000308
#  Ep200  loss=0.2289  train_acc=0.915  val_acc=0.912  lr=0.000000
#  >>> Fold 2 Test Accuracy: 0.904
#
# === Dataset=breast_cancer | Fold 3/5 ===
# number of schmidt terms: 2,number of ancilla qubits:1
# Using cpu for training
# Model: HybridModel(
#   (qc): SchmidtQuantumCircuit(
#     (unitary_params): ParameterList(
#         (0): Parameter containing: [torch.float32 of size 5]
#         (1): Parameter containing: [torch.float32 of size 5]
#     )
#   )
#   (classical_net): Sequential(
#     (0): Linear(in_features=5, out_features=64, bias=True)
#     (1): BatchNorm1d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): ReLU()
#     (3): Dropout(p=0.25, inplace=False)
#     (4): Linear(in_features=64, out_features=32, bias=True)
#     (5): BatchNorm1d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (6): ReLU()
#     (7): Dropout(p=0.25, inplace=False)
#     (8): Linear(in_features=32, out_features=2, bias=True)
#   )
# )
# Number of parameters: 2734
# Optimizer: AdamW (
# Parameter Group 0
#     amsgrad: False
#     betas: (0.9, 0.999)
#     capturable: False
#     decoupled_weight_decay: True
#     differentiable: False
#     eps: 1e-08
#     foreach: None
#     fused: None
#     initial_lr: 0.05
#     lr: 0.05
#     maximize: False
#     weight_decay: 0.0001
# )
# Loss Function: CrossEntropyLoss()
#  Ep 1  loss=0.3620  train_acc=0.860  val_acc=0.747  lr=0.049997
#  Ep10  loss=0.2280  train_acc=0.893  val_acc=0.923  lr=0.049692
#  Ep20  loss=0.2128  train_acc=0.907  val_acc=0.857  lr=0.048776
#  Ep30  loss=0.2161  train_acc=0.929  val_acc=0.945  lr=0.047275
#  Ep40  loss=0.2097  train_acc=0.915  val_acc=0.824  lr=0.045225
#  Ep50  loss=0.1929  train_acc=0.934  val_acc=0.604  lr=0.042678
#  Ep60  loss=0.2400  train_acc=0.887  val_acc=0.945  lr=0.039695
#  Ep70  loss=0.2279  train_acc=0.904  val_acc=0.945  lr=0.036350
#  Ep80  loss=0.2973  train_acc=0.909  val_acc=0.934  lr=0.032725
#  Ep90  loss=0.2383  train_acc=0.885  val_acc=0.934  lr=0.028911
#  Ep100  loss=0.2103  train_acc=0.920  val_acc=0.934  lr=0.025000
#  Ep110  loss=0.2154  train_acc=0.923  val_acc=0.956  lr=0.021089
#  Ep120  loss=0.1976  train_acc=0.926  val_acc=0.945  lr=0.017275
#  Ep130  loss=0.1730  train_acc=0.920  val_acc=0.945  lr=0.013650
#  Ep140  loss=0.1994  train_acc=0.912  val_acc=0.945  lr=0.010305
#  Ep150  loss=0.1902  train_acc=0.915  val_acc=0.956  lr=0.007322
#  Ep160  loss=0.2079  train_acc=0.923  val_acc=0.956  lr=0.004775
#  Ep170  loss=0.1726  train_acc=0.934  val_acc=0.956  lr=0.002725
#  Ep180  loss=0.2160  train_acc=0.907  val_acc=0.956  lr=0.001224
#  Ep190  loss=0.1865  train_acc=0.929  val_acc=0.956  lr=0.000308
#  Ep200  loss=0.1653  train_acc=0.948  val_acc=0.956  lr=0.000000
#  >>> Fold 3 Test Accuracy: 0.895
#
# === Dataset=breast_cancer | Fold 4/5 ===
# number of schmidt terms: 2,number of ancilla qubits:1
# Using cpu for training
# Model: HybridModel(
#   (qc): SchmidtQuantumCircuit(
#     (unitary_params): ParameterList(
#         (0): Parameter containing: [torch.float32 of size 5]
#         (1): Parameter containing: [torch.float32 of size 5]
#     )
#   )
#   (classical_net): Sequential(
#     (0): Linear(in_features=5, out_features=64, bias=True)
#     (1): BatchNorm1d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): ReLU()
#     (3): Dropout(p=0.25, inplace=False)
#     (4): Linear(in_features=64, out_features=32, bias=True)
#     (5): BatchNorm1d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (6): ReLU()
#     (7): Dropout(p=0.25, inplace=False)
#     (8): Linear(in_features=32, out_features=2, bias=True)
#   )
# )
# Number of parameters: 2734
# Optimizer: AdamW (
# Parameter Group 0
#     amsgrad: False
#     betas: (0.9, 0.999)
#     capturable: False
#     decoupled_weight_decay: True
#     differentiable: False
#     eps: 1e-08
#     foreach: None
#     fused: None
#     initial_lr: 0.05
#     lr: 0.05
#     maximize: False
#     weight_decay: 0.0001
# )
# Loss Function: CrossEntropyLoss()
#  Ep 1  loss=0.3165  train_acc=0.896  val_acc=0.714  lr=0.049997
#  Ep10  loss=0.2166  train_acc=0.901  val_acc=0.374  lr=0.049692
#  Ep20  loss=0.2262  train_acc=0.918  val_acc=0.385  lr=0.048776
#  Ep30  loss=0.2241  train_acc=0.901  val_acc=0.418  lr=0.047275
#  Ep40  loss=0.2166  train_acc=0.904  val_acc=0.857  lr=0.045225
#  Ep50  loss=0.2371  train_acc=0.918  val_acc=0.879  lr=0.042678
#  Ep60  loss=0.1820  train_acc=0.929  val_acc=0.429  lr=0.039695
#  Ep70  loss=0.1867  train_acc=0.934  val_acc=0.791  lr=0.036350
#  Ep80  loss=0.2584  train_acc=0.904  val_acc=0.462  lr=0.032725
#  Ep90  loss=0.2301  train_acc=0.918  val_acc=0.571  lr=0.028911
#  Ep100  loss=0.1846  train_acc=0.915  val_acc=0.835  lr=0.025000
#  Ep110  loss=0.2196  train_acc=0.915  val_acc=0.868  lr=0.021089
#  Ep120  loss=0.1746  train_acc=0.948  val_acc=0.846  lr=0.017275
#  Ep130  loss=0.2415  train_acc=0.926  val_acc=0.824  lr=0.013650
#  Ep140  loss=0.1777  train_acc=0.940  val_acc=0.835  lr=0.010305
#  Ep150  loss=0.1575  train_acc=0.945  val_acc=0.890  lr=0.007322
#  Ep160  loss=0.1472  train_acc=0.937  val_acc=0.846  lr=0.004775
#  Ep170  loss=0.1876  train_acc=0.918  val_acc=0.868  lr=0.002725
#  Ep180  loss=0.2016  train_acc=0.926  val_acc=0.879  lr=0.001224
#  Ep190  loss=0.1691  train_acc=0.934  val_acc=0.901  lr=0.000308
#  Ep200  loss=0.2075  train_acc=0.931  val_acc=0.901  lr=0.000000
#  >>> Fold 4 Test Accuracy: 0.947
#
# === Dataset=breast_cancer | Fold 5/5 ===
# number of schmidt terms: 2,number of ancilla qubits:1
# Using cpu for training
# Model: HybridModel(
#   (qc): SchmidtQuantumCircuit(
#     (unitary_params): ParameterList(
#         (0): Parameter containing: [torch.float32 of size 5]
#         (1): Parameter containing: [torch.float32 of size 5]
#     )
#   )
#   (classical_net): Sequential(
#     (0): Linear(in_features=5, out_features=64, bias=True)
#     (1): BatchNorm1d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): ReLU()
#     (3): Dropout(p=0.25, inplace=False)
#     (4): Linear(in_features=64, out_features=32, bias=True)
#     (5): BatchNorm1d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (6): ReLU()
#     (7): Dropout(p=0.25, inplace=False)
#     (8): Linear(in_features=32, out_features=2, bias=True)
#   )
# )
# Number of parameters: 2734
# Optimizer: AdamW (
# Parameter Group 0
#     amsgrad: False
#     betas: (0.9, 0.999)
#     capturable: False
#     decoupled_weight_decay: True
#     differentiable: False
#     eps: 1e-08
#     foreach: None
#     fused: None
#     initial_lr: 0.05
#     lr: 0.05
#     maximize: False
#     weight_decay: 0.0001
# )
# Loss Function: CrossEntropyLoss()
#  Ep 1  loss=0.3891  train_acc=0.852  val_acc=0.891  lr=0.049997
#  Ep10  loss=0.2132  train_acc=0.909  val_acc=0.663  lr=0.049692
#  Ep20  loss=0.2224  train_acc=0.898  val_acc=0.924  lr=0.048776
#  Ep30  loss=0.1998  train_acc=0.923  val_acc=0.783  lr=0.047275
#  Ep40  loss=0.2283  train_acc=0.901  val_acc=0.924  lr=0.045225
#  Ep50  loss=0.1976  train_acc=0.912  val_acc=0.880  lr=0.042678
#  Ep60  loss=0.2369  train_acc=0.915  val_acc=0.913  lr=0.039695
#  Ep70  loss=0.2008  train_acc=0.912  val_acc=0.902  lr=0.036350
#  Ep80  loss=0.1907  train_acc=0.920  val_acc=0.880  lr=0.032725
#  Ep90  loss=0.2012  train_acc=0.912  val_acc=0.880  lr=0.028911
#  Ep100  loss=0.2176  train_acc=0.904  val_acc=0.902  lr=0.025000
#  Ep110  loss=0.2121  train_acc=0.934  val_acc=0.913  lr=0.021089
#  Ep120  loss=0.2112  train_acc=0.901  val_acc=0.924  lr=0.017275
#  Ep130  loss=0.1687  train_acc=0.923  val_acc=0.902  lr=0.013650
#  Ep140  loss=0.1686  train_acc=0.920  val_acc=0.902  lr=0.010305
#  Ep150  loss=0.1627  train_acc=0.931  val_acc=0.913  lr=0.007322
#  Ep160  loss=0.2167  train_acc=0.912  val_acc=0.924  lr=0.004775
#  Ep170  loss=0.1650  train_acc=0.929  val_acc=0.913  lr=0.002725
#  Ep180  loss=0.1628  train_acc=0.929  val_acc=0.913  lr=0.001224
#  Ep190  loss=0.2042  train_acc=0.918  val_acc=0.913  lr=0.000308
#  Ep200  loss=0.1567  train_acc=0.940  val_acc=0.913  lr=0.000000
#  >>> Fold 5 Test Accuracy: 0.947
#
# >>> breast_cancer CV Results: mean=0.924, std=0.022
#
# ========================================
# ========================================
# dimension 34, padding with zeros for 64
#
# === Dataset=ionosphere
#
# === Dataset=ionosphere | Fold 1/5 ===
# number of schmidt terms: 1,number of ancilla qubits:0
# Using cpu for training
# Model: HybridModel(
#   (qc): SchmidtQuantumCircuit(
#     (unitary_params): ParameterList(  (0): Parameter containing: [torch.float32 of size 6])
#   )
#   (classical_net): Sequential(
#     (0): Linear(in_features=6, out_features=64, bias=True)
#     (1): BatchNorm1d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): ReLU()
#     (3): Dropout(p=0.25, inplace=False)
#     (4): Linear(in_features=64, out_features=32, bias=True)
#     (5): BatchNorm1d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (6): ReLU()
#     (7): Dropout(p=0.25, inplace=False)
#     (8): Linear(in_features=32, out_features=2, bias=True)
#   )
# )
# Number of parameters: 2792
# Optimizer: AdamW (
# Parameter Group 0
#     amsgrad: False
#     betas: (0.9, 0.999)
#     capturable: False
#     decoupled_weight_decay: True
#     differentiable: False
#     eps: 1e-08
#     foreach: None
#     fused: None
#     initial_lr: 0.05
#     lr: 0.05
#     maximize: False
#     weight_decay: 0.0001
# )
# Loss Function: CrossEntropyLoss()
#  Ep 1  loss=0.2703  train_acc=0.911  val_acc=0.911  lr=0.049997
#  Ep10  loss=0.1752  train_acc=0.946  val_acc=0.964  lr=0.049692
#  Ep20  loss=0.1579  train_acc=0.946  val_acc=0.964  lr=0.048776
#  Ep30  loss=0.1565  train_acc=0.933  val_acc=0.946  lr=0.047275
#  Ep40  loss=0.1533  train_acc=0.938  val_acc=0.964  lr=0.045225
#  Ep50  loss=0.1672  train_acc=0.942  val_acc=0.946  lr=0.042678
#  Ep60  loss=0.1385  train_acc=0.960  val_acc=0.946  lr=0.039695
#  Ep70  loss=0.1463  train_acc=0.951  val_acc=0.964  lr=0.036350
#  Ep80  loss=0.1282  train_acc=0.942  val_acc=0.964  lr=0.032725
#  Ep90  loss=0.1072  train_acc=0.951  val_acc=0.964  lr=0.028911
#  Ep100  loss=0.1505  train_acc=0.938  val_acc=0.964  lr=0.025000
#  Ep110  loss=0.0916  train_acc=0.969  val_acc=0.964  lr=0.021089
#  Ep120  loss=0.0975  train_acc=0.969  val_acc=0.946  lr=0.017275
#  Ep130  loss=0.0870  train_acc=0.969  val_acc=0.964  lr=0.013650
#  Ep140  loss=0.1015  train_acc=0.973  val_acc=0.946  lr=0.010305
#  Ep150  loss=0.0734  train_acc=0.973  val_acc=0.964  lr=0.007322
#  Ep160  loss=0.0576  train_acc=0.987  val_acc=0.964  lr=0.004775
#  Ep170  loss=0.0962  train_acc=0.964  val_acc=0.946  lr=0.002725
#  Ep180  loss=0.0725  train_acc=0.973  val_acc=0.946  lr=0.001224
#  Ep190  loss=0.0764  train_acc=0.982  val_acc=0.946  lr=0.000308
#  Ep200  loss=0.0711  train_acc=0.969  val_acc=0.946  lr=0.000000
#  >>> Fold 1 Test Accuracy: 0.930
#
# === Dataset=ionosphere | Fold 2/5 ===
# number of schmidt terms: 1,number of ancilla qubits:0
# Using cpu for training
# Model: HybridModel(
#   (qc): SchmidtQuantumCircuit(
#     (unitary_params): ParameterList(  (0): Parameter containing: [torch.float32 of size 6])
#   )
#   (classical_net): Sequential(
#     (0): Linear(in_features=6, out_features=64, bias=True)
#     (1): BatchNorm1d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): ReLU()
#     (3): Dropout(p=0.25, inplace=False)
#     (4): Linear(in_features=64, out_features=32, bias=True)
#     (5): BatchNorm1d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (6): ReLU()
#     (7): Dropout(p=0.25, inplace=False)
#     (8): Linear(in_features=32, out_features=2, bias=True)
#   )
# )
# Number of parameters: 2792
# Optimizer: AdamW (
# Parameter Group 0
#     amsgrad: False
#     betas: (0.9, 0.999)
#     capturable: False
#     decoupled_weight_decay: True
#     differentiable: False
#     eps: 1e-08
#     foreach: None
#     fused: None
#     initial_lr: 0.05
#     lr: 0.05
#     maximize: False
#     weight_decay: 0.0001
# )
# Loss Function: CrossEntropyLoss()
#  Ep 1  loss=0.4657  train_acc=0.763  val_acc=0.842  lr=0.049997
#  Ep10  loss=0.2203  train_acc=0.906  val_acc=0.947  lr=0.049692
#  Ep20  loss=0.1756  train_acc=0.929  val_acc=0.947  lr=0.048776
#  Ep30  loss=0.2170  train_acc=0.929  val_acc=0.912  lr=0.047275
#  Ep40  loss=0.1858  train_acc=0.942  val_acc=0.947  lr=0.045225
#  Ep50  loss=0.2946  train_acc=0.893  val_acc=0.912  lr=0.042678
#  Ep60  loss=0.1481  train_acc=0.938  val_acc=0.930  lr=0.039695
#  Ep70  loss=0.1898  train_acc=0.933  val_acc=0.947  lr=0.036350
#  Ep80  loss=0.1268  train_acc=0.951  val_acc=0.947  lr=0.032725
#  Ep90  loss=0.2107  train_acc=0.924  val_acc=0.930  lr=0.028911
#  Ep100  loss=0.1692  train_acc=0.933  val_acc=0.930  lr=0.025000
#  Ep110  loss=0.1681  train_acc=0.920  val_acc=0.912  lr=0.021089
#  Ep120  loss=0.1761  train_acc=0.946  val_acc=0.930  lr=0.017275
#  Ep130  loss=0.1759  train_acc=0.942  val_acc=0.930  lr=0.013650
#  Ep140  loss=0.1193  train_acc=0.964  val_acc=0.930  lr=0.010305
#  Ep150  loss=0.1405  train_acc=0.951  val_acc=0.947  lr=0.007322
#  Ep160  loss=0.1152  train_acc=0.969  val_acc=0.947  lr=0.004775
#  Ep170  loss=0.1201  train_acc=0.960  val_acc=0.947  lr=0.002725
#  Ep180  loss=0.1180  train_acc=0.964  val_acc=0.947  lr=0.001224
#  Ep190  loss=0.1552  train_acc=0.946  val_acc=0.930  lr=0.000308
#  Ep200  loss=0.0985  train_acc=0.964  val_acc=0.947  lr=0.000000
#  >>> Fold 2 Test Accuracy: 0.929
#
# === Dataset=ionosphere | Fold 3/5 ===
# number of schmidt terms: 1,number of ancilla qubits:0
# Using cpu for training
# Model: HybridModel(
#   (qc): SchmidtQuantumCircuit(
#     (unitary_params): ParameterList(  (0): Parameter containing: [torch.float32 of size 6])
#   )
#   (classical_net): Sequential(
#     (0): Linear(in_features=6, out_features=64, bias=True)
#     (1): BatchNorm1d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): ReLU()
#     (3): Dropout(p=0.25, inplace=False)
#     (4): Linear(in_features=64, out_features=32, bias=True)
#     (5): BatchNorm1d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (6): ReLU()
#     (7): Dropout(p=0.25, inplace=False)
#     (8): Linear(in_features=32, out_features=2, bias=True)
#   )
# )
# Number of parameters: 2792
# Optimizer: AdamW (
# Parameter Group 0
#     amsgrad: False
#     betas: (0.9, 0.999)
#     capturable: False
#     decoupled_weight_decay: True
#     differentiable: False
#     eps: 1e-08
#     foreach: None
#     fused: None
#     initial_lr: 0.05
#     lr: 0.05
#     maximize: False
#     weight_decay: 0.0001
# )
# Loss Function: CrossEntropyLoss()
#  Ep 1  loss=0.3692  train_acc=0.830  val_acc=0.772  lr=0.049997
#  Ep10  loss=0.1391  train_acc=0.951  val_acc=0.947  lr=0.049692
#  Ep20  loss=0.1324  train_acc=0.946  val_acc=0.912  lr=0.048776
#  Ep30  loss=0.1047  train_acc=0.955  val_acc=0.947  lr=0.047275
#  Ep40  loss=0.1637  train_acc=0.938  val_acc=0.947  lr=0.045225
#  Ep50  loss=0.0991  train_acc=0.978  val_acc=0.947  lr=0.042678
#  Ep60  loss=0.1129  train_acc=0.946  val_acc=0.947  lr=0.039695
#  Ep70  loss=0.0799  train_acc=0.969  val_acc=0.965  lr=0.036350
#  Ep80  loss=0.0949  train_acc=0.973  val_acc=0.965  lr=0.032725
#  Ep90  loss=0.1246  train_acc=0.960  val_acc=0.947  lr=0.028911
#  Ep100  loss=0.0994  train_acc=0.960  val_acc=0.947  lr=0.025000
#  Ep110  loss=0.0760  train_acc=0.969  val_acc=0.965  lr=0.021089
#  Ep120  loss=0.1040  train_acc=0.955  val_acc=0.947  lr=0.017275
#  Ep130  loss=0.0743  train_acc=0.964  val_acc=0.930  lr=0.013650
#  Ep140  loss=0.0569  train_acc=0.978  val_acc=0.965  lr=0.010305
#  Ep150  loss=0.0751  train_acc=0.964  val_acc=0.947  lr=0.007322
#  Ep160  loss=0.0745  train_acc=0.973  val_acc=0.930  lr=0.004775
#  Ep170  loss=0.0588  train_acc=0.987  val_acc=0.930  lr=0.002725
#  Ep180  loss=0.0740  train_acc=0.964  val_acc=0.930  lr=0.001224
#  Ep190  loss=0.0758  train_acc=0.973  val_acc=0.930  lr=0.000308
#  Ep200  loss=0.1068  train_acc=0.960  val_acc=0.930  lr=0.000000
#  >>> Fold 3 Test Accuracy: 0.943
#
# === Dataset=ionosphere | Fold 4/5 ===
# number of schmidt terms: 1,number of ancilla qubits:0
# Using cpu for training
# Model: HybridModel(
#   (qc): SchmidtQuantumCircuit(
#     (unitary_params): ParameterList(  (0): Parameter containing: [torch.float32 of size 6])
#   )
#   (classical_net): Sequential(
#     (0): Linear(in_features=6, out_features=64, bias=True)
#     (1): BatchNorm1d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): ReLU()
#     (3): Dropout(p=0.25, inplace=False)
#     (4): Linear(in_features=64, out_features=32, bias=True)
#     (5): BatchNorm1d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (6): ReLU()
#     (7): Dropout(p=0.25, inplace=False)
#     (8): Linear(in_features=32, out_features=2, bias=True)
#   )
# )
# Number of parameters: 2792
# Optimizer: AdamW (
# Parameter Group 0
#     amsgrad: False
#     betas: (0.9, 0.999)
#     capturable: False
#     decoupled_weight_decay: True
#     differentiable: False
#     eps: 1e-08
#     foreach: None
#     fused: None
#     initial_lr: 0.05
#     lr: 0.05
#     maximize: False
#     weight_decay: 0.0001
# )
# Loss Function: CrossEntropyLoss()
#  Ep 1  loss=0.4204  train_acc=0.826  val_acc=0.860  lr=0.049997
#  Ep10  loss=0.1948  train_acc=0.942  val_acc=0.930  lr=0.049692
#  Ep20  loss=0.1791  train_acc=0.942  val_acc=0.947  lr=0.048776
#  Ep30  loss=0.1179  train_acc=0.960  val_acc=0.982  lr=0.047275
#  Ep40  loss=0.0979  train_acc=0.955  val_acc=1.000  lr=0.045225
#  Ep50  loss=0.1364  train_acc=0.951  val_acc=1.000  lr=0.042678
#  Ep60  loss=0.1617  train_acc=0.933  val_acc=0.982  lr=0.039695
#  Ep70  loss=0.1136  train_acc=0.960  val_acc=0.965  lr=0.036350
#  Ep80  loss=0.1380  train_acc=0.960  val_acc=0.982  lr=0.032725
#  Ep90  loss=0.1288  train_acc=0.964  val_acc=0.965  lr=0.028911
#  Ep100  loss=0.0737  train_acc=0.960  val_acc=0.965  lr=0.025000
#  Ep110  loss=0.1146  train_acc=0.964  val_acc=0.982  lr=0.021089
# ...
#     (unitary_params): ParameterList(
#         (0): Parameter containing: [torch.float32 of size 6]
#         (1): Parameter containing: [torch.float32 of size 6]
#         (2): Parameter containing: [torch.float32 of size 6]
#     )
#   )
#   (classical_net): Sequential(
#     (0): Linear(in_features=6, out_features=64, bias=True)
#     (1): BatchNorm1d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): ReLU()
#     (3): Dropout(p=0.25, inplace=False)
#     (4): Linear(in_features=64, out_features=32, bias=True)
#     (5): BatchNorm1d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (6): ReLU()
#     (7): Dropout(p=0.25, inplace=False)
#     (8): Linear(in_features=32, out_features=7, bias=True)
#   )
# )
# Number of parameters: 2975
# Optimizer: AdamW (
# Parameter Group 0
#     amsgrad: False
#     betas: (0.9, 0.999)
#     capturable: False
#     decoupled_weight_decay: True
#     differentiable: False
#     eps: 1e-08
#     foreach: None
#     fused: None
#     initial_lr: 0.05
#     lr: 0.05
#     maximize: False
#     weight_decay: 0.0001
# )
# Loss Function: CrossEntropyLoss()
#  Ep 1  loss=1.3752  train_acc=0.486  val_acc=0.456  lr=0.049997
#  Ep10  loss=1.1427  train_acc=0.491  val_acc=0.456  lr=0.049692
#  Ep20  loss=1.1290  train_acc=0.511  val_acc=0.481  lr=0.048776
#  Ep30  loss=1.1354  train_acc=0.505  val_acc=0.481  lr=0.047275
#  Ep40  loss=1.1353  train_acc=0.502  val_acc=0.469  lr=0.045225
#  Ep50  loss=1.1274  train_acc=0.498  val_acc=0.463  lr=0.042678
#  Ep60  loss=1.1210  train_acc=0.483  val_acc=0.487  lr=0.039695
#  Ep70  loss=1.1264  train_acc=0.481  val_acc=0.475  lr=0.036350
#  Ep80  loss=1.1142  train_acc=0.508  val_acc=0.438  lr=0.032725
#  Ep90  loss=1.1141  train_acc=0.500  val_acc=0.475  lr=0.028911
#  Ep100  loss=1.1045  train_acc=0.531  val_acc=0.481  lr=0.025000
#  Ep110  loss=1.0952  train_acc=0.508  val_acc=0.481  lr=0.021089
#  Ep120  loss=1.0990  train_acc=0.508  val_acc=0.487  lr=0.017275
#  Ep130  loss=1.0891  train_acc=0.525  val_acc=0.487  lr=0.013650
#  Ep140  loss=1.0953  train_acc=0.528  val_acc=0.469  lr=0.010305
#  Ep150  loss=1.0972  train_acc=0.517  val_acc=0.506  lr=0.007322
#  Ep160  loss=1.0849  train_acc=0.539  val_acc=0.494  lr=0.004775
#  Ep170  loss=1.0901  train_acc=0.514  val_acc=0.475  lr=0.002725
#  Ep180  loss=1.0962  train_acc=0.541  val_acc=0.519  lr=0.001224
#  Ep190  loss=1.0813  train_acc=0.516  val_acc=0.506  lr=0.000308
#  Ep200  loss=1.0845  train_acc=0.545  val_acc=0.512  lr=0.000000
#  >>> Fold 5 Test Accuracy: 0.495
#
# >>> covtype CV Results: mean=0.534, std=0.043
#
# ========================================
# ========================================
#
# === Dataset=digits
#
# === Dataset=digits | Fold 1/5 ===
# number of schmidt terms: 2,number of ancilla qubits:1
# Using cpu for training
# Model: HybridModel(
#   (qc): SchmidtQuantumCircuit(
#     (unitary_params): ParameterList(
#         (0): Parameter containing: [torch.float32 of size 6]
#         (1): Parameter containing: [torch.float32 of size 6]
#     )
#   )
#   (classical_net): Sequential(
#     (0): Linear(in_features=6, out_features=64, bias=True)
#     (1): BatchNorm1d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): ReLU()
#     (3): Dropout(p=0.25, inplace=False)
#     (4): Linear(in_features=64, out_features=32, bias=True)
#     (5): BatchNorm1d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (6): ReLU()
#     (7): Dropout(p=0.25, inplace=False)
#     (8): Linear(in_features=32, out_features=10, bias=True)
#   )
# )
# Number of parameters: 3064
# Optimizer: AdamW (
# Parameter Group 0
#     amsgrad: False
#     betas: (0.9, 0.999)
#     capturable: False
#     decoupled_weight_decay: True
#     differentiable: False
#     eps: 1e-08
#     foreach: None
#     fused: None
#     initial_lr: 0.05
#     lr: 0.05
#     maximize: False
#     weight_decay: 0.0001
# )
# Loss Function: CrossEntropyLoss()
#  Ep 1  loss=1.6928  train_acc=0.436  val_acc=0.463  lr=0.049997
#  Ep10  loss=0.9866  train_acc=0.644  val_acc=0.656  lr=0.049692
#  Ep20  loss=0.9030  train_acc=0.661  val_acc=0.669  lr=0.048776
#  Ep30  loss=0.8715  train_acc=0.692  val_acc=0.713  lr=0.047275
#  Ep40  loss=0.8467  train_acc=0.700  val_acc=0.762  lr=0.045225
#  Ep50  loss=0.8776  train_acc=0.694  val_acc=0.694  lr=0.042678
#  Ep60  loss=0.8123  train_acc=0.728  val_acc=0.738  lr=0.039695
#  Ep70  loss=0.7545  train_acc=0.736  val_acc=0.738  lr=0.036350
#  Ep80  loss=0.7441  train_acc=0.722  val_acc=0.775  lr=0.032725
#  Ep90  loss=0.7903  train_acc=0.694  val_acc=0.775  lr=0.028911
#  Ep100  loss=0.7280  train_acc=0.753  val_acc=0.769  lr=0.025000
#  Ep110  loss=0.7440  train_acc=0.741  val_acc=0.775  lr=0.021089
#  Ep120  loss=0.7172  train_acc=0.750  val_acc=0.762  lr=0.017275
#  Ep130  loss=0.7656  train_acc=0.723  val_acc=0.769  lr=0.013650
#  Ep140  loss=0.6509  train_acc=0.764  val_acc=0.756  lr=0.010305
#  Ep150  loss=0.5994  train_acc=0.769  val_acc=0.762  lr=0.007322
#  Ep160  loss=0.6309  train_acc=0.781  val_acc=0.769  lr=0.004775
#  Ep170  loss=0.6134  train_acc=0.769  val_acc=0.756  lr=0.002725
#  Ep180  loss=0.7054  train_acc=0.745  val_acc=0.756  lr=0.001224
#  Ep190  loss=0.6831  train_acc=0.761  val_acc=0.756  lr=0.000308
#  Ep200  loss=0.6113  train_acc=0.770  val_acc=0.769  lr=0.000000
#  >>> Fold 1 Test Accuracy: 0.775
#
# === Dataset=digits | Fold 2/5 ===
# number of schmidt terms: 2,number of ancilla qubits:1
# Using cpu for training
# Model: HybridModel(
#   (qc): SchmidtQuantumCircuit(
#     (unitary_params): ParameterList(
#         (0): Parameter containing: [torch.float32 of size 6]
#         (1): Parameter containing: [torch.float32 of size 6]
#     )
#   )
#   (classical_net): Sequential(
#     (0): Linear(in_features=6, out_features=64, bias=True)
#     (1): BatchNorm1d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): ReLU()
#     (3): Dropout(p=0.25, inplace=False)
#     (4): Linear(in_features=64, out_features=32, bias=True)
#     (5): BatchNorm1d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (6): ReLU()
#     (7): Dropout(p=0.25, inplace=False)
#     (8): Linear(in_features=32, out_features=10, bias=True)
#   )
# )
# Number of parameters: 3064
# Optimizer: AdamW (
# Parameter Group 0
#     amsgrad: False
#     betas: (0.9, 0.999)
#     capturable: False
#     decoupled_weight_decay: True
#     differentiable: False
#     eps: 1e-08
#     foreach: None
#     fused: None
#     initial_lr: 0.05
#     lr: 0.05
#     maximize: False
#     weight_decay: 0.0001
# )
# Loss Function: CrossEntropyLoss()
#  Ep 1  loss=1.7279  train_acc=0.378  val_acc=0.494  lr=0.049997
#  Ep10  loss=1.0249  train_acc=0.667  val_acc=0.650  lr=0.049692
#  Ep20  loss=0.9196  train_acc=0.659  val_acc=0.744  lr=0.048776
#  Ep30  loss=0.8500  train_acc=0.672  val_acc=0.781  lr=0.047275
#  Ep40  loss=0.8796  train_acc=0.705  val_acc=0.787  lr=0.045225
#  Ep50  loss=0.8058  train_acc=0.717  val_acc=0.812  lr=0.042678
#  Ep60  loss=0.8458  train_acc=0.702  val_acc=0.844  lr=0.039695
#  Ep70  loss=0.7578  train_acc=0.717  val_acc=0.844  lr=0.036350
#  Ep80  loss=0.7202  train_acc=0.752  val_acc=0.825  lr=0.032725
#  Ep90  loss=0.7188  train_acc=0.717  val_acc=0.825  lr=0.028911
#  Ep100  loss=0.7305  train_acc=0.741  val_acc=0.844  lr=0.025000
#  Ep110  loss=0.6787  train_acc=0.758  val_acc=0.856  lr=0.021089
#  Ep120  loss=0.7053  train_acc=0.741  val_acc=0.838  lr=0.017275
#  Ep130  loss=0.6301  train_acc=0.766  val_acc=0.838  lr=0.013650
#  Ep140  loss=0.5794  train_acc=0.778  val_acc=0.863  lr=0.010305
#  Ep150  loss=0.5777  train_acc=0.778  val_acc=0.850  lr=0.007322
#  Ep160  loss=0.5991  train_acc=0.778  val_acc=0.863  lr=0.004775
#  Ep170  loss=0.6708  train_acc=0.756  val_acc=0.856  lr=0.002725
#  Ep180  loss=0.5901  train_acc=0.781  val_acc=0.856  lr=0.001224
#  Ep190  loss=0.6617  train_acc=0.750  val_acc=0.844  lr=0.000308
#  Ep200  loss=0.6438  train_acc=0.773  val_acc=0.844  lr=0.000000
#  >>> Fold 2 Test Accuracy: 0.745
#
# === Dataset=digits | Fold 3/5 ===
# number of schmidt terms: 2,number of ancilla qubits:1
# Using cpu for training
# Model: HybridModel(
#   (qc): SchmidtQuantumCircuit(
#     (unitary_params): ParameterList(
#         (0): Parameter containing: [torch.float32 of size 6]
#         (1): Parameter containing: [torch.float32 of size 6]
#     )
#   )
#   (classical_net): Sequential(
#     (0): Linear(in_features=6, out_features=64, bias=True)
#     (1): BatchNorm1d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): ReLU()
#     (3): Dropout(p=0.25, inplace=False)
#     (4): Linear(in_features=64, out_features=32, bias=True)
#     (5): BatchNorm1d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (6): ReLU()
#     (7): Dropout(p=0.25, inplace=False)
#     (8): Linear(in_features=32, out_features=10, bias=True)
#   )
# )
# Number of parameters: 3064
# Optimizer: AdamW (
# Parameter Group 0
#     amsgrad: False
#     betas: (0.9, 0.999)
#     capturable: False
#     decoupled_weight_decay: True
#     differentiable: False
#     eps: 1e-08
#     foreach: None
#     fused: None
#     initial_lr: 0.05
#     lr: 0.05
#     maximize: False
#     weight_decay: 0.0001
# )
# Loss Function: CrossEntropyLoss()
#  Ep 1  loss=1.7808  train_acc=0.338  val_acc=0.494  lr=0.049997
#  Ep10  loss=1.1926  train_acc=0.569  val_acc=0.675  lr=0.049692
#  Ep20  loss=1.1091  train_acc=0.609  val_acc=0.694  lr=0.048776
#  Ep30  loss=0.9976  train_acc=0.641  val_acc=0.681  lr=0.047275
#  Ep40  loss=1.0919  train_acc=0.609  val_acc=0.681  lr=0.045225
#  Ep50  loss=0.9954  train_acc=0.656  val_acc=0.675  lr=0.042678
#  Ep60  loss=0.9387  train_acc=0.658  val_acc=0.681  lr=0.039695
#  Ep70  loss=0.9451  train_acc=0.673  val_acc=0.675  lr=0.036350
#  Ep80  loss=0.9144  train_acc=0.667  val_acc=0.662  lr=0.032725
#  Ep90  loss=0.8815  train_acc=0.677  val_acc=0.675  lr=0.028911
#  Ep100  loss=0.8985  train_acc=0.689  val_acc=0.688  lr=0.025000
#  Ep110  loss=0.7987  train_acc=0.711  val_acc=0.700  lr=0.021089
#  Ep120  loss=0.8383  train_acc=0.684  val_acc=0.706  lr=0.017275
#  Ep130  loss=0.8264  train_acc=0.703  val_acc=0.700  lr=0.013650
#  Ep140  loss=0.8023  train_acc=0.708  val_acc=0.706  lr=0.010305
#  Ep150  loss=0.8528  train_acc=0.689  val_acc=0.688  lr=0.007322
#  Ep160  loss=0.8098  train_acc=0.702  val_acc=0.688  lr=0.004775
#  Ep170  loss=0.8488  train_acc=0.698  val_acc=0.719  lr=0.002725
#  Ep180  loss=0.8079  train_acc=0.684  val_acc=0.719  lr=0.001224
#  Ep190  loss=0.8725  train_acc=0.695  val_acc=0.719  lr=0.000308
#  Ep200  loss=0.8021  train_acc=0.728  val_acc=0.706  lr=0.000000
#  >>> Fold 3 Test Accuracy: 0.715
#
# === Dataset=digits | Fold 4/5 ===
# number of schmidt terms: 2,number of ancilla qubits:1
# Using cpu for training
# Model: HybridModel(
#   (qc): SchmidtQuantumCircuit(
#     (unitary_params): ParameterList(
#         (0): Parameter containing: [torch.float32 of size 6]
#         (1): Parameter containing: [torch.float32 of size 6]
#     )
#   )
#   (classical_net): Sequential(
#     (0): Linear(in_features=6, out_features=64, bias=True)
#     (1): BatchNorm1d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): ReLU()
#     (3): Dropout(p=0.25, inplace=False)
#     (4): Linear(in_features=64, out_features=32, bias=True)
#     (5): BatchNorm1d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (6): ReLU()
#     (7): Dropout(p=0.25, inplace=False)
#     (8): Linear(in_features=32, out_features=10, bias=True)
#   )
# )
# Number of parameters: 3064
# Optimizer: AdamW (
# Parameter Group 0
#     amsgrad: False
#     betas: (0.9, 0.999)
#     capturable: False
#     decoupled_weight_decay: True
#     differentiable: False
#     eps: 1e-08
#     foreach: None
#     fused: None
#     initial_lr: 0.05
#     lr: 0.05
#     maximize: False
#     weight_decay: 0.0001
# )
# Loss Function: CrossEntropyLoss()
#  Ep 1  loss=1.6169  train_acc=0.466  val_acc=0.556  lr=0.049997
#  Ep10  loss=1.0181  train_acc=0.666  val_acc=0.631  lr=0.049692
#  Ep20  loss=0.9205  train_acc=0.688  val_acc=0.694  lr=0.048776
#  Ep30  loss=0.8582  train_acc=0.713  val_acc=0.725  lr=0.047275
#  Ep40  loss=0.8202  train_acc=0.720  val_acc=0.744  lr=0.045225
#  Ep50  loss=0.8663  train_acc=0.725  val_acc=0.713  lr=0.042678
#  Ep60  loss=0.8403  train_acc=0.692  val_acc=0.725  lr=0.039695
#  Ep70  loss=0.8305  train_acc=0.736  val_acc=0.688  lr=0.036350
#  Ep80  loss=0.7529  train_acc=0.742  val_acc=0.750  lr=0.032725
#  Ep90  loss=0.7491  train_acc=0.733  val_acc=0.750  lr=0.028911
#  Ep100  loss=0.7501  train_acc=0.738  val_acc=0.750  lr=0.025000
#  Ep110  loss=0.7205  train_acc=0.772  val_acc=0.738  lr=0.021089
#  Ep120  loss=0.7555  train_acc=0.742  val_acc=0.769  lr=0.017275
#  Ep130  loss=0.6825  train_acc=0.762  val_acc=0.744  lr=0.013650
#  Ep140  loss=0.6830  train_acc=0.770  val_acc=0.750  lr=0.010305
#  Ep150  loss=0.6350  train_acc=0.769  val_acc=0.762  lr=0.007322
#  Ep160  loss=0.6871  train_acc=0.772  val_acc=0.762  lr=0.004775
#  Ep170  loss=0.6210  train_acc=0.797  val_acc=0.738  lr=0.002725
#  Ep180  loss=0.6771  train_acc=0.780  val_acc=0.756  lr=0.001224
#  Ep190  loss=0.6273  train_acc=0.791  val_acc=0.750  lr=0.000308
#  Ep200  loss=0.7324  train_acc=0.736  val_acc=0.756  lr=0.000000
#  >>> Fold 4 Test Accuracy: 0.755
#
# === Dataset=digits | Fold 5/5 ===
# number of schmidt terms: 2,number of ancilla qubits:1
# Using cpu for training
# Model: HybridModel(
#   (qc): SchmidtQuantumCircuit(
#     (unitary_params): ParameterList(
#         (0): Parameter containing: [torch.float32 of size 6]
#         (1): Parameter containing: [torch.float32 of size 6]
#     )
#   )
#   (classical_net): Sequential(
#     (0): Linear(in_features=6, out_features=64, bias=True)
#     (1): BatchNorm1d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): ReLU()
#     (3): Dropout(p=0.25, inplace=False)
#     (4): Linear(in_features=64, out_features=32, bias=True)
#     (5): BatchNorm1d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (6): ReLU()
#     (7): Dropout(p=0.25, inplace=False)
#     (8): Linear(in_features=32, out_features=10, bias=True)
#   )
# )
# Number of parameters: 3064
# Optimizer: AdamW (
# Parameter Group 0
#     amsgrad: False
#     betas: (0.9, 0.999)
#     capturable: False
#     decoupled_weight_decay: True
#     differentiable: False
#     eps: 1e-08
#     foreach: None
#     fused: None
#     initial_lr: 0.05
#     lr: 0.05
#     maximize: False
#     weight_decay: 0.0001
# )
# Loss Function: CrossEntropyLoss()
#  Ep 1  loss=1.7067  train_acc=0.372  val_acc=0.381  lr=0.049997
#  Ep10  loss=1.1889  train_acc=0.577  val_acc=0.662  lr=0.049692
#  Ep20  loss=1.0577  train_acc=0.619  val_acc=0.650  lr=0.048776
#  Ep30  loss=1.0232  train_acc=0.625  val_acc=0.637  lr=0.047275
#  Ep40  loss=1.0125  train_acc=0.616  val_acc=0.700  lr=0.045225
#  Ep50  loss=1.0505  train_acc=0.595  val_acc=0.681  lr=0.042678
#  Ep60  loss=1.0022  train_acc=0.639  val_acc=0.706  lr=0.039695
#  Ep70  loss=0.9041  train_acc=0.659  val_acc=0.706  lr=0.036350
#  Ep80  loss=0.9140  train_acc=0.641  val_acc=0.744  lr=0.032725
#  Ep90  loss=0.9331  train_acc=0.647  val_acc=0.706  lr=0.028911
#  Ep100  loss=0.8416  train_acc=0.675  val_acc=0.694  lr=0.025000
#  Ep110  loss=0.8896  train_acc=0.658  val_acc=0.713  lr=0.021089
#  Ep120  loss=0.8463  train_acc=0.670  val_acc=0.744  lr=0.017275
#  Ep130  loss=0.8162  train_acc=0.675  val_acc=0.750  lr=0.013650
#  Ep140  loss=0.8089  train_acc=0.672  val_acc=0.719  lr=0.010305
#  Ep150  loss=0.7544  train_acc=0.709  val_acc=0.744  lr=0.007322
#  Ep160  loss=0.7802  train_acc=0.702  val_acc=0.725  lr=0.004775
#  Ep170  loss=0.8152  train_acc=0.681  val_acc=0.719  lr=0.002725
#  Ep180  loss=0.7536  train_acc=0.702  val_acc=0.725  lr=0.001224
#  Ep190  loss=0.7246  train_acc=0.716  val_acc=0.738  lr=0.000308
#  Ep200  loss=0.7454  train_acc=0.706  val_acc=0.725  lr=0.000000
#  >>> Fold 5 Test Accuracy: 0.705
#
# >>> digits CV Results: mean=0.739, std=0.026
#
# ========================================
# ========================================
# === Final Summary ===
# iris            folds=5  mean_acc=0.960  std=0.049
# wine            folds=5  mean_acc=0.853  std=0.052
# breast_cancer   folds=5  mean_acc=0.924  std=0.022
# ionosphere      folds=5  mean_acc=0.934  std=0.007
# covtype         folds=5  mean_acc=0.534  std=0.043
# digits          folds=5  mean_acc=0.739  std=0.026

# %%
1
# Out:
# 1

# %%
# %%
def plot_cv_results(all_results, all_losses, fig_name="cv_results_summary"):
    import numpy as np
    import matplotlib.pyplot as plt
    import matplotlib as mpl
    from matplotlib.ticker import MaxNLocator
    from matplotlib.lines import Line2D
    import seaborn as sns
    
    # Configure global font settings
    mpl.rcParams.update({
        'font.size': 24,
        'axes.titlesize': 24,
        'axes.labelsize': 24,
        'xtick.labelsize': 24,
        'ytick.labelsize': 24,
        'legend.fontsize': 24
    })
    
    # Create 2x3 grid
    fig, axs = plt.subplots(2, 3, figsize=(24, 16))
    axs = axs.flatten()
    
    palette = sns.color_palette("pastel")
    loss_color = palette[0]       
    train_acc_color = palette[1]  
    val_acc_color = palette[6]    
    
    # Create custom legend elements
    legend_elements = [
        Line2D([0], [0], color=loss_color, lw=3, label='Train Loss'),
        Line2D([0], [0], color=train_acc_color, lw=3, label='Train Accuracy'),
        Line2D([0], [0], color=val_acc_color, lw=3, label='Validation Accuracy')
    ]
    
    for i, (dataset, fold_losses) in enumerate(all_losses.items()):
        if i >= 6:  # Only plot first 6 datasets
            break
            
        ax = axs[i]
        n_folds = len(fold_losses)
        max_epochs = max(len(fold) for fold in fold_losses.values())
        
        # Prepare arrays for metrics
        train_loss = np.full((n_folds, max_epochs), np.nan)
        train_acc = np.full((n_folds, max_epochs), np.nan)
        val_acc = np.full((n_folds, max_epochs), np.nan)
        best_val_acc = np.zeros(n_folds)
        
        # Extract metrics for each fold
        for fold_idx, fold_data in enumerate(fold_losses.values()):
            n_epochs = len(fold_data)
            train_loss[fold_idx, :n_epochs] = [x[0] for x in fold_data]
            train_acc[fold_idx, :n_epochs] = [x[1] for x in fold_data]
            val_acc[fold_idx, :n_epochs] = [x[2] for x in fold_data]
            best_val_acc[fold_idx] = max(x[2] for x in fold_data)
        
        # Calculate means and stds
        mean_train_loss = np.nanmean(train_loss, axis=0)
        mean_train_acc = np.nanmean(train_acc, axis=0)
        mean_val_acc = np.nanmean(val_acc, axis=0)
        
        # Get test accuracies
        test_accs = all_results[dataset]
        mean_test_acc = np.mean(test_accs)
        std_test_acc = np.std(test_accs)
        # Create twin axis for accuracies
        ax2 = ax#.twinx()
        # Plot individual runs with shadows
        for fold_idx in range(n_folds):
            # Plot individual training loss (light shadow)
            ax.plot(train_loss[fold_idx], 
                     color=loss_color, 
                     alpha=0.35, 
                     linewidth=0.8)
            

            
            # Plot individual accuracy runs
            ax2.plot(train_acc[fold_idx], 
                      color=train_acc_color, 
                      alpha=0.35, 
                      linewidth=0.8)
            ax2.plot(val_acc[fold_idx], 
                      color=val_acc_color, 
                      alpha=0.35, 
                      linewidth=0.8)
        
        # Plot mean training loss
        ax.plot(mean_train_loss, color=loss_color, linewidth=3, alpha=1)
        
        # Plot mean accuracies
        ax2.plot(mean_train_acc, color=train_acc_color, linewidth=3, alpha=1)
        ax2.plot(mean_val_acc, color=val_acc_color, linewidth=3, alpha=1)
        
        
        # Set titles and labels
        title = f"{dataset.replace('_', ' ').title()}\n"
        title += f"Test Acc: {mean_test_acc:.3f} ± {std_test_acc:.3f}"
        ax.set_title(title, fontsize=24, pad=15)
        
        ax.set_xlabel('Epochs', fontsize=24)
        # ax.set_ylabel('Training Loss', fontsize=24)
        ax.set_ylabel('Loss / Accuracy', fontsize=24)
        
        # Set axis colors
        # ax.tick_params(axis='y', labelcolor=loss_color)
        # ax2.tick_params(axis='y', labelcolor=val_acc_color)
        
        # Configure grid and limits
        ax.grid(True, linestyle='--', alpha=0.3, axis='x')
        ax2.grid(True, linestyle='--', alpha=0.3, axis='y')
        
        ax.set_ylim(bottom=0)
        # ax2.set_ylim(0, 1.05)
        

    # Add common legend
    fig.legend(handles=legend_elements, loc='center', 
               ncol=4, fontsize=24, framealpha=0.9)
    
    # Adjust layout
    plt.tight_layout(pad=4.0, w_pad=3.0, h_pad=4.0)
    fig.subplots_adjust(bottom=0.1)  # Make space for legend
    
    # Save high-resolution figures
    plt.savefig(f'{fig_name}.pdf', dpi=300, bbox_inches='tight')
    plt.savefig(f'{fig_name}.png', dpi=300, bbox_inches='tight')
    plt.show()
    plt.close()

# %%
# %%
plot_cv_results(all_results, all_losses, fig_name="fig_cross_validation_summary")
