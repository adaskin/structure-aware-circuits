# %%
import pennylane as qml
import numpy as np
from math import ceil, log2

import torch
import torch.nn as nn
from torch.utils.data import DataLoader, TensorDataset
from schmidt_decomposition import SchmidtDecomposition


# -----------------------------------------------------------------------------
# 2) Quantum circuit module - FIXED TENSOR HANDLING
# -----------------------------------------------------------------------------
class SchmidtQuantumCircuit(nn.Module):
    def __init__(
        self,
        n_qubits: int,
        n_terms: int,
        init_terms: list = None,
        n_ancilla_layers: int = 2,
    ):
        super().__init__()
        self.n_qubits = n_qubits
        self.n_terms = n_terms
        self.n_ancilla = ceil(log2(n_terms)) if n_terms > 1 else 0
        self.n_ancilla_layers = n_ancilla_layers

        # Ancilla rotation parameters
        if self.n_ancilla > 0:
            num_ancilla_params = self.n_ancilla + max(0, self.n_ancilla - 1)
            self.ancilla_params = nn.Parameter(
                torch.randn(self.n_ancilla_layers * num_ancilla_params)
            )
        else:
            self.ancilla_params = None

        # Data-qubit parameters - now with optional Schmidt initialization
        self.unitary_params = nn.ParameterList()

        # # Initialize from Schmidt decomposition if provided
        # # We did not observe any performance improvement from this!
        # # maybe the angle computations for also coefficients would make better!
        # if init_terms:

        #     for k in range(min(n_terms, len(init_terms))):
        #         term_angles = []
        #         for vector in init_terms[k]:
        #             angle = SchmidtDecomposition.vector_to_angle(vector)
        #             term_angles.append(angle)
        #         # Initialize parameter with Schmidt-derived angles
        #         self.unitary_params.append(
        #             nn.Parameter(torch.tensor(term_angles, dtype=torch.float32)))

        #     # Initialize remaining terms randomly
        #     for _ in range(n_terms - len(init_terms)):
        #         print("herrrrr")
        #         self.unitary_params.append(
        #             nn.Parameter(torch.randn(self.n_qubits)))
        # else:
        # All random initialization
        for _ in range(n_terms):
            self.unitary_params.append(nn.Parameter(torch.randn(self.n_qubits)))

        self.dev = qml.device("lightning.qubit", wires=self.n_ancilla + self.n_qubits)
        self.qnode = self.create_qnode()

    def create_qnode(self):
        @qml.qnode(self.dev, interface="torch")
        def circuit(features):
            # Ancilla preparation
            if self.n_ancilla > 0:
                p = 0
                for l in range(self.n_ancilla_layers):
                    for i in range(self.n_ancilla):
                        qml.RY(self.ancilla_params[p], wires=i)
                        p += 1
                    for i in range(self.n_ancilla - 1):
                        qml.CRY(self.ancilla_params[p], wires=[i, i + 1])
                        p += 1

            # Embed input data
            data_wires = list(range(self.n_ancilla, self.n_ancilla + self.n_qubits))
            qml.AmplitudeEmbedding(features=features, wires=data_wires, normalize=True)

            # Apply parameterized unitaries
            ctrl_qubits = list(range(self.n_ancilla))
            if self.n_ancilla == 0:
                for q in range(self.n_qubits):
                    qml.RY(self.unitary_params[0][q], wires=q + self.n_ancilla)
            else:
                for k in range(self.n_terms):
                    ctrl_bin_values = bin(k)[2:].zfill(self.n_ancilla)
                    ctrl_int_values = [int(a) for a in list(ctrl_bin_values)]
                    for q in range(self.n_qubits):
                        qml.ctrl(qml.RY, ctrl_qubits, control_values=ctrl_int_values)(
                            self.unitary_params[k][q], wires=q + self.n_ancilla
                        )

            return [qml.expval(qml.PauliZ(w)) for w in data_wires]

        return circuit

    def forward(self, x: torch.Tensor):
        # x: [batch, features]
        # Process each sample individually
        return x.float() # for only classical
        results = []
        for sample in x:
            results.append(torch.Tensor(self.qnode(sample)).float())
        return torch.stack(results)


# -----------------------------------------------------------------------------
# 3) Hybrid classifier
# -----------------------------------------------------------------------------
class HybridModel(nn.Module):
    def __init__(
        self,
        n_qubits: int,
        data_mean: np.ndarray,
        output_dim: int = 1,
        schmidt_threshold: float = 0.1,
        hidden_dims=[64, 32],
        dropout_prob=0.25,
        min_terms=1 #min schmidt terms, min ancilla
    ):
        super().__init__()
        # Schmidt decomposition on the mean
        sd = SchmidtDecomposition(threshold=schmidt_threshold)
        terms, _ = sd.flatten_decomposition(data_mean)
        n_terms = len(terms)
        if n_terms == 1:
            n_terms = min_terms
        self.qc = SchmidtQuantumCircuit(n_qubits, n_terms, terms)
        total_wires = n_qubits + self.qc.n_ancilla
        print(
            f"number of schmidt terms: {n_terms},"
            f"number of ancilla qubits:{self.qc.n_ancilla}"
        )

        # classical head takes exactly n_qubits inputs
        layers = []
        input_dim = 2**n_qubits
        for h in hidden_dims:
            layers += [
                nn.Linear(input_dim, h),
                nn.BatchNorm1d(h),
                nn.ReLU(),
                nn.Dropout(dropout_prob),
            ]
            input_dim = h

        # final classifier
        layers.append(nn.Linear(input_dim, output_dim))
        self.classical_net = nn.Sequential(*layers)

    def forward(self, x: torch.Tensor):
        # x: [batch, features]
        q_out = self.qc(x)
        return self.classical_net(q_out)


# -----------------------------------------------------------------------------
# K-Fold cross-validation driver
# -----------------------------------------------------------------------------
from sklearn.model_selection import train_test_split
from sklearn.model_selection import StratifiedKFold, train_test_split


def cross_validate(
    X,
    y,
    n_qubits,
    n_classes,
    schmidt_threshold=0.1,
    hidden_dims=[64,32],
    max_terms=4, #not used
    min_terms=1,
    epochs=50,
    lr=0.05,
    batch_size=32,
    k_folds=5,
    val_frac=0.2,
    dataset_name="",
    seed=42,
):
    # reproducibility & device
    torch.manual_seed(seed)
    np.random.seed(seed)
    device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

    skf = StratifiedKFold(n_splits=k_folds, shuffle=True, random_state=seed)
    fold_accuracies = []
    losses = {}
    for fold, (train_idx, test_idx) in enumerate(skf.split(X, y), 1):
        print(f"\n=== Dataset={dataset_name} | Fold {fold}/{k_folds} ===")

        # Split out test fold
        X_train_full, y_train_full = X[train_idx], y[train_idx]
        X_test, y_test = X[test_idx], y[test_idx]

        # Further carve out a validation set from the training folds
        X_train, X_val, y_train, y_val = train_test_split(
            X_train_full,
            y_train_full,
            test_size=val_frac,
            random_state=seed+fold,
            stratify=y_train_full,
        )

        # DataLoaders
        train_loader = DataLoader(
            TensorDataset(
                torch.tensor(X_train, dtype=torch.float64),
                torch.tensor(y_train, dtype=torch.long),
            ),
            batch_size=batch_size,
            shuffle=True,
        )
        val_loader = DataLoader(
            TensorDataset(
                torch.tensor(X_val, dtype=torch.float64),
                torch.tensor(y_val, dtype=torch.long),
            ),
            batch_size=batch_size,
        )
        test_loader = DataLoader(
            TensorDataset(
                torch.tensor(X_test, dtype=torch.float64),
                torch.tensor(y_test, dtype=torch.long),
            ),
            batch_size=batch_size,
        )

        # Precompute mean vector for Schmidt decomposition
        mean_vec = X_train.mean(axis=0)
        mean_vec /= np.linalg.norm(mean_vec)
        
        # Initialize model, optimizer, scheduler, loss
        model = HybridModel(
            n_qubits,
            mean_vec,
            output_dim=n_classes,
            schmidt_threshold=schmidt_threshold,
            hidden_dims=hidden_dims,
            min_terms=min_terms,
        )
        opt = torch.optim.AdamW(model.parameters(), lr=lr, weight_decay=1e-4)
        sched = torch.optim.lr_scheduler.CosineAnnealingLR(opt, T_max=epochs)
        loss_fn = nn.CrossEntropyLoss()
        print(f"Using {device} for training")
        print(f"Model: {model}")
        print(
            f"Number of parameters: {sum(p.numel() for p in model.parameters() if p.requires_grad)}"
        )
        print(f"Optimizer: {opt}")
        print(f"Loss Function: {loss_fn}")
        best_val_acc = 0.0
        best_state = None
        losses[fold] = []
        # ----- Training Loop -----
        for ep in range(1, epochs + 1):
            model.train()
            running_loss = 0.0
            correct, total = 0, 0

            for xb, yb in train_loader:
                opt.zero_grad()
                preds = model(xb)
 
                loss = loss_fn(preds, yb)
                loss.backward()
                opt.step()

                running_loss += loss.item() * xb.size(0)
                correct += (preds.argmax(1) == yb).sum().item()
                total += xb.size(0)

            sched.step()
            train_acc = correct / total

            # ----- Validation -----
            model.eval()
            v_corr, v_tot = 0, 0
            with torch.no_grad():
                for xb, yb in val_loader:
                    preds = model(xb)
                    v_corr += (preds.argmax(1) == yb).sum().item()
                    v_tot += xb.size(0)
            val_acc = v_corr / v_tot

            if val_acc > best_val_acc:
                best_val_acc = val_acc
                best_state = model.state_dict()

            if ep % 10 == 0 or ep == 1:
                lr_val = sched.get_last_lr()[0]
                print(
                    f" Ep{ep:2d}  loss={(running_loss/total):.4f}  "
                    f"train_acc={train_acc:.3f}  val_acc={val_acc:.3f}  lr={lr_val:.6f}"
                )
            losses[fold].append([(running_loss / total), train_acc, val_acc])
        # ----- Test Evaluation -----
        model.load_state_dict(best_state)
        model.eval()
        t_corr, t_tot = 0, 0
        with torch.no_grad():
            for xb, yb in test_loader:
                preds = model(xb)
                t_corr += (preds.argmax(1) == yb).sum().item()
                t_tot += xb.size(0)
        test_acc = t_corr / t_tot

        print(f" >>> Fold {fold} Test Accuracy: {test_acc:.3f}")
        fold_accuracies.append(test_acc)

    mean_acc = np.mean(fold_accuracies)
    std_acc = np.std(fold_accuracies)
    print(f"\n>>> {dataset_name} CV Results: mean={mean_acc:.3f}, std={std_acc:.3f}\n")
    return fold_accuracies, losses




# if __name__ == "__main__":
from data_loaders import load_dataset

datasets = [
    "iris",
    "wine",
    "breast_cancer",
    "ionosphere",
    "covtype",
    "digits",
]
threshold = 0.3
sd = SchmidtDecomposition(threshold=threshold)
all_results = {}
all_losses = {}
for ds in datasets:
    X, y, n_qubits, n_classes = load_dataset(ds)
    print(f"Reducing data dimension of {ds} by using Schmidt decompostion")
    for i in range(len(X)):
        X[i] = sd.compute_decomposition(X[i])



    print(f"\n=== Dataset={ds}")
    accs, losses = cross_validate(
        X,
        y,
        n_qubits,
        n_classes,
        hidden_dims=[64,32],
        schmidt_threshold=0.3,
        min_terms=1,
        epochs=200,
        lr=0.05,
        batch_size=32,
        k_folds=5,
        val_frac=0.2,
        seed=42,
        dataset_name=ds,
    )
    all_results[ds] = accs
    all_losses[ds] = losses
    print("=" * 40)
    print("=" * 40)
# Summary
print("=== Final Summary ===")
for ds, accs in all_results.items():
    print(
        f"{ds:15} folds={len(accs)}  mean_acc={np.mean(accs):.3f}  std={np.std(accs):.3f}"
    )


# %%
# Out:
# Reducing data dimension of iris by using Schmidt decompostion
#
# === Dataset=iris
#
# === Dataset=iris | Fold 1/5 ===
# number of schmidt terms: 1,number of ancilla qubits:0
# <ipython-input-1-18bb75006c8e>:344: ComplexWarning: Casting complex values to real discards the imaginary part
#   X[i] = sd.compute_decomposition(X[i])
# Using cpu for training
# Model: HybridModel(
#   (qc): SchmidtQuantumCircuit(
#     (unitary_params): ParameterList(  (0): Parameter containing: [torch.float32 of size 2])
#   )
#   (classical_net): Sequential(
#     (0): Linear(in_features=4, out_features=64, bias=True)
#     (1): BatchNorm1d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): ReLU()
#     (3): Dropout(p=0.25, inplace=False)
#     (4): Linear(in_features=64, out_features=32, bias=True)
#     (5): BatchNorm1d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (6): ReLU()
#     (7): Dropout(p=0.25, inplace=False)
#     (8): Linear(in_features=32, out_features=3, bias=True)
#   )
# )
# Number of parameters: 2693
# Optimizer: AdamW (
# Parameter Group 0
#     amsgrad: False
#     betas: (0.9, 0.999)
#     capturable: False
#     decoupled_weight_decay: True
#     differentiable: False
#     eps: 1e-08
#     foreach: None
#     fused: None
#     initial_lr: 0.05
#     lr: 0.05
#     maximize: False
#     weight_decay: 0.0001
# )
# Loss Function: CrossEntropyLoss()
#  Ep 1  loss=0.8547  train_acc=0.562  val_acc=0.667  lr=0.049997
#  Ep10  loss=0.1065  train_acc=0.948  val_acc=0.667  lr=0.049692
#  Ep20  loss=0.1281  train_acc=0.948  val_acc=0.792  lr=0.048776
#  Ep30  loss=0.1070  train_acc=0.948  val_acc=0.833  lr=0.047275
#  Ep40  loss=0.1219  train_acc=0.938  val_acc=0.917  lr=0.045225
#  Ep50  loss=0.0869  train_acc=0.938  val_acc=0.917  lr=0.042678
#  Ep60  loss=0.0865  train_acc=0.979  val_acc=0.917  lr=0.039695
#  Ep70  loss=0.0815  train_acc=0.958  val_acc=0.792  lr=0.036350
#  Ep80  loss=0.2169  train_acc=0.938  val_acc=0.917  lr=0.032725
#  Ep90  loss=0.1127  train_acc=0.958  val_acc=0.875  lr=0.028911
#  Ep100  loss=0.1226  train_acc=0.927  val_acc=0.917  lr=0.025000
#  Ep110  loss=0.0775  train_acc=0.958  val_acc=0.875  lr=0.021089
#  Ep120  loss=0.1309  train_acc=0.927  val_acc=0.917  lr=0.017275
#  Ep130  loss=0.2237  train_acc=0.917  val_acc=0.917  lr=0.013650
#  Ep140  loss=0.0854  train_acc=0.958  val_acc=0.917  lr=0.010305
#  Ep150  loss=0.1327  train_acc=0.927  val_acc=0.917  lr=0.007322
#  Ep160  loss=0.1088  train_acc=0.958  val_acc=0.875  lr=0.004775
#  Ep170  loss=0.0850  train_acc=0.948  val_acc=0.917  lr=0.002725
#  Ep180  loss=0.1238  train_acc=0.958  val_acc=0.917  lr=0.001224
#  Ep190  loss=0.0742  train_acc=0.979  val_acc=0.917  lr=0.000308
#  Ep200  loss=0.1259  train_acc=0.938  val_acc=0.875  lr=0.000000
#  >>> Fold 1 Test Accuracy: 1.000
#
# === Dataset=iris | Fold 2/5 ===
# number of schmidt terms: 1,number of ancilla qubits:0
# Using cpu for training
# Model: HybridModel(
#   (qc): SchmidtQuantumCircuit(
#     (unitary_params): ParameterList(  (0): Parameter containing: [torch.float32 of size 2])
#   )
#   (classical_net): Sequential(
#     (0): Linear(in_features=4, out_features=64, bias=True)
#     (1): BatchNorm1d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): ReLU()
#     (3): Dropout(p=0.25, inplace=False)
#     (4): Linear(in_features=64, out_features=32, bias=True)
#     (5): BatchNorm1d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (6): ReLU()
#     (7): Dropout(p=0.25, inplace=False)
#     (8): Linear(in_features=32, out_features=3, bias=True)
#   )
# )
# Number of parameters: 2693
# Optimizer: AdamW (
# Parameter Group 0
#     amsgrad: False
#     betas: (0.9, 0.999)
#     capturable: False
#     decoupled_weight_decay: True
#     differentiable: False
#     eps: 1e-08
#     foreach: None
#     fused: None
#     initial_lr: 0.05
#     lr: 0.05
#     maximize: False
#     weight_decay: 0.0001
# )
# Loss Function: CrossEntropyLoss()
#  Ep 1  loss=0.7251  train_acc=0.656  val_acc=0.667  lr=0.049997
#  Ep10  loss=0.1950  train_acc=0.896  val_acc=0.667  lr=0.049692
#  Ep20  loss=0.1526  train_acc=0.927  val_acc=0.958  lr=0.048776
#  Ep30  loss=0.1258  train_acc=0.948  val_acc=0.875  lr=0.047275
#  Ep40  loss=0.1829  train_acc=0.938  val_acc=0.958  lr=0.045225
#  Ep50  loss=0.1849  train_acc=0.938  val_acc=0.875  lr=0.042678
#  Ep60  loss=0.1917  train_acc=0.927  val_acc=1.000  lr=0.039695
#  Ep70  loss=0.2672  train_acc=0.896  val_acc=1.000  lr=0.036350
#  Ep80  loss=0.1614  train_acc=0.927  val_acc=0.708  lr=0.032725
#  Ep90  loss=0.2473  train_acc=0.896  val_acc=1.000  lr=0.028911
#  Ep100  loss=0.1403  train_acc=0.917  val_acc=1.000  lr=0.025000
#  Ep110  loss=0.1586  train_acc=0.917  val_acc=1.000  lr=0.021089
#  Ep120  loss=0.1239  train_acc=0.948  val_acc=1.000  lr=0.017275
#  Ep130  loss=0.1407  train_acc=0.958  val_acc=0.958  lr=0.013650
#  Ep140  loss=0.2087  train_acc=0.906  val_acc=1.000  lr=0.010305
#  Ep150  loss=0.1667  train_acc=0.948  val_acc=1.000  lr=0.007322
#  Ep160  loss=0.1323  train_acc=0.958  val_acc=1.000  lr=0.004775
#  Ep170  loss=0.1219  train_acc=0.948  val_acc=1.000  lr=0.002725
#  Ep180  loss=0.1575  train_acc=0.938  val_acc=1.000  lr=0.001224
#  Ep190  loss=0.1162  train_acc=0.958  val_acc=1.000  lr=0.000308
#  Ep200  loss=0.1887  train_acc=0.906  val_acc=1.000  lr=0.000000
#  >>> Fold 2 Test Accuracy: 0.967
#
# === Dataset=iris | Fold 3/5 ===
# number of schmidt terms: 1,number of ancilla qubits:0
# Using cpu for training
# Model: HybridModel(
#   (qc): SchmidtQuantumCircuit(
#     (unitary_params): ParameterList(  (0): Parameter containing: [torch.float32 of size 2])
#   )
#   (classical_net): Sequential(
#     (0): Linear(in_features=4, out_features=64, bias=True)
#     (1): BatchNorm1d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): ReLU()
#     (3): Dropout(p=0.25, inplace=False)
#     (4): Linear(in_features=64, out_features=32, bias=True)
#     (5): BatchNorm1d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (6): ReLU()
#     (7): Dropout(p=0.25, inplace=False)
#     (8): Linear(in_features=32, out_features=3, bias=True)
#   )
# )
# Number of parameters: 2693
# Optimizer: AdamW (
# Parameter Group 0
#     amsgrad: False
#     betas: (0.9, 0.999)
#     capturable: False
#     decoupled_weight_decay: True
#     differentiable: False
#     eps: 1e-08
#     foreach: None
#     fused: None
#     initial_lr: 0.05
#     lr: 0.05
#     maximize: False
#     weight_decay: 0.0001
# )
# Loss Function: CrossEntropyLoss()
#  Ep 1  loss=0.7644  train_acc=0.708  val_acc=0.333  lr=0.049997
#  Ep10  loss=0.1388  train_acc=0.938  val_acc=0.667  lr=0.049692
#  Ep20  loss=0.1242  train_acc=0.969  val_acc=0.958  lr=0.048776
#  Ep30  loss=0.0715  train_acc=0.969  val_acc=1.000  lr=0.047275
#  Ep40  loss=0.1191  train_acc=0.927  val_acc=1.000  lr=0.045225
#  Ep50  loss=0.1127  train_acc=0.958  val_acc=0.750  lr=0.042678
#  Ep60  loss=0.1099  train_acc=0.958  val_acc=0.958  lr=0.039695
#  Ep70  loss=0.0992  train_acc=0.969  val_acc=1.000  lr=0.036350
#  Ep80  loss=0.1349  train_acc=0.938  val_acc=1.000  lr=0.032725
#  Ep90  loss=0.0622  train_acc=0.979  val_acc=0.792  lr=0.028911
#  Ep100  loss=0.1532  train_acc=0.948  val_acc=1.000  lr=0.025000
#  Ep110  loss=0.1723  train_acc=0.917  val_acc=1.000  lr=0.021089
#  Ep120  loss=0.0854  train_acc=0.969  val_acc=1.000  lr=0.017275
#  Ep130  loss=0.0708  train_acc=0.990  val_acc=1.000  lr=0.013650
#  Ep140  loss=0.0695  train_acc=0.969  val_acc=1.000  lr=0.010305
#  Ep150  loss=0.0646  train_acc=0.979  val_acc=1.000  lr=0.007322
#  Ep160  loss=0.0942  train_acc=0.948  val_acc=1.000  lr=0.004775
#  Ep170  loss=0.1089  train_acc=0.948  val_acc=1.000  lr=0.002725
#  Ep180  loss=0.0725  train_acc=0.958  val_acc=1.000  lr=0.001224
#  Ep190  loss=0.0509  train_acc=0.979  val_acc=1.000  lr=0.000308
#  Ep200  loss=0.0932  train_acc=0.969  val_acc=1.000  lr=0.000000
#  >>> Fold 3 Test Accuracy: 0.867
#
# === Dataset=iris | Fold 4/5 ===
# number of schmidt terms: 1,number of ancilla qubits:0
# Using cpu for training
# Model: HybridModel(
#   (qc): SchmidtQuantumCircuit(
#     (unitary_params): ParameterList(  (0): Parameter containing: [torch.float32 of size 2])
#   )
#   (classical_net): Sequential(
#     (0): Linear(in_features=4, out_features=64, bias=True)
#     (1): BatchNorm1d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): ReLU()
#     (3): Dropout(p=0.25, inplace=False)
#     (4): Linear(in_features=64, out_features=32, bias=True)
#     (5): BatchNorm1d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (6): ReLU()
#     (7): Dropout(p=0.25, inplace=False)
#     (8): Linear(in_features=32, out_features=3, bias=True)
#   )
# )
# Number of parameters: 2693
# Optimizer: AdamW (
# Parameter Group 0
#     amsgrad: False
#     betas: (0.9, 0.999)
#     capturable: False
#     decoupled_weight_decay: True
#     differentiable: False
#     eps: 1e-08
#     foreach: None
#     fused: None
#     initial_lr: 0.05
#     lr: 0.05
#     maximize: False
#     weight_decay: 0.0001
# )
# Loss Function: CrossEntropyLoss()
#  Ep 1  loss=0.8062  train_acc=0.583  val_acc=0.333  lr=0.049997
#  Ep10  loss=0.1965  train_acc=0.927  val_acc=0.667  lr=0.049692
#  Ep20  loss=0.1144  train_acc=0.958  val_acc=0.917  lr=0.048776
#  Ep30  loss=0.1487  train_acc=0.938  val_acc=0.958  lr=0.047275
#  Ep40  loss=0.1448  train_acc=0.948  val_acc=0.958  lr=0.045225
#  Ep50  loss=0.1450  train_acc=0.969  val_acc=0.958  lr=0.042678
#  Ep60  loss=0.1098  train_acc=0.958  val_acc=0.917  lr=0.039695
#  Ep70  loss=0.1732  train_acc=0.927  val_acc=0.750  lr=0.036350
#  Ep80  loss=0.1788  train_acc=0.906  val_acc=0.958  lr=0.032725
#  Ep90  loss=0.1179  train_acc=0.958  val_acc=0.917  lr=0.028911
#  Ep100  loss=0.1384  train_acc=0.948  val_acc=0.833  lr=0.025000
#  Ep110  loss=0.1161  train_acc=0.948  val_acc=0.917  lr=0.021089
#  Ep120  loss=0.1028  train_acc=0.969  val_acc=0.917  lr=0.017275
#  Ep130  loss=0.1026  train_acc=0.979  val_acc=0.958  lr=0.013650
#  Ep140  loss=0.1265  train_acc=0.958  val_acc=0.958  lr=0.010305
#  Ep150  loss=0.1072  train_acc=0.969  val_acc=0.958  lr=0.007322
#  Ep160  loss=0.1366  train_acc=0.938  val_acc=0.958  lr=0.004775
#  Ep170  loss=0.1365  train_acc=0.958  val_acc=0.958  lr=0.002725
#  Ep180  loss=0.1300  train_acc=0.958  val_acc=0.917  lr=0.001224
#  Ep190  loss=0.1219  train_acc=0.948  val_acc=0.917  lr=0.000308
#  Ep200  loss=0.0961  train_acc=0.969  val_acc=0.917  lr=0.000000
#  >>> Fold 4 Test Accuracy: 0.933
#
# === Dataset=iris | Fold 5/5 ===
# number of schmidt terms: 1,number of ancilla qubits:0
# Using cpu for training
# Model: HybridModel(
#   (qc): SchmidtQuantumCircuit(
#     (unitary_params): ParameterList(  (0): Parameter containing: [torch.float32 of size 2])
#   )
#   (classical_net): Sequential(
#     (0): Linear(in_features=4, out_features=64, bias=True)
#     (1): BatchNorm1d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): ReLU()
#     (3): Dropout(p=0.25, inplace=False)
#     (4): Linear(in_features=64, out_features=32, bias=True)
#     (5): BatchNorm1d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (6): ReLU()
#     (7): Dropout(p=0.25, inplace=False)
#     (8): Linear(in_features=32, out_features=3, bias=True)
#   )
# )
# Number of parameters: 2693
# Optimizer: AdamW (
# Parameter Group 0
#     amsgrad: False
#     betas: (0.9, 0.999)
#     capturable: False
#     decoupled_weight_decay: True
#     differentiable: False
#     eps: 1e-08
#     foreach: None
#     fused: None
#     initial_lr: 0.05
#     lr: 0.05
#     maximize: False
#     weight_decay: 0.0001
# )
# Loss Function: CrossEntropyLoss()
#  Ep 1  loss=0.7418  train_acc=0.729  val_acc=0.333  lr=0.049997
#  Ep10  loss=0.2078  train_acc=0.917  val_acc=0.667  lr=0.049692
#  Ep20  loss=0.1730  train_acc=0.938  val_acc=0.708  lr=0.048776
#  Ep30  loss=0.2248  train_acc=0.917  val_acc=0.792  lr=0.047275
#  Ep40  loss=0.1443  train_acc=0.917  val_acc=0.708  lr=0.045225
#  Ep50  loss=0.1348  train_acc=0.938  val_acc=0.958  lr=0.042678
#  Ep60  loss=0.2189  train_acc=0.906  val_acc=0.833  lr=0.039695
#  Ep70  loss=0.2455  train_acc=0.875  val_acc=0.833  lr=0.036350
#  Ep80  loss=0.1296  train_acc=0.948  val_acc=0.667  lr=0.032725
#  Ep90  loss=0.1794  train_acc=0.917  val_acc=1.000  lr=0.028911
#  Ep100  loss=0.1352  train_acc=0.969  val_acc=0.833  lr=0.025000
#  Ep110  loss=0.1596  train_acc=0.938  val_acc=0.958  lr=0.021089
#  Ep120  loss=0.1400  train_acc=0.938  val_acc=1.000  lr=0.017275
#  Ep130  loss=0.1167  train_acc=0.958  val_acc=0.917  lr=0.013650
#  Ep140  loss=0.1306  train_acc=0.948  val_acc=1.000  lr=0.010305
#  Ep150  loss=0.1357  train_acc=0.938  val_acc=1.000  lr=0.007322
#  Ep160  loss=0.1375  train_acc=0.948  val_acc=1.000  lr=0.004775
#  Ep170  loss=0.1104  train_acc=0.969  val_acc=1.000  lr=0.002725
#  Ep180  loss=0.1385  train_acc=0.938  val_acc=0.958  lr=0.001224
#  Ep190  loss=0.1314  train_acc=0.958  val_acc=1.000  lr=0.000308
#  Ep200  loss=0.1002  train_acc=0.958  val_acc=1.000  lr=0.000000
#  >>> Fold 5 Test Accuracy: 0.967
#
# >>> iris CV Results: mean=0.947, std=0.045
#
# ========================================
# ========================================
# dimension 13, padding with zeros for 16
# Reducing data dimension of wine by using Schmidt decompostion
#
# === Dataset=wine
#
# === Dataset=wine | Fold 1/5 ===
# number of schmidt terms: 1,number of ancilla qubits:0
# Using cpu for training
# Model: HybridModel(
#   (qc): SchmidtQuantumCircuit(
#     (unitary_params): ParameterList(  (0): Parameter containing: [torch.float32 of size 4])
#   )
#   (classical_net): Sequential(
#     (0): Linear(in_features=16, out_features=64, bias=True)
#     (1): BatchNorm1d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): ReLU()
#     (3): Dropout(p=0.25, inplace=False)
#     (4): Linear(in_features=64, out_features=32, bias=True)
#     (5): BatchNorm1d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (6): ReLU()
#     (7): Dropout(p=0.25, inplace=False)
#     (8): Linear(in_features=32, out_features=3, bias=True)
#   )
# )
# Number of parameters: 3463
# Optimizer: AdamW (
# Parameter Group 0
#     amsgrad: False
#     betas: (0.9, 0.999)
#     capturable: False
#     decoupled_weight_decay: True
#     differentiable: False
#     eps: 1e-08
#     foreach: None
#     fused: None
#     initial_lr: 0.05
#     lr: 0.05
#     maximize: False
#     weight_decay: 0.0001
# )
# Loss Function: CrossEntropyLoss()
#  Ep 1  loss=0.9055  train_acc=0.531  val_acc=0.517  lr=0.049997
#  Ep10  loss=0.7004  train_acc=0.699  val_acc=0.414  lr=0.049692
# <ipython-input-1-18bb75006c8e>:344: ComplexWarning: Casting complex values to real discards the imaginary part
#   X[i] = sd.compute_decomposition(X[i])
#  Ep20  loss=0.5933  train_acc=0.664  val_acc=0.414  lr=0.048776
#  Ep30  loss=0.5609  train_acc=0.681  val_acc=0.552  lr=0.047275
#  Ep40  loss=0.4837  train_acc=0.735  val_acc=0.310  lr=0.045225
#  Ep50  loss=0.6190  train_acc=0.770  val_acc=0.310  lr=0.042678
#  Ep60  loss=0.4373  train_acc=0.814  val_acc=0.690  lr=0.039695
#  Ep70  loss=0.4592  train_acc=0.796  val_acc=0.310  lr=0.036350
#  Ep80  loss=0.4124  train_acc=0.823  val_acc=0.655  lr=0.032725
#  Ep90  loss=0.3452  train_acc=0.850  val_acc=0.310  lr=0.028911
#  Ep100  loss=0.4311  train_acc=0.814  val_acc=0.517  lr=0.025000
#  Ep110  loss=0.3775  train_acc=0.823  val_acc=0.414  lr=0.021089
#  Ep120  loss=0.4160  train_acc=0.858  val_acc=0.414  lr=0.017275
#  Ep130  loss=0.2989  train_acc=0.876  val_acc=0.552  lr=0.013650
#  Ep140  loss=0.3603  train_acc=0.858  val_acc=0.414  lr=0.010305
#  Ep150  loss=0.3880  train_acc=0.788  val_acc=0.552  lr=0.007322
#  Ep160  loss=0.3435  train_acc=0.894  val_acc=0.448  lr=0.004775
#  Ep170  loss=0.2673  train_acc=0.876  val_acc=0.552  lr=0.002725
#  Ep180  loss=0.3257  train_acc=0.823  val_acc=0.862  lr=0.001224
#  Ep190  loss=0.3012  train_acc=0.876  val_acc=0.793  lr=0.000308
#  Ep200  loss=0.3642  train_acc=0.841  val_acc=0.828  lr=0.000000
#  >>> Fold 1 Test Accuracy: 0.861
#
# === Dataset=wine | Fold 2/5 ===
# number of schmidt terms: 1,number of ancilla qubits:0
# Using cpu for training
# Model: HybridModel(
#   (qc): SchmidtQuantumCircuit(
#     (unitary_params): ParameterList(  (0): Parameter containing: [torch.float32 of size 4])
#   )
#   (classical_net): Sequential(
#     (0): Linear(in_features=16, out_features=64, bias=True)
#     (1): BatchNorm1d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): ReLU()
#     (3): Dropout(p=0.25, inplace=False)
#     (4): Linear(in_features=64, out_features=32, bias=True)
#     (5): BatchNorm1d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (6): ReLU()
#     (7): Dropout(p=0.25, inplace=False)
#     (8): Linear(in_features=32, out_features=3, bias=True)
#   )
# )
# Number of parameters: 3463
# Optimizer: AdamW (
# Parameter Group 0
#     amsgrad: False
#     betas: (0.9, 0.999)
#     capturable: False
#     decoupled_weight_decay: True
#     differentiable: False
#     eps: 1e-08
#     foreach: None
#     fused: None
#     initial_lr: 0.05
#     lr: 0.05
#     maximize: False
#     weight_decay: 0.0001
# )
# Loss Function: CrossEntropyLoss()
#  Ep 1  loss=1.0404  train_acc=0.496  val_acc=0.414  lr=0.049997
#  Ep10  loss=0.5894  train_acc=0.735  val_acc=0.414  lr=0.049692
#  Ep20  loss=0.5587  train_acc=0.788  val_acc=0.621  lr=0.048776
#  Ep30  loss=0.5107  train_acc=0.814  val_acc=0.414  lr=0.047275
#  Ep40  loss=0.5148  train_acc=0.788  val_acc=0.414  lr=0.045225
#  Ep50  loss=0.4266  train_acc=0.832  val_acc=0.483  lr=0.042678
#  Ep60  loss=0.6073  train_acc=0.761  val_acc=0.414  lr=0.039695
#  Ep70  loss=0.4128  train_acc=0.814  val_acc=0.414  lr=0.036350
#  Ep80  loss=0.4678  train_acc=0.796  val_acc=0.414  lr=0.032725
#  Ep90  loss=0.4236  train_acc=0.814  val_acc=0.414  lr=0.028911
#  Ep100  loss=0.4079  train_acc=0.841  val_acc=0.448  lr=0.025000
#  Ep110  loss=0.3534  train_acc=0.850  val_acc=0.414  lr=0.021089
#  Ep120  loss=0.3228  train_acc=0.876  val_acc=0.414  lr=0.017275
#  Ep130  loss=0.3632  train_acc=0.841  val_acc=0.586  lr=0.013650
#  Ep140  loss=0.3258  train_acc=0.876  val_acc=0.414  lr=0.010305
#  Ep150  loss=0.3153  train_acc=0.867  val_acc=0.414  lr=0.007322
#  Ep160  loss=0.3734  train_acc=0.858  val_acc=0.483  lr=0.004775
#  Ep170  loss=0.2493  train_acc=0.885  val_acc=0.655  lr=0.002725
#  Ep180  loss=0.2834  train_acc=0.858  val_acc=0.862  lr=0.001224
#  Ep190  loss=0.3141  train_acc=0.885  val_acc=0.931  lr=0.000308
#  Ep200  loss=0.3349  train_acc=0.814  val_acc=0.966  lr=0.000000
#  >>> Fold 2 Test Accuracy: 0.917
#
# === Dataset=wine | Fold 3/5 ===
# number of schmidt terms: 1,number of ancilla qubits:0
# Using cpu for training
# Model: HybridModel(
#   (qc): SchmidtQuantumCircuit(
#     (unitary_params): ParameterList(  (0): Parameter containing: [torch.float32 of size 4])
#   )
#   (classical_net): Sequential(
#     (0): Linear(in_features=16, out_features=64, bias=True)
#     (1): BatchNorm1d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): ReLU()
#     (3): Dropout(p=0.25, inplace=False)
#     (4): Linear(in_features=64, out_features=32, bias=True)
#     (5): BatchNorm1d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (6): ReLU()
#     (7): Dropout(p=0.25, inplace=False)
#     (8): Linear(in_features=32, out_features=3, bias=True)
#   )
# )
# Number of parameters: 3463
# Optimizer: AdamW (
# Parameter Group 0
#     amsgrad: False
#     betas: (0.9, 0.999)
#     capturable: False
#     decoupled_weight_decay: True
#     differentiable: False
#     eps: 1e-08
#     foreach: None
#     fused: None
#     initial_lr: 0.05
#     lr: 0.05
#     maximize: False
#     weight_decay: 0.0001
# )
# Loss Function: CrossEntropyLoss()
#  Ep 1  loss=0.8637  train_acc=0.540  val_acc=0.448  lr=0.049997
#  Ep10  loss=0.6017  train_acc=0.664  val_acc=0.414  lr=0.049692
#  Ep20  loss=0.5694  train_acc=0.708  val_acc=0.414  lr=0.048776
#  Ep30  loss=0.5569  train_acc=0.743  val_acc=0.448  lr=0.047275
#  Ep40  loss=0.5954  train_acc=0.752  val_acc=0.414  lr=0.045225
#  Ep50  loss=0.4803  train_acc=0.779  val_acc=0.448  lr=0.042678
#  Ep60  loss=0.4689  train_acc=0.805  val_acc=0.310  lr=0.039695
#  Ep70  loss=0.4171  train_acc=0.823  val_acc=0.414  lr=0.036350
#  Ep80  loss=0.3535  train_acc=0.823  val_acc=0.552  lr=0.032725
#  Ep90  loss=0.4582  train_acc=0.823  val_acc=0.448  lr=0.028911
#  Ep100  loss=0.3945  train_acc=0.796  val_acc=0.310  lr=0.025000
#  Ep110  loss=0.3243  train_acc=0.858  val_acc=0.276  lr=0.021089
#  Ep120  loss=0.2902  train_acc=0.876  val_acc=0.552  lr=0.017275
#  Ep130  loss=0.4637  train_acc=0.814  val_acc=0.586  lr=0.013650
#  Ep140  loss=0.2353  train_acc=0.876  val_acc=0.621  lr=0.010305
#  Ep150  loss=0.3107  train_acc=0.876  val_acc=0.586  lr=0.007322
#  Ep160  loss=0.2756  train_acc=0.894  val_acc=0.759  lr=0.004775
#  Ep170  loss=0.3312  train_acc=0.885  val_acc=0.655  lr=0.002725
#  Ep180  loss=0.2145  train_acc=0.885  val_acc=0.759  lr=0.001224
#  Ep190  loss=0.2770  train_acc=0.912  val_acc=0.793  lr=0.000308
#  Ep200  loss=0.1673  train_acc=0.929  val_acc=0.793  lr=0.000000
#  >>> Fold 3 Test Accuracy: 0.917
#
# === Dataset=wine | Fold 4/5 ===
# number of schmidt terms: 1,number of ancilla qubits:0
# Using cpu for training
# Model: HybridModel(
#   (qc): SchmidtQuantumCircuit(
#     (unitary_params): ParameterList(  (0): Parameter containing: [torch.float32 of size 4])
#   )
#   (classical_net): Sequential(
#     (0): Linear(in_features=16, out_features=64, bias=True)
#     (1): BatchNorm1d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): ReLU()
#     (3): Dropout(p=0.25, inplace=False)
#     (4): Linear(in_features=64, out_features=32, bias=True)
#     (5): BatchNorm1d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (6): ReLU()
#     (7): Dropout(p=0.25, inplace=False)
#     (8): Linear(in_features=32, out_features=3, bias=True)
#   )
# )
# Number of parameters: 3463
# Optimizer: AdamW (
# Parameter Group 0
#     amsgrad: False
#     betas: (0.9, 0.999)
#     capturable: False
#     decoupled_weight_decay: True
#     differentiable: False
#     eps: 1e-08
#     foreach: None
#     fused: None
#     initial_lr: 0.05
#     lr: 0.05
#     maximize: False
#     weight_decay: 0.0001
# )
# Loss Function: CrossEntropyLoss()
#  Ep 1  loss=0.9220  train_acc=0.553  val_acc=0.414  lr=0.049997
#  Ep10  loss=0.6146  train_acc=0.763  val_acc=0.414  lr=0.049692
#  Ep20  loss=0.5662  train_acc=0.746  val_acc=0.310  lr=0.048776
#  Ep30  loss=0.5067  train_acc=0.772  val_acc=0.448  lr=0.047275
#  Ep40  loss=0.4821  train_acc=0.763  val_acc=0.655  lr=0.045225
#  Ep50  loss=0.4504  train_acc=0.798  val_acc=0.345  lr=0.042678
#  Ep60  loss=0.3985  train_acc=0.833  val_acc=0.414  lr=0.039695
#  Ep70  loss=0.4014  train_acc=0.842  val_acc=0.414  lr=0.036350
#  Ep80  loss=0.3504  train_acc=0.860  val_acc=0.310  lr=0.032725
#  Ep90  loss=0.3194  train_acc=0.895  val_acc=0.310  lr=0.028911
#  Ep100  loss=0.5442  train_acc=0.833  val_acc=0.310  lr=0.025000
#  Ep110  loss=0.3500  train_acc=0.825  val_acc=0.448  lr=0.021089
#  Ep120  loss=0.3106  train_acc=0.833  val_acc=0.448  lr=0.017275
#  Ep130  loss=0.2579  train_acc=0.886  val_acc=0.517  lr=0.013650
#  Ep140  loss=0.2796  train_acc=0.860  val_acc=0.655  lr=0.010305
#  Ep150  loss=0.3757  train_acc=0.842  val_acc=0.483  lr=0.007322
#  Ep160  loss=0.2489  train_acc=0.860  val_acc=0.483  lr=0.004775
#  Ep170  loss=0.2370  train_acc=0.904  val_acc=0.862  lr=0.002725
#  Ep180  loss=0.2171  train_acc=0.904  val_acc=0.793  lr=0.001224
#  Ep190  loss=0.2153  train_acc=0.886  val_acc=0.862  lr=0.000308
#  Ep200  loss=0.2408  train_acc=0.886  val_acc=0.862  lr=0.000000
#  >>> Fold 4 Test Accuracy: 0.829
#
# === Dataset=wine | Fold 5/5 ===
# number of schmidt terms: 1,number of ancilla qubits:0
# Using cpu for training
# Model: HybridModel(
#   (qc): SchmidtQuantumCircuit(
#     (unitary_params): ParameterList(  (0): Parameter containing: [torch.float32 of size 4])
#   )
#   (classical_net): Sequential(
#     (0): Linear(in_features=16, out_features=64, bias=True)
#     (1): BatchNorm1d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): ReLU()
#     (3): Dropout(p=0.25, inplace=False)
#     (4): Linear(in_features=64, out_features=32, bias=True)
#     (5): BatchNorm1d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (6): ReLU()
#     (7): Dropout(p=0.25, inplace=False)
#     (8): Linear(in_features=32, out_features=3, bias=True)
#   )
# )
# Number of parameters: 3463
# Optimizer: AdamW (
# Parameter Group 0
#     amsgrad: False
#     betas: (0.9, 0.999)
#     capturable: False
#     decoupled_weight_decay: True
#     differentiable: False
#     eps: 1e-08
#     foreach: None
#     fused: None
#     initial_lr: 0.05
#     lr: 0.05
#     maximize: False
#     weight_decay: 0.0001
# )
# Loss Function: CrossEntropyLoss()
#  Ep 1  loss=1.0205  train_acc=0.509  val_acc=0.345  lr=0.049997
#  Ep10  loss=0.7232  train_acc=0.667  val_acc=0.379  lr=0.049692
#  Ep20  loss=0.6307  train_acc=0.675  val_acc=0.379  lr=0.048776
#  Ep30  loss=0.5922  train_acc=0.763  val_acc=0.379  lr=0.047275
#  Ep40  loss=0.5428  train_acc=0.772  val_acc=0.345  lr=0.045225
#  Ep50  loss=0.5122  train_acc=0.789  val_acc=0.621  lr=0.042678
#  Ep60  loss=0.5396  train_acc=0.816  val_acc=0.483  lr=0.039695
#  Ep70  loss=0.4143  train_acc=0.842  val_acc=0.379  lr=0.036350
#  Ep80  loss=0.3178  train_acc=0.860  val_acc=0.379  lr=0.032725
#  Ep90  loss=0.2839  train_acc=0.868  val_acc=0.379  lr=0.028911
#  Ep100  loss=0.3773  train_acc=0.807  val_acc=0.379  lr=0.025000
#  Ep110  loss=0.2914  train_acc=0.842  val_acc=0.276  lr=0.021089
#  Ep120  loss=0.2927  train_acc=0.877  val_acc=0.448  lr=0.017275
#  Ep130  loss=0.3011  train_acc=0.842  val_acc=0.586  lr=0.013650
#  Ep140  loss=0.2065  train_acc=0.930  val_acc=0.414  lr=0.010305
#  Ep150  loss=0.3192  train_acc=0.868  val_acc=0.793  lr=0.007322
#  Ep160  loss=0.2636  train_acc=0.886  val_acc=0.759  lr=0.004775
#  Ep170  loss=0.2364  train_acc=0.912  val_acc=0.724  lr=0.002725
#  Ep180  loss=0.3186  train_acc=0.895  val_acc=0.690  lr=0.001224
#  Ep190  loss=0.2208  train_acc=0.921  val_acc=0.966  lr=0.000308
#  Ep200  loss=0.2317  train_acc=0.904  val_acc=0.931  lr=0.000000
#  >>> Fold 5 Test Accuracy: 0.857
#
# >>> wine CV Results: mean=0.876, std=0.035
#
# ========================================
# ========================================
# dimension 30, padding with zeros for 32
# Reducing data dimension of breast_cancer by using Schmidt decompostion
#
# === Dataset=breast_cancer
#
# === Dataset=breast_cancer | Fold 1/5 ===
# number of schmidt terms: 2,number of ancilla qubits:1
# Using cpu for training
# Model: HybridModel(
#   (qc): SchmidtQuantumCircuit(
#     (unitary_params): ParameterList(
#         (0): Parameter containing: [torch.float32 of size 5]
#         (1): Parameter containing: [torch.float32 of size 5]
#     )
#   )
#   (classical_net): Sequential(
#     (0): Linear(in_features=32, out_features=64, bias=True)
#     (1): BatchNorm1d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): ReLU()
#     (3): Dropout(p=0.25, inplace=False)
#     (4): Linear(in_features=64, out_features=32, bias=True)
#     (5): BatchNorm1d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (6): ReLU()
#     (7): Dropout(p=0.25, inplace=False)
#     (8): Linear(in_features=32, out_features=2, bias=True)
#   )
# )
# Number of parameters: 4462
# Optimizer: AdamW (
# Parameter Group 0
#     amsgrad: False
#     betas: (0.9, 0.999)
#     capturable: False
#     decoupled_weight_decay: True
#     differentiable: False
#     eps: 1e-08
#     foreach: None
#     fused: None
#     initial_lr: 0.05
#     lr: 0.05
#     maximize: False
#     weight_decay: 0.0001
# )
# Loss Function: CrossEntropyLoss()
#  Ep 1  loss=0.3639  train_acc=0.838  val_acc=0.791  lr=0.049997
# <ipython-input-1-18bb75006c8e>:344: ComplexWarning: Casting complex values to real discards the imaginary part
#   X[i] = sd.compute_decomposition(X[i])
#  Ep10  loss=0.1924  train_acc=0.920  val_acc=0.615  lr=0.049692
#  Ep20  loss=0.2272  train_acc=0.909  val_acc=0.879  lr=0.048776
#  Ep30  loss=0.1646  train_acc=0.940  val_acc=0.879  lr=0.047275
#  Ep40  loss=0.2120  train_acc=0.904  val_acc=0.791  lr=0.045225
#  Ep50  loss=0.1724  train_acc=0.920  val_acc=0.593  lr=0.042678
#  Ep60  loss=0.2002  train_acc=0.929  val_acc=0.945  lr=0.039695
#  Ep70  loss=0.1618  train_acc=0.931  val_acc=0.956  lr=0.036350
#  Ep80  loss=0.1826  train_acc=0.907  val_acc=0.945  lr=0.032725
#  Ep90  loss=0.1469  train_acc=0.929  val_acc=0.835  lr=0.028911
#  Ep100  loss=0.1320  train_acc=0.937  val_acc=0.945  lr=0.025000
#  Ep110  loss=0.1665  train_acc=0.926  val_acc=0.890  lr=0.021089
#  Ep120  loss=0.1202  train_acc=0.940  val_acc=0.945  lr=0.017275
#  Ep130  loss=0.1610  train_acc=0.931  val_acc=0.934  lr=0.013650
#  Ep140  loss=0.1586  train_acc=0.934  val_acc=0.934  lr=0.010305
#  Ep150  loss=0.1321  train_acc=0.948  val_acc=0.934  lr=0.007322
#  Ep160  loss=0.1463  train_acc=0.931  val_acc=0.967  lr=0.004775
#  Ep170  loss=0.1051  train_acc=0.953  val_acc=0.967  lr=0.002725
#  Ep180  loss=0.1370  train_acc=0.931  val_acc=0.956  lr=0.001224
#  Ep190  loss=0.1455  train_acc=0.942  val_acc=0.956  lr=0.000308
#  Ep200  loss=0.1459  train_acc=0.934  val_acc=0.956  lr=0.000000
#  >>> Fold 1 Test Accuracy: 0.930
#
# === Dataset=breast_cancer | Fold 2/5 ===
# number of schmidt terms: 2,number of ancilla qubits:1
# Using cpu for training
# Model: HybridModel(
#   (qc): SchmidtQuantumCircuit(
#     (unitary_params): ParameterList(
#         (0): Parameter containing: [torch.float32 of size 5]
#         (1): Parameter containing: [torch.float32 of size 5]
#     )
#   )
#   (classical_net): Sequential(
#     (0): Linear(in_features=32, out_features=64, bias=True)
#     (1): BatchNorm1d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): ReLU()
#     (3): Dropout(p=0.25, inplace=False)
#     (4): Linear(in_features=64, out_features=32, bias=True)
#     (5): BatchNorm1d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (6): ReLU()
#     (7): Dropout(p=0.25, inplace=False)
#     (8): Linear(in_features=32, out_features=2, bias=True)
#   )
# )
# Number of parameters: 4462
# Optimizer: AdamW (
# Parameter Group 0
#     amsgrad: False
#     betas: (0.9, 0.999)
#     capturable: False
#     decoupled_weight_decay: True
#     differentiable: False
#     eps: 1e-08
#     foreach: None
#     fused: None
#     initial_lr: 0.05
#     lr: 0.05
#     maximize: False
#     weight_decay: 0.0001
# )
# Loss Function: CrossEntropyLoss()
#  Ep 1  loss=0.3148  train_acc=0.890  val_acc=0.626  lr=0.049997
#  Ep10  loss=0.2005  train_acc=0.923  val_acc=0.692  lr=0.049692
#  Ep20  loss=0.1904  train_acc=0.915  val_acc=0.879  lr=0.048776
#  Ep30  loss=0.1875  train_acc=0.923  val_acc=0.725  lr=0.047275
#  Ep40  loss=0.1706  train_acc=0.909  val_acc=0.956  lr=0.045225
#  Ep50  loss=0.2593  train_acc=0.887  val_acc=0.912  lr=0.042678
#  Ep60  loss=0.1958  train_acc=0.909  val_acc=0.835  lr=0.039695
#  Ep70  loss=0.1682  train_acc=0.909  val_acc=0.901  lr=0.036350
#  Ep80  loss=0.1435  train_acc=0.942  val_acc=0.868  lr=0.032725
#  Ep90  loss=0.1629  train_acc=0.937  val_acc=0.912  lr=0.028911
#  Ep100  loss=0.1252  train_acc=0.953  val_acc=0.956  lr=0.025000
#  Ep110  loss=0.1910  train_acc=0.926  val_acc=0.879  lr=0.021089
#  Ep120  loss=0.1540  train_acc=0.940  val_acc=0.670  lr=0.017275
#  Ep130  loss=0.1389  train_acc=0.934  val_acc=0.879  lr=0.013650
#  Ep140  loss=0.1157  train_acc=0.940  val_acc=0.967  lr=0.010305
#  Ep150  loss=0.1452  train_acc=0.937  val_acc=0.890  lr=0.007322
#  Ep160  loss=0.1615  train_acc=0.934  val_acc=0.967  lr=0.004775
#  Ep170  loss=0.1333  train_acc=0.937  val_acc=0.978  lr=0.002725
#  Ep180  loss=0.1112  train_acc=0.948  val_acc=0.967  lr=0.001224
#  Ep190  loss=0.1145  train_acc=0.951  val_acc=0.978  lr=0.000308
#  Ep200  loss=0.1288  train_acc=0.940  val_acc=0.956  lr=0.000000
#  >>> Fold 2 Test Accuracy: 0.912
#
# === Dataset=breast_cancer | Fold 3/5 ===
# number of schmidt terms: 2,number of ancilla qubits:1
# Using cpu for training
# Model: HybridModel(
#   (qc): SchmidtQuantumCircuit(
#     (unitary_params): ParameterList(
#         (0): Parameter containing: [torch.float32 of size 5]
#         (1): Parameter containing: [torch.float32 of size 5]
#     )
#   )
#   (classical_net): Sequential(
#     (0): Linear(in_features=32, out_features=64, bias=True)
#     (1): BatchNorm1d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): ReLU()
#     (3): Dropout(p=0.25, inplace=False)
#     (4): Linear(in_features=64, out_features=32, bias=True)
#     (5): BatchNorm1d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (6): ReLU()
#     (7): Dropout(p=0.25, inplace=False)
#     (8): Linear(in_features=32, out_features=2, bias=True)
#   )
# )
# Number of parameters: 4462
# Optimizer: AdamW (
# Parameter Group 0
#     amsgrad: False
#     betas: (0.9, 0.999)
#     capturable: False
#     decoupled_weight_decay: True
#     differentiable: False
#     eps: 1e-08
#     foreach: None
#     fused: None
#     initial_lr: 0.05
#     lr: 0.05
#     maximize: False
#     weight_decay: 0.0001
# )
# Loss Function: CrossEntropyLoss()
#  Ep 1  loss=0.3650  train_acc=0.854  val_acc=0.835  lr=0.049997
#  Ep10  loss=0.2442  train_acc=0.909  val_acc=0.945  lr=0.049692
#  Ep20  loss=0.2089  train_acc=0.929  val_acc=0.824  lr=0.048776
#  Ep30  loss=0.1497  train_acc=0.926  val_acc=0.868  lr=0.047275
#  Ep40  loss=0.1862  train_acc=0.942  val_acc=0.901  lr=0.045225
#  Ep50  loss=0.2390  train_acc=0.904  val_acc=0.923  lr=0.042678
#  Ep60  loss=0.1775  train_acc=0.923  val_acc=0.780  lr=0.039695
#  Ep70  loss=0.1417  train_acc=0.945  val_acc=0.945  lr=0.036350
#  Ep80  loss=0.1936  train_acc=0.923  val_acc=0.978  lr=0.032725
#  Ep90  loss=0.1579  train_acc=0.929  val_acc=0.934  lr=0.028911
#  Ep100  loss=0.1823  train_acc=0.926  val_acc=0.901  lr=0.025000
#  Ep110  loss=0.1498  train_acc=0.926  val_acc=0.956  lr=0.021089
#  Ep120  loss=0.1603  train_acc=0.937  val_acc=0.967  lr=0.017275
#  Ep130  loss=0.1109  train_acc=0.959  val_acc=0.967  lr=0.013650
#  Ep140  loss=0.1460  train_acc=0.934  val_acc=0.912  lr=0.010305
#  Ep150  loss=0.1348  train_acc=0.962  val_acc=0.967  lr=0.007322
#  Ep160  loss=0.1268  train_acc=0.956  val_acc=0.967  lr=0.004775
#  Ep170  loss=0.1335  train_acc=0.937  val_acc=0.956  lr=0.002725
#  Ep180  loss=0.0881  train_acc=0.959  val_acc=0.967  lr=0.001224
#  Ep190  loss=0.1106  train_acc=0.959  val_acc=0.978  lr=0.000308
#  Ep200  loss=0.1335  train_acc=0.956  val_acc=0.978  lr=0.000000
#  >>> Fold 3 Test Accuracy: 0.912
#
# === Dataset=breast_cancer | Fold 4/5 ===
# number of schmidt terms: 2,number of ancilla qubits:1
# Using cpu for training
# Model: HybridModel(
#   (qc): SchmidtQuantumCircuit(
#     (unitary_params): ParameterList(
#         (0): Parameter containing: [torch.float32 of size 5]
#         (1): Parameter containing: [torch.float32 of size 5]
#     )
#   )
#   (classical_net): Sequential(
#     (0): Linear(in_features=32, out_features=64, bias=True)
#     (1): BatchNorm1d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): ReLU()
#     (3): Dropout(p=0.25, inplace=False)
#     (4): Linear(in_features=64, out_features=32, bias=True)
#     (5): BatchNorm1d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (6): ReLU()
#     (7): Dropout(p=0.25, inplace=False)
#     (8): Linear(in_features=32, out_features=2, bias=True)
#   )
# )
# Number of parameters: 4462
# Optimizer: AdamW (
# Parameter Group 0
#     amsgrad: False
#     betas: (0.9, 0.999)
#     capturable: False
#     decoupled_weight_decay: True
#     differentiable: False
#     eps: 1e-08
#     foreach: None
#     fused: None
#     initial_lr: 0.05
#     lr: 0.05
#     maximize: False
#     weight_decay: 0.0001
# )
# Loss Function: CrossEntropyLoss()
#  Ep 1  loss=0.3706  train_acc=0.808  val_acc=0.725  lr=0.049997
#  Ep10  loss=0.2181  train_acc=0.915  val_acc=0.879  lr=0.049692
#  Ep20  loss=0.2006  train_acc=0.915  val_acc=0.901  lr=0.048776
#  Ep30  loss=0.1887  train_acc=0.912  val_acc=0.659  lr=0.047275
#  Ep40  loss=0.2139  train_acc=0.912  val_acc=0.879  lr=0.045225
#  Ep50  loss=0.2052  train_acc=0.915  val_acc=0.879  lr=0.042678
#  Ep60  loss=0.2039  train_acc=0.912  val_acc=0.879  lr=0.039695
#  Ep70  loss=0.1645  train_acc=0.945  val_acc=0.901  lr=0.036350
#  Ep80  loss=0.1608  train_acc=0.929  val_acc=0.901  lr=0.032725
#  Ep90  loss=0.2122  train_acc=0.931  val_acc=0.912  lr=0.028911
#  Ep100  loss=0.1740  train_acc=0.926  val_acc=0.780  lr=0.025000
#  Ep110  loss=0.1464  train_acc=0.934  val_acc=0.846  lr=0.021089
#  Ep120  loss=0.1480  train_acc=0.945  val_acc=0.912  lr=0.017275
#  Ep130  loss=0.1282  train_acc=0.951  val_acc=0.901  lr=0.013650
#  Ep140  loss=0.1246  train_acc=0.948  val_acc=0.879  lr=0.010305
#  Ep150  loss=0.1170  train_acc=0.948  val_acc=0.890  lr=0.007322
#  Ep160  loss=0.1253  train_acc=0.959  val_acc=0.857  lr=0.004775
#  Ep170  loss=0.1456  train_acc=0.945  val_acc=0.901  lr=0.002725
#  Ep180  loss=0.1107  train_acc=0.956  val_acc=0.912  lr=0.001224
#  Ep190  loss=0.1054  train_acc=0.951  val_acc=0.890  lr=0.000308
#  Ep200  loss=0.1038  train_acc=0.945  val_acc=0.868  lr=0.000000
#  >>> Fold 4 Test Accuracy: 0.947
#
# === Dataset=breast_cancer | Fold 5/5 ===
# number of schmidt terms: 2,number of ancilla qubits:1
# Using cpu for training
# Model: HybridModel(
#   (qc): SchmidtQuantumCircuit(
#     (unitary_params): ParameterList(
#         (0): Parameter containing: [torch.float32 of size 5]
#         (1): Parameter containing: [torch.float32 of size 5]
#     )
#   )
#   (classical_net): Sequential(
#     (0): Linear(in_features=32, out_features=64, bias=True)
#     (1): BatchNorm1d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): ReLU()
#     (3): Dropout(p=0.25, inplace=False)
#     (4): Linear(in_features=64, out_features=32, bias=True)
#     (5): BatchNorm1d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (6): ReLU()
#     (7): Dropout(p=0.25, inplace=False)
#     (8): Linear(in_features=32, out_features=2, bias=True)
#   )
# )
# Number of parameters: 4462
# Optimizer: AdamW (
# Parameter Group 0
#     amsgrad: False
#     betas: (0.9, 0.999)
#     capturable: False
#     decoupled_weight_decay: True
#     differentiable: False
#     eps: 1e-08
#     foreach: None
#     fused: None
#     initial_lr: 0.05
#     lr: 0.05
#     maximize: False
#     weight_decay: 0.0001
# )
# Loss Function: CrossEntropyLoss()
#  Ep 1  loss=0.3566  train_acc=0.827  val_acc=0.630  lr=0.049997
#  Ep10  loss=0.2206  train_acc=0.909  val_acc=0.924  lr=0.049692
#  Ep20  loss=0.2206  train_acc=0.918  val_acc=0.946  lr=0.048776
#  Ep30  loss=0.2912  train_acc=0.901  val_acc=0.696  lr=0.047275
#  Ep40  loss=0.2350  train_acc=0.909  val_acc=0.913  lr=0.045225
#  Ep50  loss=0.1980  train_acc=0.915  val_acc=0.913  lr=0.042678
#  Ep60  loss=0.1847  train_acc=0.907  val_acc=0.946  lr=0.039695
#  Ep70  loss=0.1571  train_acc=0.929  val_acc=0.946  lr=0.036350
#  Ep80  loss=0.2099  train_acc=0.909  val_acc=0.891  lr=0.032725
#  Ep90  loss=0.2212  train_acc=0.915  val_acc=0.935  lr=0.028911
#  Ep100  loss=0.2391  train_acc=0.898  val_acc=0.924  lr=0.025000
#  Ep110  loss=0.1618  train_acc=0.929  val_acc=0.924  lr=0.021089
#  Ep120  loss=0.1771  train_acc=0.929  val_acc=0.946  lr=0.017275
#  Ep130  loss=0.1442  train_acc=0.937  val_acc=0.478  lr=0.013650
#  Ep140  loss=0.1543  train_acc=0.942  val_acc=0.913  lr=0.010305
#  Ep150  loss=0.1827  train_acc=0.912  val_acc=0.924  lr=0.007322
#  Ep160  loss=0.1281  train_acc=0.948  val_acc=0.913  lr=0.004775
#  Ep170  loss=0.1650  train_acc=0.929  val_acc=0.913  lr=0.002725
#  Ep180  loss=0.1267  train_acc=0.942  val_acc=0.924  lr=0.001224
#  Ep190  loss=0.1593  train_acc=0.918  val_acc=0.924  lr=0.000308
#  Ep200  loss=0.1245  train_acc=0.951  val_acc=0.924  lr=0.000000
#  >>> Fold 5 Test Accuracy: 0.965
#
# >>> breast_cancer CV Results: mean=0.933, std=0.020
#
# ========================================
# ========================================
# dimension 34, padding with zeros for 64
# Reducing data dimension of ionosphere by using Schmidt decompostion
#
# === Dataset=ionosphere
#
# === Dataset=ionosphere | Fold 1/5 ===
# number of schmidt terms: 1,number of ancilla qubits:0
# Using cpu for training
# Model: HybridModel(
#   (qc): SchmidtQuantumCircuit(
#     (unitary_params): ParameterList(  (0): Parameter containing: [torch.float32 of size 6])
#   )
#   (classical_net): Sequential(
#     (0): Linear(in_features=64, out_features=64, bias=True)
#     (1): BatchNorm1d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): ReLU()
#     (3): Dropout(p=0.25, inplace=False)
#     (4): Linear(in_features=64, out_features=32, bias=True)
#     (5): BatchNorm1d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (6): ReLU()
#     (7): Dropout(p=0.25, inplace=False)
#     (8): Linear(in_features=32, out_features=2, bias=True)
#   )
# )
# Number of parameters: 6504
# Optimizer: AdamW (
# Parameter Group 0
#     amsgrad: False
#     betas: (0.9, 0.999)
#     capturable: False
#     decoupled_weight_decay: True
#     differentiable: False
#     eps: 1e-08
#     foreach: None
#     fused: None
#     initial_lr: 0.05
#     lr: 0.05
#     maximize: False
#     weight_decay: 0.0001
# )
# Loss Function: CrossEntropyLoss()
#  Ep 1  loss=0.4650  train_acc=0.790  val_acc=0.768  lr=0.049997
#  Ep10  loss=0.1752  train_acc=0.955  val_acc=0.946  lr=0.049692
#  Ep20  loss=0.0771  train_acc=0.973  val_acc=0.929  lr=0.048776
# <ipython-input-1-18bb75006c8e>:344: ComplexWarning: Casting complex values to real discards the imaginary part
#   X[i] = sd.compute_decomposition(X[i])
#  Ep30  loss=0.1076  train_acc=0.960  val_acc=0.893  lr=0.047275
#  Ep40  loss=0.1168  train_acc=0.960  val_acc=0.911  lr=0.045225
#  Ep50  loss=0.0890  train_acc=0.973  val_acc=0.929  lr=0.042678
#  Ep60  loss=0.0850  train_acc=0.978  val_acc=0.929  lr=0.039695
#  Ep70  loss=0.0737  train_acc=0.978  val_acc=0.929  lr=0.036350
#  Ep80  loss=0.0777  train_acc=0.978  val_acc=0.929  lr=0.032725
#  Ep90  loss=0.0937  train_acc=0.969  val_acc=0.929  lr=0.028911
#  Ep100  loss=0.1064  train_acc=0.973  val_acc=0.929  lr=0.025000
#  Ep110  loss=0.0633  train_acc=0.978  val_acc=0.929  lr=0.021089
#  Ep120  loss=0.0625  train_acc=0.987  val_acc=0.929  lr=0.017275
#  Ep130  loss=0.0812  train_acc=0.973  val_acc=0.929  lr=0.013650
#  Ep140  loss=0.0366  train_acc=0.991  val_acc=0.929  lr=0.010305
#  Ep150  loss=0.0625  train_acc=0.982  val_acc=0.929  lr=0.007322
#  Ep160  loss=0.0624  train_acc=0.978  val_acc=0.946  lr=0.004775
#  Ep170  loss=0.0591  train_acc=0.973  val_acc=0.929  lr=0.002725
#  Ep180  loss=0.0624  train_acc=0.978  val_acc=0.929  lr=0.001224
#  Ep190  loss=0.0467  train_acc=0.987  val_acc=0.929  lr=0.000308
#  Ep200  loss=0.0677  train_acc=0.969  val_acc=0.929  lr=0.000000
#  >>> Fold 1 Test Accuracy: 0.915
#
# === Dataset=ionosphere | Fold 2/5 ===
# number of schmidt terms: 1,number of ancilla qubits:0
# Using cpu for training
# Model: HybridModel(
#   (qc): SchmidtQuantumCircuit(
#     (unitary_params): ParameterList(  (0): Parameter containing: [torch.float32 of size 6])
#   )
#   (classical_net): Sequential(
#     (0): Linear(in_features=64, out_features=64, bias=True)
#     (1): BatchNorm1d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): ReLU()
#     (3): Dropout(p=0.25, inplace=False)
#     (4): Linear(in_features=64, out_features=32, bias=True)
#     (5): BatchNorm1d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (6): ReLU()
#     (7): Dropout(p=0.25, inplace=False)
#     (8): Linear(in_features=32, out_features=2, bias=True)
#   )
# )
# Number of parameters: 6504
# Optimizer: AdamW (
# Parameter Group 0
#     amsgrad: False
#     betas: (0.9, 0.999)
#     capturable: False
#     decoupled_weight_decay: True
#     differentiable: False
#     eps: 1e-08
#     foreach: None
#     fused: None
#     initial_lr: 0.05
#     lr: 0.05
#     maximize: False
#     weight_decay: 0.0001
# )
# Loss Function: CrossEntropyLoss()
#  Ep 1  loss=0.4671  train_acc=0.741  val_acc=0.877  lr=0.049997
#  Ep10  loss=0.1265  train_acc=0.973  val_acc=0.947  lr=0.049692
#  Ep20  loss=0.1099  train_acc=0.960  val_acc=0.965  lr=0.048776
#  Ep30  loss=0.1113  train_acc=0.969  val_acc=0.965  lr=0.047275
#  Ep40  loss=0.1158  train_acc=0.946  val_acc=0.947  lr=0.045225
#  Ep50  loss=0.1100  train_acc=0.960  val_acc=0.965  lr=0.042678
#  Ep60  loss=0.0901  train_acc=0.960  val_acc=0.947  lr=0.039695
#  Ep70  loss=0.0751  train_acc=0.982  val_acc=0.947  lr=0.036350
#  Ep80  loss=0.0541  train_acc=0.982  val_acc=0.947  lr=0.032725
#  Ep90  loss=0.0759  train_acc=0.987  val_acc=0.930  lr=0.028911
#  Ep100  loss=0.1256  train_acc=0.969  val_acc=0.947  lr=0.025000
#  Ep110  loss=0.0574  train_acc=0.982  val_acc=0.947  lr=0.021089
#  Ep120  loss=0.0516  train_acc=0.987  val_acc=0.930  lr=0.017275
#  Ep130  loss=0.0447  train_acc=0.987  val_acc=0.930  lr=0.013650
#  Ep140  loss=0.0519  train_acc=0.982  val_acc=0.930  lr=0.010305
#  Ep150  loss=0.0551  train_acc=0.969  val_acc=0.930  lr=0.007322
#  Ep160  loss=0.0626  train_acc=0.978  val_acc=0.930  lr=0.004775
#  Ep170  loss=0.0519  train_acc=0.987  val_acc=0.930  lr=0.002725
#  Ep180  loss=0.0428  train_acc=0.991  val_acc=0.930  lr=0.001224
#  Ep190  loss=0.0526  train_acc=0.973  val_acc=0.930  lr=0.000308
#  Ep200  loss=0.0577  train_acc=0.973  val_acc=0.930  lr=0.000000
#  >>> Fold 2 Test Accuracy: 0.957
#
# === Dataset=ionosphere | Fold 3/5 ===
# number of schmidt terms: 1,number of ancilla qubits:0
# Using cpu for training
# Model: HybridModel(
#   (qc): SchmidtQuantumCircuit(
#     (unitary_params): ParameterList(  (0): Parameter containing: [torch.float32 of size 6])
#   )
#   (classical_net): Sequential(
#     (0): Linear(in_features=64, out_features=64, bias=True)
#     (1): BatchNorm1d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): ReLU()
#     (3): Dropout(p=0.25, inplace=False)
#     (4): Linear(in_features=64, out_features=32, bias=True)
#     (5): BatchNorm1d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (6): ReLU()
#     (7): Dropout(p=0.25, inplace=False)
#     (8): Linear(in_features=32, out_features=2, bias=True)
#   )
# )
# Number of parameters: 6504
# Optimizer: AdamW (
# Parameter Group 0
#     amsgrad: False
#     betas: (0.9, 0.999)
#     capturable: False
#     decoupled_weight_decay: True
#     differentiable: False
#     eps: 1e-08
#     foreach: None
#     fused: None
#     initial_lr: 0.05
#     lr: 0.05
#     maximize: False
#     weight_decay: 0.0001
# )
# Loss Function: CrossEntropyLoss()
#  Ep 1  loss=0.4279  train_acc=0.808  val_acc=0.772  lr=0.049997
#  Ep10  loss=0.1510  train_acc=0.960  val_acc=0.895  lr=0.049692
#  Ep20  loss=0.1287  train_acc=0.960  val_acc=0.912  lr=0.048776
#  Ep30  loss=0.1032  train_acc=0.969  val_acc=0.912  lr=0.047275
#  Ep40  loss=0.0801  train_acc=0.987  val_acc=0.912  lr=0.045225
#  Ep50  loss=0.1322  train_acc=0.960  val_acc=0.912  lr=0.042678
#  Ep60  loss=0.0999  train_acc=0.973  val_acc=0.912  lr=0.039695
#  Ep70  loss=0.1018  train_acc=0.969  val_acc=0.912  lr=0.036350
#  Ep80  loss=0.1550  train_acc=0.955  val_acc=0.877  lr=0.032725
#  Ep90  loss=0.1036  train_acc=0.964  val_acc=0.895  lr=0.028911
#  Ep100  loss=0.0825  train_acc=0.969  val_acc=0.895  lr=0.025000
#  Ep110  loss=0.0559  train_acc=0.987  val_acc=0.895  lr=0.021089
#  Ep120  loss=0.0758  train_acc=0.973  val_acc=0.930  lr=0.017275
#  Ep130  loss=0.0712  train_acc=0.978  val_acc=0.912  lr=0.013650
#  Ep140  loss=0.0678  train_acc=0.978  val_acc=0.912  lr=0.010305
#  Ep150  loss=0.0674  train_acc=0.982  val_acc=0.912  lr=0.007322
#  Ep160  loss=0.0524  train_acc=0.987  val_acc=0.895  lr=0.004775
#  Ep170  loss=0.0612  train_acc=0.987  val_acc=0.895  lr=0.002725
#  Ep180  loss=0.0562  train_acc=0.982  val_acc=0.895  lr=0.001224
#  Ep190  loss=0.0643  train_acc=0.987  val_acc=0.895  lr=0.000308
#  Ep200  loss=0.0492  train_acc=0.987  val_acc=0.895  lr=0.000000
#  >>> Fold 3 Test Accuracy: 0.914
#
# === Dataset=ionosphere | Fold 4/5 ===
# number of schmidt terms: 1,number of ancilla qubits:0
# Using cpu for training
# Model: HybridModel(
#   (qc): SchmidtQuantumCircuit(
#     (unitary_params): ParameterList(  (0): Parameter containing: [torch.float32 of size 6])
#   )
#   (classical_net): Sequential(
#     (0): Linear(in_features=64, out_features=64, bias=True)
#     (1): BatchNorm1d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): ReLU()
#     (3): Dropout(p=0.25, inplace=False)
#     (4): Linear(in_features=64, out_features=32, bias=True)
#     (5): BatchNorm1d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (6): ReLU()
#     (7): Dropout(p=0.25, inplace=False)
#     (8): Linear(in_features=32, out_features=2, bias=True)
#   )
# )
# Number of parameters: 6504
# Optimizer: AdamW (
# Parameter Group 0
#     amsgrad: False
#     betas: (0.9, 0.999)
#     capturable: False
#     decoupled_weight_decay: True
#     differentiable: False
#     eps: 1e-08
#     foreach: None
#     fused: None
#     initial_lr: 0.05
#     lr: 0.05
# ...
#     )
#   )
#   (classical_net): Sequential(
#     (0): Linear(in_features=64, out_features=64, bias=True)
#     (1): BatchNorm1d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): ReLU()
#     (3): Dropout(p=0.25, inplace=False)
#     (4): Linear(in_features=64, out_features=32, bias=True)
#     (5): BatchNorm1d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (6): ReLU()
#     (7): Dropout(p=0.25, inplace=False)
#     (8): Linear(in_features=32, out_features=7, bias=True)
#   )
# )
# Number of parameters: 6687
# Optimizer: AdamW (
# Parameter Group 0
#     amsgrad: False
#     betas: (0.9, 0.999)
#     capturable: False
#     decoupled_weight_decay: True
#     differentiable: False
#     eps: 1e-08
#     foreach: None
#     fused: None
#     initial_lr: 0.05
#     lr: 0.05
#     maximize: False
#     weight_decay: 0.0001
# )
# Loss Function: CrossEntropyLoss()
#  Ep 1  loss=1.3178  train_acc=0.442  val_acc=0.463  lr=0.049997
#  Ep10  loss=1.1283  train_acc=0.506  val_acc=0.469  lr=0.049692
#  Ep20  loss=1.0884  train_acc=0.519  val_acc=0.506  lr=0.048776
#  Ep30  loss=1.0654  train_acc=0.555  val_acc=0.506  lr=0.047275
#  Ep40  loss=1.0411  train_acc=0.558  val_acc=0.525  lr=0.045225
#  Ep50  loss=1.0396  train_acc=0.559  val_acc=0.562  lr=0.042678
#  Ep60  loss=1.0043  train_acc=0.570  val_acc=0.525  lr=0.039695
#  Ep70  loss=0.9878  train_acc=0.592  val_acc=0.600  lr=0.036350
#  Ep80  loss=1.0086  train_acc=0.591  val_acc=0.487  lr=0.032725
#  Ep90  loss=0.9585  train_acc=0.602  val_acc=0.556  lr=0.028911
#  Ep100  loss=0.9368  train_acc=0.628  val_acc=0.556  lr=0.025000
#  Ep110  loss=0.9618  train_acc=0.605  val_acc=0.544  lr=0.021089
#  Ep120  loss=0.9085  train_acc=0.620  val_acc=0.600  lr=0.017275
#  Ep130  loss=0.9001  train_acc=0.617  val_acc=0.569  lr=0.013650
#  Ep140  loss=0.8809  train_acc=0.655  val_acc=0.594  lr=0.010305
#  Ep150  loss=0.8920  train_acc=0.622  val_acc=0.581  lr=0.007322
#  Ep160  loss=0.8785  train_acc=0.631  val_acc=0.575  lr=0.004775
#  Ep170  loss=0.8894  train_acc=0.639  val_acc=0.588  lr=0.002725
#  Ep180  loss=0.9067  train_acc=0.634  val_acc=0.588  lr=0.001224
#  Ep190  loss=0.8575  train_acc=0.642  val_acc=0.594  lr=0.000308
#  Ep200  loss=0.8887  train_acc=0.658  val_acc=0.594  lr=0.000000
#  >>> Fold 5 Test Accuracy: 0.565
#
# >>> covtype CV Results: mean=0.604, std=0.027
#
# ========================================
# ========================================
# Reducing data dimension of digits by using Schmidt decompostion
# <ipython-input-1-18bb75006c8e>:344: ComplexWarning: Casting complex values to real discards the imaginary part
#   X[i] = sd.compute_decomposition(X[i])
# === Dataset=digits
#
# === Dataset=digits | Fold 1/5 ===
# number of schmidt terms: 2,number of ancilla qubits:1
# Using cpu for training
# Model: HybridModel(
#   (qc): SchmidtQuantumCircuit(
#     (unitary_params): ParameterList(
#         (0): Parameter containing: [torch.float32 of size 6]
#         (1): Parameter containing: [torch.float32 of size 6]
#     )
#   )
#   (classical_net): Sequential(
#     (0): Linear(in_features=64, out_features=64, bias=True)
#     (1): BatchNorm1d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): ReLU()
#     (3): Dropout(p=0.25, inplace=False)
#     (4): Linear(in_features=64, out_features=32, bias=True)
#     (5): BatchNorm1d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (6): ReLU()
#     (7): Dropout(p=0.25, inplace=False)
#     (8): Linear(in_features=32, out_features=10, bias=True)
#   )
# )
# Number of parameters: 6776
# Optimizer: AdamW (
# Parameter Group 0
#     amsgrad: False
#     betas: (0.9, 0.999)
#     capturable: False
#     decoupled_weight_decay: True
#     differentiable: False
#     eps: 1e-08
#     foreach: None
#     fused: None
#     initial_lr: 0.05
#     lr: 0.05
#     maximize: False
#     weight_decay: 0.0001
# )
# Loss Function: CrossEntropyLoss()
#  Ep 1  loss=1.5077  train_acc=0.494  val_acc=0.619  lr=0.049997
#  Ep10  loss=0.7479  train_acc=0.747  val_acc=0.781  lr=0.049692
#  Ep20  loss=0.5922  train_acc=0.780  val_acc=0.800  lr=0.048776
#  Ep30  loss=0.7336  train_acc=0.764  val_acc=0.781  lr=0.047275
#  Ep40  loss=0.5250  train_acc=0.814  val_acc=0.800  lr=0.045225
#  Ep50  loss=0.4353  train_acc=0.850  val_acc=0.812  lr=0.042678
#  Ep60  loss=0.4961  train_acc=0.839  val_acc=0.800  lr=0.039695
#  Ep70  loss=0.4500  train_acc=0.853  val_acc=0.825  lr=0.036350
#  Ep80  loss=0.4467  train_acc=0.845  val_acc=0.794  lr=0.032725
#  Ep90  loss=0.3983  train_acc=0.863  val_acc=0.819  lr=0.028911
#  Ep100  loss=0.3207  train_acc=0.875  val_acc=0.831  lr=0.025000
#  Ep110  loss=0.3224  train_acc=0.894  val_acc=0.825  lr=0.021089
#  Ep120  loss=0.3481  train_acc=0.877  val_acc=0.831  lr=0.017275
#  Ep130  loss=0.3505  train_acc=0.880  val_acc=0.831  lr=0.013650
#  Ep140  loss=0.3049  train_acc=0.883  val_acc=0.825  lr=0.010305
#  Ep150  loss=0.3618  train_acc=0.870  val_acc=0.838  lr=0.007322
#  Ep160  loss=0.3048  train_acc=0.905  val_acc=0.838  lr=0.004775
#  Ep170  loss=0.3062  train_acc=0.895  val_acc=0.831  lr=0.002725
#  Ep180  loss=0.3020  train_acc=0.897  val_acc=0.838  lr=0.001224
#  Ep190  loss=0.2528  train_acc=0.911  val_acc=0.819  lr=0.000308
#  Ep200  loss=0.2835  train_acc=0.905  val_acc=0.825  lr=0.000000
#  >>> Fold 1 Test Accuracy: 0.845
#
# === Dataset=digits | Fold 2/5 ===
# number of schmidt terms: 2,number of ancilla qubits:1
# Using cpu for training
# Model: HybridModel(
#   (qc): SchmidtQuantumCircuit(
#     (unitary_params): ParameterList(
#         (0): Parameter containing: [torch.float32 of size 6]
#         (1): Parameter containing: [torch.float32 of size 6]
#     )
#   )
#   (classical_net): Sequential(
#     (0): Linear(in_features=64, out_features=64, bias=True)
#     (1): BatchNorm1d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): ReLU()
#     (3): Dropout(p=0.25, inplace=False)
#     (4): Linear(in_features=64, out_features=32, bias=True)
#     (5): BatchNorm1d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (6): ReLU()
#     (7): Dropout(p=0.25, inplace=False)
#     (8): Linear(in_features=32, out_features=10, bias=True)
#   )
# )
# Number of parameters: 6776
# Optimizer: AdamW (
# Parameter Group 0
#     amsgrad: False
#     betas: (0.9, 0.999)
#     capturable: False
#     decoupled_weight_decay: True
#     differentiable: False
#     eps: 1e-08
#     foreach: None
#     fused: None
#     initial_lr: 0.05
#     lr: 0.05
#     maximize: False
#     weight_decay: 0.0001
# )
# Loss Function: CrossEntropyLoss()
#  Ep 1  loss=1.4151  train_acc=0.522  val_acc=0.675  lr=0.049997
#  Ep10  loss=0.6696  train_acc=0.770  val_acc=0.806  lr=0.049692
#  Ep20  loss=0.6309  train_acc=0.778  val_acc=0.831  lr=0.048776
#  Ep30  loss=0.5044  train_acc=0.823  val_acc=0.844  lr=0.047275
#  Ep40  loss=0.5587  train_acc=0.814  val_acc=0.863  lr=0.045225
#  Ep50  loss=0.5032  train_acc=0.844  val_acc=0.875  lr=0.042678
#  Ep60  loss=0.4750  train_acc=0.853  val_acc=0.838  lr=0.039695
#  Ep70  loss=0.4209  train_acc=0.842  val_acc=0.850  lr=0.036350
#  Ep80  loss=0.3594  train_acc=0.867  val_acc=0.856  lr=0.032725
#  Ep90  loss=0.3767  train_acc=0.878  val_acc=0.831  lr=0.028911
#  Ep100  loss=0.3765  train_acc=0.866  val_acc=0.825  lr=0.025000
#  Ep110  loss=0.3375  train_acc=0.872  val_acc=0.838  lr=0.021089
#  Ep120  loss=0.3642  train_acc=0.870  val_acc=0.863  lr=0.017275
#  Ep130  loss=0.3650  train_acc=0.889  val_acc=0.856  lr=0.013650
#  Ep140  loss=0.3092  train_acc=0.884  val_acc=0.838  lr=0.010305
#  Ep150  loss=0.2594  train_acc=0.905  val_acc=0.856  lr=0.007322
#  Ep160  loss=0.2939  train_acc=0.911  val_acc=0.863  lr=0.004775
#  Ep170  loss=0.2417  train_acc=0.906  val_acc=0.856  lr=0.002725
#  Ep180  loss=0.3017  train_acc=0.895  val_acc=0.863  lr=0.001224
#  Ep190  loss=0.2512  train_acc=0.906  val_acc=0.875  lr=0.000308
#  Ep200  loss=0.3159  train_acc=0.908  val_acc=0.856  lr=0.000000
#  >>> Fold 2 Test Accuracy: 0.805
#
# === Dataset=digits | Fold 3/5 ===
# number of schmidt terms: 2,number of ancilla qubits:1
# Using cpu for training
# Model: HybridModel(
#   (qc): SchmidtQuantumCircuit(
#     (unitary_params): ParameterList(
#         (0): Parameter containing: [torch.float32 of size 6]
#         (1): Parameter containing: [torch.float32 of size 6]
#     )
#   )
#   (classical_net): Sequential(
#     (0): Linear(in_features=64, out_features=64, bias=True)
#     (1): BatchNorm1d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): ReLU()
#     (3): Dropout(p=0.25, inplace=False)
#     (4): Linear(in_features=64, out_features=32, bias=True)
#     (5): BatchNorm1d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (6): ReLU()
#     (7): Dropout(p=0.25, inplace=False)
#     (8): Linear(in_features=32, out_features=10, bias=True)
#   )
# )
# Number of parameters: 6776
# Optimizer: AdamW (
# Parameter Group 0
#     amsgrad: False
#     betas: (0.9, 0.999)
#     capturable: False
#     decoupled_weight_decay: True
#     differentiable: False
#     eps: 1e-08
#     foreach: None
#     fused: None
#     initial_lr: 0.05
#     lr: 0.05
#     maximize: False
#     weight_decay: 0.0001
# )
# Loss Function: CrossEntropyLoss()
#  Ep 1  loss=1.4846  train_acc=0.503  val_acc=0.756  lr=0.049997
#  Ep10  loss=0.7075  train_acc=0.755  val_acc=0.806  lr=0.049692
#  Ep20  loss=0.6686  train_acc=0.777  val_acc=0.850  lr=0.048776
#  Ep30  loss=0.6046  train_acc=0.797  val_acc=0.838  lr=0.047275
#  Ep40  loss=0.5020  train_acc=0.820  val_acc=0.825  lr=0.045225
#  Ep50  loss=0.5069  train_acc=0.819  val_acc=0.863  lr=0.042678
#  Ep60  loss=0.5041  train_acc=0.828  val_acc=0.838  lr=0.039695
#  Ep70  loss=0.4131  train_acc=0.858  val_acc=0.838  lr=0.036350
#  Ep80  loss=0.4106  train_acc=0.861  val_acc=0.844  lr=0.032725
#  Ep90  loss=0.4072  train_acc=0.855  val_acc=0.812  lr=0.028911
#  Ep100  loss=0.2876  train_acc=0.892  val_acc=0.856  lr=0.025000
#  Ep110  loss=0.3692  train_acc=0.867  val_acc=0.831  lr=0.021089
#  Ep120  loss=0.2604  train_acc=0.903  val_acc=0.838  lr=0.017275
#  Ep130  loss=0.3096  train_acc=0.887  val_acc=0.831  lr=0.013650
#  Ep140  loss=0.2980  train_acc=0.909  val_acc=0.856  lr=0.010305
#  Ep150  loss=0.2697  train_acc=0.908  val_acc=0.863  lr=0.007322
#  Ep160  loss=0.2772  train_acc=0.912  val_acc=0.856  lr=0.004775
#  Ep170  loss=0.2914  train_acc=0.902  val_acc=0.856  lr=0.002725
#  Ep180  loss=0.2296  train_acc=0.916  val_acc=0.856  lr=0.001224
#  Ep190  loss=0.2634  train_acc=0.894  val_acc=0.863  lr=0.000308
#  Ep200  loss=0.2653  train_acc=0.911  val_acc=0.869  lr=0.000000
#  >>> Fold 3 Test Accuracy: 0.810
#
# === Dataset=digits | Fold 4/5 ===
# number of schmidt terms: 2,number of ancilla qubits:1
# Using cpu for training
# Model: HybridModel(
#   (qc): SchmidtQuantumCircuit(
#     (unitary_params): ParameterList(
#         (0): Parameter containing: [torch.float32 of size 6]
#         (1): Parameter containing: [torch.float32 of size 6]
#     )
#   )
#   (classical_net): Sequential(
#     (0): Linear(in_features=64, out_features=64, bias=True)
#     (1): BatchNorm1d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): ReLU()
#     (3): Dropout(p=0.25, inplace=False)
#     (4): Linear(in_features=64, out_features=32, bias=True)
#     (5): BatchNorm1d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (6): ReLU()
#     (7): Dropout(p=0.25, inplace=False)
#     (8): Linear(in_features=32, out_features=10, bias=True)
#   )
# )
# Number of parameters: 6776
# Optimizer: AdamW (
# Parameter Group 0
#     amsgrad: False
#     betas: (0.9, 0.999)
#     capturable: False
#     decoupled_weight_decay: True
#     differentiable: False
#     eps: 1e-08
#     foreach: None
#     fused: None
#     initial_lr: 0.05
#     lr: 0.05
#     maximize: False
#     weight_decay: 0.0001
# )
# Loss Function: CrossEntropyLoss()
#  Ep 1  loss=1.5891  train_acc=0.480  val_acc=0.637  lr=0.049997
#  Ep10  loss=0.7207  train_acc=0.770  val_acc=0.713  lr=0.049692
#  Ep20  loss=0.6152  train_acc=0.781  val_acc=0.756  lr=0.048776
#  Ep30  loss=0.5165  train_acc=0.827  val_acc=0.781  lr=0.047275
#  Ep40  loss=0.5046  train_acc=0.834  val_acc=0.812  lr=0.045225
#  Ep50  loss=0.5310  train_acc=0.838  val_acc=0.750  lr=0.042678
#  Ep60  loss=0.5243  train_acc=0.814  val_acc=0.787  lr=0.039695
#  Ep70  loss=0.4863  train_acc=0.828  val_acc=0.781  lr=0.036350
#  Ep80  loss=0.4494  train_acc=0.848  val_acc=0.794  lr=0.032725
#  Ep90  loss=0.4026  train_acc=0.853  val_acc=0.781  lr=0.028911
#  Ep100  loss=0.3973  train_acc=0.870  val_acc=0.787  lr=0.025000
#  Ep110  loss=0.3460  train_acc=0.878  val_acc=0.806  lr=0.021089
#  Ep120  loss=0.3213  train_acc=0.873  val_acc=0.787  lr=0.017275
#  Ep130  loss=0.3498  train_acc=0.880  val_acc=0.781  lr=0.013650
#  Ep140  loss=0.3351  train_acc=0.894  val_acc=0.775  lr=0.010305
#  Ep150  loss=0.2668  train_acc=0.916  val_acc=0.787  lr=0.007322
#  Ep160  loss=0.3026  train_acc=0.883  val_acc=0.787  lr=0.004775
#  Ep170  loss=0.3023  train_acc=0.891  val_acc=0.794  lr=0.002725
#  Ep180  loss=0.3150  train_acc=0.884  val_acc=0.787  lr=0.001224
#  Ep190  loss=0.2645  train_acc=0.914  val_acc=0.781  lr=0.000308
#  Ep200  loss=0.2628  train_acc=0.894  val_acc=0.781  lr=0.000000
#  >>> Fold 4 Test Accuracy: 0.860
#
# === Dataset=digits | Fold 5/5 ===
# number of schmidt terms: 2,number of ancilla qubits:1
# Using cpu for training
# Model: HybridModel(
#   (qc): SchmidtQuantumCircuit(
#     (unitary_params): ParameterList(
#         (0): Parameter containing: [torch.float32 of size 6]
#         (1): Parameter containing: [torch.float32 of size 6]
#     )
#   )
#   (classical_net): Sequential(
#     (0): Linear(in_features=64, out_features=64, bias=True)
#     (1): BatchNorm1d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): ReLU()
#     (3): Dropout(p=0.25, inplace=False)
#     (4): Linear(in_features=64, out_features=32, bias=True)
#     (5): BatchNorm1d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (6): ReLU()
#     (7): Dropout(p=0.25, inplace=False)
#     (8): Linear(in_features=32, out_features=10, bias=True)
#   )
# )
# Number of parameters: 6776
# Optimizer: AdamW (
# Parameter Group 0
#     amsgrad: False
#     betas: (0.9, 0.999)
#     capturable: False
#     decoupled_weight_decay: True
#     differentiable: False
#     eps: 1e-08
#     foreach: None
#     fused: None
#     initial_lr: 0.05
#     lr: 0.05
#     maximize: False
#     weight_decay: 0.0001
# )
# Loss Function: CrossEntropyLoss()
#  Ep 1  loss=1.5195  train_acc=0.483  val_acc=0.562  lr=0.049997
#  Ep10  loss=0.6779  train_acc=0.766  val_acc=0.787  lr=0.049692
#  Ep20  loss=0.5690  train_acc=0.809  val_acc=0.781  lr=0.048776
#  Ep30  loss=0.5827  train_acc=0.783  val_acc=0.812  lr=0.047275
#  Ep40  loss=0.5688  train_acc=0.802  val_acc=0.775  lr=0.045225
#  Ep50  loss=0.5278  train_acc=0.819  val_acc=0.819  lr=0.042678
#  Ep60  loss=0.5425  train_acc=0.823  val_acc=0.787  lr=0.039695
#  Ep70  loss=0.4221  train_acc=0.853  val_acc=0.844  lr=0.036350
#  Ep80  loss=0.3957  train_acc=0.873  val_acc=0.819  lr=0.032725
#  Ep90  loss=0.4286  train_acc=0.863  val_acc=0.819  lr=0.028911
#  Ep100  loss=0.3903  train_acc=0.855  val_acc=0.831  lr=0.025000
#  Ep110  loss=0.3697  train_acc=0.855  val_acc=0.819  lr=0.021089
#  Ep120  loss=0.4001  train_acc=0.858  val_acc=0.825  lr=0.017275
#  Ep130  loss=0.3308  train_acc=0.883  val_acc=0.819  lr=0.013650
#  Ep140  loss=0.3271  train_acc=0.873  val_acc=0.831  lr=0.010305
#  Ep150  loss=0.2621  train_acc=0.903  val_acc=0.838  lr=0.007322
#  Ep160  loss=0.3138  train_acc=0.878  val_acc=0.831  lr=0.004775
#  Ep170  loss=0.2732  train_acc=0.883  val_acc=0.825  lr=0.002725
#  Ep180  loss=0.2717  train_acc=0.895  val_acc=0.831  lr=0.001224
#  Ep190  loss=0.2869  train_acc=0.897  val_acc=0.831  lr=0.000308
#  Ep200  loss=0.2695  train_acc=0.892  val_acc=0.825  lr=0.000000
#  >>> Fold 5 Test Accuracy: 0.885
#
# >>> digits CV Results: mean=0.841, std=0.030
#
# ========================================
# ========================================
# === Final Summary ===
# iris            folds=5  mean_acc=0.947  std=0.045
# wine            folds=5  mean_acc=0.876  std=0.035
# breast_cancer   folds=5  mean_acc=0.933  std=0.020
# ionosphere      folds=5  mean_acc=0.920  std=0.023
# covtype         folds=5  mean_acc=0.604  std=0.027
# digits          folds=5  mean_acc=0.841  std=0.030

# %%
def plot_cv_results(all_results, all_losses, fig_name="cv_results_summary"):
    import numpy as np
    import matplotlib.pyplot as plt
    import matplotlib as mpl
    from matplotlib.ticker import MaxNLocator
    from matplotlib.lines import Line2D
    import seaborn as sns
    
    # Configure global font settings
    mpl.rcParams.update({
        'font.size': 24,
        'axes.titlesize': 24,
        'axes.labelsize': 24,
        'xtick.labelsize': 24,
        'ytick.labelsize': 24,
        'legend.fontsize': 24
    })
    
    # Create 2x3 grid
    fig, axs = plt.subplots(2, 3, figsize=(24, 16))
    axs = axs.flatten()
    
    palette = sns.color_palette("pastel")
    loss_color = palette[0]       
    train_acc_color = palette[1]  
    val_acc_color = palette[6]    
    
    # Create custom legend elements
    legend_elements = [
        Line2D([0], [0], color=loss_color, lw=3, label='Train Loss'),
        Line2D([0], [0], color=train_acc_color, lw=3, label='Train Accuracy'),
        Line2D([0], [0], color=val_acc_color, lw=3, label='Validation Accuracy')
    ]
    
    for i, (dataset, fold_losses) in enumerate(all_losses.items()):
        if i >= 6:  # Only plot first 6 datasets
            break
            
        ax = axs[i]
        n_folds = len(fold_losses)
        max_epochs = max(len(fold) for fold in fold_losses.values())
        
        # Prepare arrays for metrics
        train_loss = np.full((n_folds, max_epochs), np.nan)
        train_acc = np.full((n_folds, max_epochs), np.nan)
        val_acc = np.full((n_folds, max_epochs), np.nan)
        best_val_acc = np.zeros(n_folds)
        
        # Extract metrics for each fold
        for fold_idx, fold_data in enumerate(fold_losses.values()):
            n_epochs = len(fold_data)
            train_loss[fold_idx, :n_epochs] = [x[0] for x in fold_data]
            train_acc[fold_idx, :n_epochs] = [x[1] for x in fold_data]
            val_acc[fold_idx, :n_epochs] = [x[2] for x in fold_data]
            best_val_acc[fold_idx] = max(x[2] for x in fold_data)
        
        # Calculate means and stds
        mean_train_loss = np.nanmean(train_loss, axis=0)
        mean_train_acc = np.nanmean(train_acc, axis=0)
        mean_val_acc = np.nanmean(val_acc, axis=0)
        
        # Get test accuracies
        test_accs = all_results[dataset]
        mean_test_acc = np.mean(test_accs)
        std_test_acc = np.std(test_accs)
        # Create twin axis for accuracies
        ax2 = ax#.twinx()
        # Plot individual runs with shadows
        for fold_idx in range(n_folds):
            # Plot individual training loss (light shadow)
            ax.plot(train_loss[fold_idx], 
                     color=loss_color, 
                     alpha=0.35, 
                     linewidth=0.8)
            

            
            # Plot individual accuracy runs
            ax2.plot(train_acc[fold_idx], 
                      color=train_acc_color, 
                      alpha=0.35, 
                      linewidth=0.8)
            ax2.plot(val_acc[fold_idx], 
                      color=val_acc_color, 
                      alpha=0.35, 
                      linewidth=0.8)
        
        # Plot mean training loss
        ax.plot(mean_train_loss, color=loss_color, linewidth=3, alpha=1)
        
        # Plot mean accuracies
        ax2.plot(mean_train_acc, color=train_acc_color, linewidth=3, alpha=1)
        ax2.plot(mean_val_acc, color=val_acc_color, linewidth=3, alpha=1)
        
        
        # Set titles and labels
        title = f"{dataset.replace('_', ' ').title()}\n"
        title += f"Test Acc: {mean_test_acc:.3f} ± {std_test_acc:.3f}"
        ax.set_title(title, fontsize=24, pad=15)
        
        ax.set_xlabel('Epochs', fontsize=24)
        # ax.set_ylabel('Training Loss', fontsize=24)
        ax.set_ylabel('Loss / Accuracy', fontsize=24)
        
        # Set axis colors
        # ax.tick_params(axis='y', labelcolor=loss_color)
        # ax2.tick_params(axis='y', labelcolor=val_acc_color)
        
        # Configure grid and limits
        ax.grid(True, linestyle='--', alpha=0.3, axis='x')
        ax2.grid(True, linestyle='--', alpha=0.3, axis='y')
        
        ax.set_ylim(bottom=0)
        # ax2.set_ylim(0, 1.05)
        

    # Add common legend
    fig.legend(handles=legend_elements, loc='center', 
               ncol=4, fontsize=24, framealpha=0.9)
    
    # Adjust layout
    plt.tight_layout(pad=4.0, w_pad=3.0, h_pad=4.0)
    fig.subplots_adjust(bottom=0.1)  # Make space for legend
    
    # Save high-resolution figures
    plt.savefig(f'{fig_name}.pdf', dpi=300, bbox_inches='tight')
    plt.savefig(f'{fig_name}.png', dpi=300, bbox_inches='tight')
    plt.show()
    plt.close()

plot_cv_results(all_results, all_losses, fig_name="fig_cross_validation_summary_classical_reduced")
